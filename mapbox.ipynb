# %%
import requests
from itertools import product
import pandas as pd

def fetch_route_from_mapbox(start_coords, end_coords, mapbox_token):
    url = f"https://api.mapbox.com/directions/v5/mapbox/driving-traffic/{start_coords};{end_coords}"
    params = {
        "access_token": mapbox_token,
        "geometries": "geojson",
        "overview": "full",
        "annotations": "duration,distance,congestion"
    }
    response = requests.get(url, params=params)
    return response.json()

def main(start_coords, end_coords, mapbox_token):
    # Fetch the route
    route_response = fetch_route_from_mapbox(start_coords, end_coords, mapbox_token)

    if 'routes' in route_response and route_response['routes']:
        best_route = min(route_response["routes"], key=lambda r: r['duration'])
        distance = best_route["distance"] / 1000  # Convert to kilometers
        duration = best_route["duration"] / 60    # Convert to minutes

        return distance  # Optionally return the best route
    else:
        print("Failed to fetch the route. Please check your coordinates and Mapbox token.")
        return None

if __name__ == "__main__":
    mapbox_token = "pk.eyJ1Ijoia3Jpc2hhbmd1cHRhMzMiLCJhIjoiY2xwOHNuZmIwMHluZzJqcXA2Y253ajhwNyJ9.AgLEDuvcdU7ocKc8tLumPQ"                


    #read Removal Sectors i sheet from DataFrames.xlsx
    df_removal_sites = pd.read_excel('DataFrames.xlsx', sheet_name='Removal Sectors i')
    #read Disposal Sites j sheet from DataFrames.xlsx
    df_disposal_sites = pd.read_excel('DataFrames.xlsx', sheet_name='Disposal Sites j')

    removal_sites_longitudes=df_removal_sites['Longitude'].tolist()
    removal_sites_latitudes=df_removal_sites['Latitude'].tolist()

    disposal_sites_longitudes=df_disposal_sites['Longitude'].tolist()
    disposal_sites_latitudes=df_disposal_sites['Latitude'].tolist()

    final_df = pd.DataFrame(columns=['Removal Site', 'Disposal Site', 'Distance'])

    for i in range(len(removal_sites_longitudes)):
        for j in range(len(disposal_sites_longitudes)):
            start_location = f"{removal_sites_longitudes[i]},{removal_sites_latitudes[i]}"
            start_name=df_removal_sites['NomSecteur'][i]

            end_location = f"{disposal_sites_longitudes[j]},{disposal_sites_latitudes[j]}" 
            end_name=df_disposal_sites['NomDepot'][j]  

            distance=main(start_location, end_location, mapbox_token)
            print(f"Distance between {start_name} and {end_name} is {distance} km")
            new_row = {'Removal Site': start_name, 'Disposal Site': end_name, 'Distance': distance}
            new_row_df = pd.DataFrame([new_row])
            final_df = pd.concat([final_df, new_row_df], ignore_index=True)

    print(final_df)
    final_df.to_excel('Distance_output.xlsx',index=False)
# Out:
# Distance between AHU-101 and St-Michel - Charland (VSP) is 10.195564000000001 km
# Distance between AHU-101 and St-Michel - Robert (VSP) is 13.140525 km
# Distance between AHU-101 and St-Michel-17i̬me(Sous-Sol) is 11.041832000000001 km
# Distance between AHU-101 and Butler (S-O) is 18.75826 km
# Distance between AHU-101 and De la Salle (MHM) is 18.303719 km
# Distance between AHU-101 and Fullum (VMA) is 22.753967 km
# Distance between AHU-101 and Iberville (PMR) is 15.924388 km
# Distance between AHU-101 and Jules-Poitras 1 (AHU) is 3.0129569999999997 km
# Distance between AHU-101 and Jules-Poitras 2 (SLA) is 3.0591 km
# Distance between AHU-101 and Lausanne (MTN) is 8.901012000000001 km
# Distance between AHU-101 and Millen (AHU) is 5.557220999999999 km
# Distance between AHU-101 and Riverside (VMA) is 20.92116 km
# Distance between AHU-101 and Saint-Pierre (LAC) is 16.787975 km
# Distance between AHU-101 and Sauv̩ (AHU) is 4.406625 km
# Distance between AHU-101 and Verdun (VER) is 19.021715 km
# Distance between AHU-101 and 46 ieme (LAC) is 17.271354 km
# Distance between AHU-101 and Angrignon (LAS) is 19.437044999999998 km
# Distance between AHU-101 and Armand-Chaput (RDP) is 25.578122999999998 km
# Distance between AHU-101 and Autoroute 13 (PRF) is 8.735166999999999 km
# Distance between AHU-101 and Ch̢teau Pierrefonds (PRF) is 22.402009999999997 km
# Distance between AHU-101 and Lafarge (sud) (MHM) is 22.576158 km
# Distance between AHU-101 and Langelier (SLE) is 14.245256999999999 km
# Distance between AHU-101 and Newman (S-O) is 20.94551 km
# Distance between AHU-101 and Ray-Lawson (ANJ) is 16.097496 km
# Distance between AHU-101 and Sartelon (SLA) is 6.499959 km
# Distance between AHU-101 and Thimens (SLA) is 8.246578 km
# Distance between AHU-102 and St-Michel - Charland (VSP) is 9.986773 km
# Distance between AHU-102 and St-Michel - Robert (VSP) is 12.931734 km
# Distance between AHU-102 and St-Michel-17i̬me(Sous-Sol) is 10.833041 km
# Distance between AHU-102 and Butler (S-O) is 18.549469000000002 km
# Distance between AHU-102 and De la Salle (MHM) is 18.094928 km
# Distance between AHU-102 and Fullum (VMA) is 22.545175999999998 km
# Distance between AHU-102 and Iberville (PMR) is 15.715596999999999 km
# Distance between AHU-102 and Jules-Poitras 1 (AHU) is 2.8041660000000004 km
# Distance between AHU-102 and Jules-Poitras 2 (SLA) is 2.850309 km
# Distance between AHU-102 and Lausanne (MTN) is 8.692221 km
# Distance between AHU-102 and Millen (AHU) is 3.718911 km
# Distance between AHU-102 and Riverside (VMA) is 20.712366999999997 km
# Distance between AHU-102 and Saint-Pierre (LAC) is 16.579184 km
# Distance between AHU-102 and Sauv̩ (AHU) is 4.197833999999999 km
# Distance between AHU-102 and Verdun (VER) is 18.812924 km
# Distance between AHU-102 and 46 ieme (LAC) is 17.062561000000002 km
# Distance between AHU-102 and Angrignon (LAS) is 19.228252 km
# Distance between AHU-102 and Armand-Chaput (RDP) is 25.369332 km
# Distance between AHU-102 and Autoroute 13 (PRF) is 8.769993000000001 km
# Distance between AHU-102 and Ch̢teau Pierrefonds (PRF) is 22.436837999999998 km
# Distance between AHU-102 and Lafarge (sud) (MHM) is 22.367366999999998 km
# Distance between AHU-102 and Langelier (SLE) is 14.036466 km
# Distance between AHU-102 and Newman (S-O) is 20.736717000000002 km
# Distance between AHU-102 and Ray-Lawson (ANJ) is 15.888707 km
# Distance between AHU-102 and Sartelon (SLA) is 6.534786 km
# Distance between AHU-102 and Thimens (SLA) is 8.281404 km
# Distance between AHU-103 and St-Michel - Charland (VSP) is 10.195564000000001 km
# Distance between AHU-103 and St-Michel - Robert (VSP) is 13.140525 km
# Distance between AHU-103 and St-Michel-17i̬me(Sous-Sol) is 11.041832000000001 km
# Distance between AHU-103 and Butler (S-O) is 18.75826 km
# Distance between AHU-103 and De la Salle (MHM) is 18.303719 km
# Distance between AHU-103 and Fullum (VMA) is 22.753967 km
# Distance between AHU-103 and Iberville (PMR) is 15.924388 km
# Distance between AHU-103 and Jules-Poitras 1 (AHU) is 3.0129569999999997 km
# Distance between AHU-103 and Jules-Poitras 2 (SLA) is 3.0591 km
# Distance between AHU-103 and Lausanne (MTN) is 8.901012000000001 km
# Distance between AHU-103 and Millen (AHU) is 5.557220999999999 km
# Distance between AHU-103 and Riverside (VMA) is 20.92116 km
# Distance between AHU-103 and Saint-Pierre (LAC) is 16.787975 km
# Distance between AHU-103 and Sauv̩ (AHU) is 4.406625 km
# Distance between AHU-103 and Verdun (VER) is 19.021715 km
# Distance between AHU-103 and 46 ieme (LAC) is 17.271354 km
# Distance between AHU-103 and Angrignon (LAS) is 19.437044999999998 km
# Distance between AHU-103 and Armand-Chaput (RDP) is 25.578122999999998 km
# Distance between AHU-103 and Autoroute 13 (PRF) is 8.735166999999999 km
# Distance between AHU-103 and Ch̢teau Pierrefonds (PRF) is 22.402009999999997 km
# Distance between AHU-103 and Lafarge (sud) (MHM) is 22.576158 km
# Distance between AHU-103 and Langelier (SLE) is 14.245256999999999 km
# Distance between AHU-103 and Newman (S-O) is 20.94551 km
# Distance between AHU-103 and Ray-Lawson (ANJ) is 16.097496 km
# Distance between AHU-103 and Sartelon (SLA) is 6.499959 km
# Distance between AHU-103 and Thimens (SLA) is 8.246578 km
# Distance between AHU-104 and St-Michel - Charland (VSP) is 8.576025 km
# Distance between AHU-104 and St-Michel - Robert (VSP) is 11.184773999999999 km
# Distance between AHU-104 and St-Michel-17i̬me(Sous-Sol) is 9.422293 km
# Distance between AHU-104 and Butler (S-O) is 19.032473000000003 km
# Distance between AHU-104 and De la Salle (MHM) is 18.577928 km
# Distance between AHU-104 and Fullum (VMA) is 23.028178 km
# Distance between AHU-104 and Iberville (PMR) is 16.198597 km
# Distance between AHU-104 and Jules-Poitras 1 (AHU) is 3.2871680000000003 km
# Distance between AHU-104 and Jules-Poitras 2 (SLA) is 3.333311 km
# Distance between AHU-104 and Lausanne (MTN) is 7.281472 km
# Distance between AHU-104 and Millen (AHU) is 3.5242150000000003 km
# Distance between AHU-104 and Riverside (VMA) is 21.195369 km
# Distance between AHU-104 and Saint-Pierre (LAC) is 17.062188 km
# Distance between AHU-104 and Sauv̩ (AHU) is 3.435382 km
# Distance between AHU-104 and Verdun (VER) is 19.295928 km
# Distance between AHU-104 and 46 ieme (LAC) is 17.545562 km
# Distance between AHU-104 and Angrignon (LAS) is 19.711254 km
# Distance between AHU-104 and Armand-Chaput (RDP) is 20.615116999999998 km
# Distance between AHU-104 and Autoroute 13 (PRF) is 9.252995 km
# Distance between AHU-104 and Ch̢teau Pierrefonds (PRF) is 22.91984 km
# Distance between AHU-104 and Lafarge (sud) (MHM) is 22.850371 km
# Distance between AHU-104 and Langelier (SLE) is 12.625717 km
# Distance between AHU-104 and Newman (S-O) is 21.219719 km
# Distance between AHU-104 and Ray-Lawson (ANJ) is 14.477957 km
# Distance between AHU-104 and Sartelon (SLA) is 7.0177879999999995 km
# Distance between AHU-104 and Thimens (SLA) is 8.764406999999999 km
# Distance between AHU-105 and St-Michel - Charland (VSP) is 4.836357 km
# Distance between AHU-105 and St-Michel - Robert (VSP) is 7.255793 km
# Distance between AHU-105 and St-Michel-17i̬me(Sous-Sol) is 5.682625 km
# Distance between AHU-105 and Butler (S-O) is 15.860021000000001 km
# Distance between AHU-105 and De la Salle (MHM) is 12.418987 km
# Distance between AHU-105 and Fullum (VMA) is 11.314351 km
# Distance between AHU-105 and Iberville (PMR) is 10.039655 km
# Distance between AHU-105 and Jules-Poitras 1 (AHU) is 4.824479 km
# Distance between AHU-105 and Jules-Poitras 2 (SLA) is 3.406698 km
# Distance between AHU-105 and Lausanne (MTN) is 6.181189000000001 km
# Distance between AHU-105 and Millen (AHU) is 2.837399 km
# Distance between AHU-105 and Riverside (VMA) is 11.584847 km
# Distance between AHU-105 and Saint-Pierre (LAC) is 13.889736000000001 km
# Distance between AHU-105 and Sauv̩ (AHU) is 1.620614 km
# Distance between AHU-105 and Verdun (VER) is 16.123476 km
# Distance between AHU-105 and 46 ieme (LAC) is 14.373113 km
# Distance between AHU-105 and Angrignon (LAS) is 16.538805 km
# Distance between AHU-105 and Armand-Chaput (RDP) is 19.693393 km
# Distance between AHU-105 and Autoroute 13 (PRF) is 10.413579 km
# Distance between AHU-105 and Ch̢teau Pierrefonds (PRF) is 26.814059 km
# Distance between AHU-105 and Lafarge (sud) (MHM) is 16.691428 km
# Distance between AHU-105 and Langelier (SLE) is 9.241039 km
# Distance between AHU-105 and Newman (S-O) is 18.04727 km
# Distance between AHU-105 and Ray-Lawson (ANJ) is 13.377675 km
# Distance between AHU-105 and Sartelon (SLA) is 8.178372999999999 km
# Distance between AHU-105 and Thimens (SLA) is 10.998635 km
# Distance between AHU-106 and St-Michel - Charland (VSP) is 5.942661 km
# Distance between AHU-106 and St-Michel - Robert (VSP) is 9.284607 km
# Distance between AHU-106 and St-Michel-17i̬me(Sous-Sol) is 6.788928 km
# Distance between AHU-106 and Butler (S-O) is 23.188266 km
# Distance between AHU-106 and De la Salle (MHM) is 14.85378 km
# Distance between AHU-106 and Fullum (VMA) is 13.685593999999998 km
# Distance between AHU-106 and Iberville (PMR) is 12.468313 km
# Distance between AHU-106 and Jules-Poitras 1 (AHU) is 9.482476 km
# Distance between AHU-106 and Jules-Poitras 2 (SLA) is 8.108403000000001 km
# Distance between AHU-106 and Lausanne (MTN) is 5.920314 km
# Distance between AHU-106 and Millen (AHU) is 4.5898509999999995 km
# Distance between AHU-106 and Riverside (VMA) is 17.222527 km
# Distance between AHU-106 and Saint-Pierre (LAC) is 21.21798 km
# Distance between AHU-106 and Sauv̩ (AHU) is 7.092377000000001 km
# Distance between AHU-106 and Verdun (VER) is 23.451719 km
# Distance between AHU-106 and 46 ieme (LAC) is 31.761219 km
# Distance between AHU-106 and Angrignon (LAS) is 23.867048999999998 km
# Distance between AHU-106 and Armand-Chaput (RDP) is 25.77324 km
# Distance between AHU-106 and Autoroute 13 (PRF) is 23.499092 km
# Distance between AHU-106 and Ch̢teau Pierrefonds (PRF) is 39.914125 km
# Distance between AHU-106 and Lafarge (sud) (MHM) is 25.673211 km
# Distance between AHU-106 and Langelier (SLE) is 10.021263000000001 km
# Distance between AHU-106 and Newman (S-O) is 25.375514 km
# Distance between AHU-106 and Ray-Lawson (ANJ) is 19.636082 km
# Distance between AHU-106 and Sartelon (SLA) is 12.880077 km
# Distance between AHU-106 and Thimens (SLA) is 14.604445 km
# Distance between AHU-107 and St-Michel - Charland (VSP) is 3.924458 km
# Distance between AHU-107 and St-Michel - Robert (VSP) is 6.533207999999999 km
# Distance between AHU-107 and St-Michel-17i̬me(Sous-Sol) is 4.7707250000000005 km
# Distance between AHU-107 and Butler (S-O) is 17.15526 km
# Distance between AHU-107 and De la Salle (MHM) is 12.407896000000001 km
# Distance between AHU-107 and Fullum (VMA) is 10.743086 km
# Distance between AHU-107 and Iberville (PMR) is 9.468392 km
# Distance between AHU-107 and Jules-Poitras 1 (AHU) is 5.962518 km
# Distance between AHU-107 and Jules-Poitras 2 (SLA) is 4.588446 km
# Distance between AHU-107 and Lausanne (MTN) is 5.321327 km
# Distance between AHU-107 and Millen (AHU) is 1.821556 km
# Distance between AHU-107 and Riverside (VMA) is 12.249281000000002 km
# Distance between AHU-107 and Saint-Pierre (LAC) is 15.184975 km
# Distance between AHU-107 and Sauv̩ (AHU) is 2.409444 km
# Distance between AHU-107 and Verdun (VER) is 17.418715 km
# Distance between AHU-107 and 46 ieme (LAC) is 15.668352 km
# Distance between AHU-107 and Angrignon (LAS) is 17.834041000000003 km
# Distance between AHU-107 and Armand-Chaput (RDP) is 19.122127 km
# Distance between AHU-107 and Autoroute 13 (PRF) is 11.595327 km
# Distance between AHU-107 and Ch̢teau Pierrefonds (PRF) is 28.109299 km
# Distance between AHU-107 and Lafarge (sud) (MHM) is 16.120163 km
# Distance between AHU-107 and Langelier (SLE) is 8.329139 km
# Distance between AHU-107 and Newman (S-O) is 19.342508000000002 km
# Distance between AHU-107 and Ray-Lawson (ANJ) is 12.517812 km
# Distance between AHU-107 and Sartelon (SLA) is 9.36012 km
# Distance between AHU-107 and Thimens (SLA) is 12.293873 km
# Distance between AHU-201 and St-Michel - Charland (VSP) is 5.414553 km
# Distance between AHU-201 and St-Michel - Robert (VSP) is 8.023303 km
# Distance between AHU-201 and St-Michel-17i̬me(Sous-Sol) is 6.260821 km
# Distance between AHU-201 and Butler (S-O) is 19.780707 km
# Distance between AHU-201 and De la Salle (MHM) is 12.816754999999999 km
# Distance between AHU-201 and Fullum (VMA) is 12.707554 km
# Distance between AHU-201 and Iberville (PMR) is 10.437424 km
# Distance between AHU-201 and Jules-Poitras 1 (AHU) is 5.455617 km
# Distance between AHU-201 and Jules-Poitras 2 (SLA) is 4.081545 km
# Distance between AHU-201 and Lausanne (MTN) is 4.12 km
# Distance between AHU-201 and Millen (AHU) is 0.562991 km
# Distance between AHU-201 and Riverside (VMA) is 16.244486000000002 km
# Distance between AHU-201 and Saint-Pierre (LAC) is 17.810422 km
# Distance between AHU-201 and Sauv̩ (AHU) is 3.065518 km
# Distance between AHU-201 and Verdun (VER) is 20.04416 km
# Distance between AHU-201 and 46 ieme (LAC) is 18.293796999999998 km
# Distance between AHU-201 and Angrignon (LAS) is 20.459488 km
# Distance between AHU-201 and Armand-Chaput (RDP) is 17.453646 km
# Distance between AHU-201 and Autoroute 13 (PRF) is 11.088426 km
# Distance between AHU-201 and Ch̢teau Pierrefonds (PRF) is 24.75527 km
# Distance between AHU-201 and Lafarge (sud) (MHM) is 17.089197 km
# Distance between AHU-201 and Langelier (SLE) is 9.464245 km
# Distance between AHU-201 and Newman (S-O) is 21.967953 km
# Distance between AHU-201 and Ray-Lawson (ANJ) is 11.316485 km
# Distance between AHU-201 and Sartelon (SLA) is 8.853219 km
# Distance between AHU-201 and Thimens (SLA) is 10.577586 km
# Distance between AHU-202 and St-Michel - Charland (VSP) is 6.715224 km
# Distance between AHU-202 and St-Michel - Robert (VSP) is 9.323975 km
# Distance between AHU-202 and St-Michel-17i̬me(Sous-Sol) is 7.5614930000000005 km
# Distance between AHU-202 and Butler (S-O) is 18.752842 km
# Distance between AHU-202 and De la Salle (MHM) is 14.117427 km
# Distance between AHU-202 and Fullum (VMA) is 22.748547 km
# Distance between AHU-202 and Iberville (PMR) is 11.738095999999999 km
# Distance between AHU-202 and Jules-Poitras 1 (AHU) is 4.427752000000001 km
# Distance between AHU-202 and Jules-Poitras 2 (SLA) is 3.05368 km
# Distance between AHU-202 and Lausanne (MTN) is 5.420672 km
# Distance between AHU-202 and Millen (AHU) is 1.6634149999999999 km
# Distance between AHU-202 and Riverside (VMA) is 20.915738 km
# Distance between AHU-202 and Saint-Pierre (LAC) is 16.782557 km
# Distance between AHU-202 and Sauv̩ (AHU) is 2.037654 km
# Distance between AHU-202 and Verdun (VER) is 19.016296999999998 km
# Distance between AHU-202 and 46 ieme (LAC) is 17.265932 km
# Distance between AHU-202 and Angrignon (LAS) is 19.431625 km
# Distance between AHU-202 and Armand-Chaput (RDP) is 18.754317999999998 km
# Distance between AHU-202 and Autoroute 13 (PRF) is 10.060562 km
# Distance between AHU-202 and Ch̢teau Pierrefonds (PRF) is 23.727406 km
# Distance between AHU-202 and Lafarge (sud) (MHM) is 18.389867 km
# Distance between AHU-202 and Langelier (SLE) is 10.764916 km
# Distance between AHU-202 and Newman (S-O) is 20.940088 km
# Distance between AHU-202 and Ray-Lawson (ANJ) is 12.617158 km
# Distance between AHU-202 and Sartelon (SLA) is 7.825354999999999 km
# Distance between AHU-202 and Thimens (SLA) is 9.549723 km
# Distance between ANJ-101 and St-Michel - Charland (VSP) is 12.260465 km
# Distance between ANJ-101 and St-Michel - Robert (VSP) is 9.252343000000002 km
# Distance between ANJ-101 and St-Michel-17i̬me(Sous-Sol) is 11.392243 km
# Distance between ANJ-101 and Butler (S-O) is 22.650332 km
# Distance between ANJ-101 and De la Salle (MHM) is 12.96312 km
# Distance between ANJ-101 and Fullum (VMA) is 16.053041 km
# Distance between ANJ-101 and Iberville (PMR) is 13.221193999999999 km
# Distance between ANJ-101 and Jules-Poitras 1 (AHU) is 20.599406 km
# Distance between ANJ-101 and Jules-Poitras 2 (SLA) is 17.810406 km
# Distance between ANJ-101 and Lausanne (MTN) is 11.306134 km
# Distance between ANJ-101 and Millen (AHU) is 14.705264 km
# Distance between ANJ-101 and Riverside (VMA) is 19.977299 km
# Distance between ANJ-101 and Saint-Pierre (LAC) is 25.071068 km
# Distance between ANJ-101 and Sauv̩ (AHU) is 15.979113 km
# Distance between ANJ-101 and Verdun (VER) is 24.093359 km
# Distance between ANJ-101 and 46 ieme (LAC) is 26.195047 km
# Distance between ANJ-101 and Angrignon (LAS) is 27.746641 km
# Distance between ANJ-101 and Armand-Chaput (RDP) is 5.9569790000000005 km
# Distance between ANJ-101 and Autoroute 13 (PRF) is 36.898664 km
# Distance between ANJ-101 and Ch̢teau Pierrefonds (PRF) is 38.635992 km
# Distance between ANJ-101 and Lafarge (sud) (MHM) is 5.98526 km
# Distance between ANJ-101 and Langelier (SLE) is 7.374618000000001 km
# Distance between ANJ-101 and Newman (S-O) is 26.978275 km
# Distance between ANJ-101 and Ray-Lawson (ANJ) is 3.6205079999999996 km
# Distance between ANJ-101 and Sartelon (SLA) is 22.582078000000003 km
# Distance between ANJ-101 and Thimens (SLA) is 22.82057 km
# Distance between ANJ-309 and St-Michel - Charland (VSP) is 11.028395 km
# Distance between ANJ-309 and St-Michel - Robert (VSP) is 8.020272 km
# Distance between ANJ-309 and St-Michel-17i̬me(Sous-Sol) is 10.160174000000001 km
# Distance between ANJ-309 and Butler (S-O) is 19.675743999999998 km
# Distance between ANJ-309 and De la Salle (MHM) is 9.988533 km
# Distance between ANJ-309 and Fullum (VMA) is 13.078451999999999 km
# Distance between ANJ-309 and Iberville (PMR) is 10.246604999999999 km
# Distance between ANJ-309 and Jules-Poitras 1 (AHU) is 19.367335999999998 km
# Distance between ANJ-309 and Jules-Poitras 2 (SLA) is 16.578333999999998 km
# Distance between ANJ-309 and Lausanne (MTN) is 10.430399999999999 km
# Distance between ANJ-309 and Millen (AHU) is 13.473192999999998 km
# Distance between ANJ-309 and Riverside (VMA) is 17.002710999999998 km
# Distance between ANJ-309 and Saint-Pierre (LAC) is 22.096479 km
# Distance between ANJ-309 and Sauv̩ (AHU) is 14.747043 km
# Distance between ANJ-309 and Verdun (VER) is 21.118771000000002 km
# Distance between ANJ-309 and 46 ieme (LAC) is 24.962979 km
# Distance between ANJ-309 and Angrignon (LAS) is 24.772053 km
# Distance between ANJ-309 and Armand-Chaput (RDP) is 9.106046000000001 km
# Distance between ANJ-309 and Autoroute 13 (PRF) is 36.02293 km
# Distance between ANJ-309 and Ch̢teau Pierrefonds (PRF) is 37.403926 km
# Distance between ANJ-309 and Lafarge (sud) (MHM) is 4.752083 km
# Distance between ANJ-309 and Langelier (SLE) is 6.411417999999999 km
# Distance between ANJ-309 and Newman (S-O) is 24.003688999999998 km
# Distance between ANJ-309 and Ray-Lawson (ANJ) is 3.847512 km
# Distance between ANJ-309 and Sartelon (SLA) is 21.350009999999997 km
# Distance between ANJ-309 and Thimens (SLA) is 21.588498 km
# Distance between ANJ-310 and St-Michel - Charland (VSP) is 10.356798000000001 km
# Distance between ANJ-310 and St-Michel - Robert (VSP) is 7.346677 km
# Distance between ANJ-310 and St-Michel-17i̬me(Sous-Sol) is 9.488577 km
# Distance between ANJ-310 and Butler (S-O) is 17.746502 km
# Distance between ANJ-310 and De la Salle (MHM) is 8.059292000000001 km
# Distance between ANJ-310 and Fullum (VMA) is 11.149211 km
# Distance between ANJ-310 and Iberville (PMR) is 8.383688 km
# Distance between ANJ-310 and Jules-Poitras 1 (AHU) is 18.695738000000002 km
# Distance between ANJ-310 and Jules-Poitras 2 (SLA) is 15.906739 km
# Distance between ANJ-310 and Lausanne (MTN) is 10.725715000000001 km
# Distance between ANJ-310 and Millen (AHU) is 12.801596 km
# Distance between ANJ-310 and Riverside (VMA) is 15.073469 km
# Distance between ANJ-310 and Saint-Pierre (LAC) is 20.167238 km
# Distance between ANJ-310 and Sauv̩ (AHU) is 14.075446 km
# Distance between ANJ-310 and Verdun (VER) is 19.189529 km
# Distance between ANJ-310 and 46 ieme (LAC) is 24.291383000000003 km
# Distance between ANJ-310 and Angrignon (LAS) is 22.842812000000002 km
# Distance between ANJ-310 and Armand-Chaput (RDP) is 12.74034 km
# Distance between ANJ-310 and Autoroute 13 (PRF) is 23.784491999999997 km
# Distance between ANJ-310 and Ch̢teau Pierrefonds (PRF) is 36.732328 km
# Distance between ANJ-310 and Lafarge (sud) (MHM) is 5.147437 km
# Distance between ANJ-310 and Langelier (SLE) is 5.775234 km
# Distance between ANJ-310 and Newman (S-O) is 22.074447 km
# Distance between ANJ-310 and Ray-Lawson (ANJ) is 7.554152 km
# Distance between ANJ-310 and Sartelon (SLA) is 20.678412 km
# Distance between ANJ-310 and Thimens (SLA) is 20.916900000000002 km
# Distance between ANJ-311 and St-Michel - Charland (VSP) is 7.176721 km
# Distance between ANJ-311 and St-Michel - Robert (VSP) is 4.987497 km
# Distance between ANJ-311 and St-Michel-17i̬me(Sous-Sol) is 7.129396 km
# Distance between ANJ-311 and Butler (S-O) is 19.355248 km
# Distance between ANJ-311 and De la Salle (MHM) is 9.668037 km
# Distance between ANJ-311 and Fullum (VMA) is 12.570135 km
# Distance between ANJ-311 and Iberville (PMR) is 9.992434 km
# Distance between ANJ-311 and Jules-Poitras 1 (AHU) is 16.33656 km
# Distance between ANJ-311 and Jules-Poitras 2 (SLA) is 13.547558 km
# Distance between ANJ-311 and Lausanne (MTN) is 7.881763 km
# Distance between ANJ-311 and Millen (AHU) is 10.442415 km
# Distance between ANJ-311 and Riverside (VMA) is 16.682217 km
# Distance between ANJ-311 and Saint-Pierre (LAC) is 21.775984 km
# Distance between ANJ-311 and Sauv̩ (AHU) is 11.716266 km
# Distance between ANJ-311 and Verdun (VER) is 20.798277 km
# Distance between ANJ-311 and 46 ieme (LAC) is 21.932199 km
# Distance between ANJ-311 and Angrignon (LAS) is 24.097893 km
# Distance between ANJ-311 and Armand-Chaput (RDP) is 10.413452 km
# Distance between ANJ-311 and Autoroute 13 (PRF) is 21.425312 km
# Distance between ANJ-311 and Ch̢teau Pierrefonds (PRF) is 34.373148 km
# Distance between ANJ-311 and Lafarge (sud) (MHM) is 7.215255 km
# Distance between ANJ-311 and Langelier (SLE) is 2.917329 km
# Distance between ANJ-311 and Newman (S-O) is 25.606355 km
# Distance between ANJ-311 and Ray-Lawson (ANJ) is 4.00143 km
# Distance between ANJ-311 and Sartelon (SLA) is 18.319232 km
# Distance between ANJ-311 and Thimens (SLA) is 18.557721 km
# Distance between ANJ-312 and St-Michel - Charland (VSP) is 5.4184790000000005 km
# Distance between ANJ-312 and St-Michel - Robert (VSP) is 5.743117 km
# Distance between ANJ-312 and St-Michel-17i̬me(Sous-Sol) is 7.165888 km
# Distance between ANJ-312 and Butler (S-O) is 22.585974999999998 km
# Distance between ANJ-312 and De la Salle (MHM) is 12.898763 km
# Distance between ANJ-312 and Fullum (VMA) is 15.988683000000002 km
# Distance between ANJ-312 and Iberville (PMR) is 13.156836 km
# Distance between ANJ-312 and Jules-Poitras 1 (AHU) is 14.172438 km
# Distance between ANJ-312 and Jules-Poitras 2 (SLA) is 12.798366 km
# Distance between ANJ-312 and Lausanne (MTN) is 5.446957 km
# Distance between ANJ-312 and Millen (AHU) is 9.279813 km
# Distance between ANJ-312 and Riverside (VMA) is 19.912941 km
# Distance between ANJ-312 and Saint-Pierre (LAC) is 25.006708999999997 km
# Distance between ANJ-312 and Sauv̩ (AHU) is 11.782341 km
# Distance between ANJ-312 and Verdun (VER) is 24.029 km
# Distance between ANJ-312 and 46 ieme (LAC) is 24.406145000000002 km
# Distance between ANJ-312 and Angrignon (LAS) is 27.682282999999998 km
# Distance between ANJ-312 and Armand-Chaput (RDP) is 8.765164 km
# Distance between ANJ-312 and Autoroute 13 (PRF) is 32.450703000000004 km
# Distance between ANJ-312 and Ch̢teau Pierrefonds (PRF) is 48.865733999999996 km
# Distance between ANJ-312 and Lafarge (sud) (MHM) is 9.047518 km
# Distance between ANJ-312 and Langelier (SLE) is 1.159088 km
# Distance between ANJ-312 and Newman (S-O) is 26.913919999999997 km
# Distance between ANJ-312 and Ray-Lawson (ANJ) is 2.628005 km
# Distance between ANJ-312 and Sartelon (SLA) is 17.570041 km
# Distance between ANJ-312 and Thimens (SLA) is 21.031668 km
# Distance between CDN-111 and St-Michel - Charland (VSP) is 17.281162000000002 km
# Distance between CDN-111 and St-Michel - Robert (VSP) is 15.833508 km
# Distance between CDN-111 and St-Michel-17i̬me(Sous-Sol) is 16.412941 km
# Distance between CDN-111 and Butler (S-O) is 4.789453000000001 km
# Distance between CDN-111 and De la Salle (MHM) is 13.143606 km
# Distance between CDN-111 and Fullum (VMA) is 10.112551999999999 km
# Distance between CDN-111 and Iberville (PMR) is 11.895476 km
# Distance between CDN-111 and Jules-Poitras 1 (AHU) is 12.017136 km
# Distance between CDN-111 and Jules-Poitras 2 (SLA) is 11.852426 km
# Distance between CDN-111 and Lausanne (MTN) is 17.598796999999998 km
# Distance between CDN-111 and Millen (AHU) is 14.255004000000001 km
# Distance between CDN-111 and Riverside (VMA) is 8.279743 km
# Distance between CDN-111 and Saint-Pierre (LAC) is 2.6672919999999998 km
# Distance between CDN-111 and Sauv̩ (AHU) is 13.104409 km
# Distance between CDN-111 and Verdun (VER) is 5.052907 km
# Distance between CDN-111 and 46 ieme (LAC) is 13.228788 km
# Distance between CDN-111 and Angrignon (LAS) is 5.468237 km
# Distance between CDN-111 and Armand-Chaput (RDP) is 28.271107 km
# Distance between CDN-111 and Autoroute 13 (PRF) is 17.937484 km
# Distance between CDN-111 and Ch̢teau Pierrefonds (PRF) is 28.463551 km
# Distance between CDN-111 and Lafarge (sud) (MHM) is 22.332682000000002 km
# Distance between CDN-111 and Langelier (SLE) is 20.47685 km
# Distance between CDN-111 and Newman (S-O) is 6.9767 km
# Distance between CDN-111 and Ray-Lawson (ANJ) is 22.88841 km
# Distance between CDN-111 and Sartelon (SLA) is 13.190531 km
# Distance between CDN-111 and Thimens (SLA) is 11.210956 km
# Distance between CDN-112 and St-Michel - Charland (VSP) is 15.367493 km
# Distance between CDN-112 and St-Michel - Robert (VSP) is 13.919838 km
# Distance between CDN-112 and St-Michel-17i̬me(Sous-Sol) is 14.499272000000001 km
# Distance between CDN-112 and Butler (S-O) is 7.38313 km
# Distance between CDN-112 and De la Salle (MHM) is 14.409891 km
# Distance between CDN-112 and Fullum (VMA) is 11.378836 km
# Distance between CDN-112 and Iberville (PMR) is 13.161762000000001 km
# Distance between CDN-112 and Jules-Poitras 1 (AHU) is 10.103468000000001 km
# Distance between CDN-112 and Jules-Poitras 2 (SLA) is 9.938756999999999 km
# Distance between CDN-112 and Lausanne (MTN) is 15.685127 km
# Distance between CDN-112 and Millen (AHU) is 12.341336 km
# Distance between CDN-112 and Riverside (VMA) is 9.546028 km
# Distance between CDN-112 and Saint-Pierre (LAC) is 5.412845 km
# Distance between CDN-112 and Sauv̩ (AHU) is 11.19074 km
# Distance between CDN-112 and Verdun (VER) is 7.646584 km
# Distance between CDN-112 and 46 ieme (LAC) is 12.671768 km
# Distance between CDN-112 and Angrignon (LAS) is 8.061914 km
# Distance between CDN-112 and Armand-Chaput (RDP) is 26.357438 km
# Distance between CDN-112 and Autoroute 13 (PRF) is 12.164879999999998 km
# Distance between CDN-112 and Ch̢teau Pierrefonds (PRF) is 25.112713 km
# Distance between CDN-112 and Lafarge (sud) (MHM) is 23.598965 km
# Distance between CDN-112 and Langelier (SLE) is 18.563184 km
# Distance between CDN-112 and Newman (S-O) is 9.570377 km
# Distance between CDN-112 and Ray-Lawson (ANJ) is 20.97474 km
# Distance between CDN-112 and Sartelon (SLA) is 11.276862 km
# Distance between CDN-112 and Thimens (SLA) is 9.297288 km
# Distance between CDN-113 and St-Michel - Charland (VSP) is 15.752861000000001 km
# Distance between CDN-113 and St-Michel - Robert (VSP) is 14.305204999999999 km
# Distance between CDN-113 and St-Michel-17i̬me(Sous-Sol) is 14.88464 km
# Distance between CDN-113 and Butler (S-O) is 7.749175 km
# Distance between CDN-113 and De la Salle (MHM) is 14.775937 km
# Distance between CDN-113 and Fullum (VMA) is 11.744881 km
# Distance between CDN-113 and Iberville (PMR) is 13.527806 km
# Distance between CDN-113 and Jules-Poitras 1 (AHU) is 10.488834 km
# Distance between CDN-113 and Jules-Poitras 2 (SLA) is 10.324124 km
# Distance between CDN-113 and Lausanne (MTN) is 16.070494 km
# Distance between CDN-113 and Millen (AHU) is 12.726702999999999 km
# Distance between CDN-113 and Riverside (VMA) is 7.475032000000001 km
# Distance between CDN-113 and Saint-Pierre (LAC) is 5.778891 km
# Distance between CDN-113 and Sauv̩ (AHU) is 11.576108 km
# Distance between CDN-113 and Verdun (VER) is 8.012629 km
# Distance between CDN-113 and 46 ieme (LAC) is 13.057135 km
# Distance between CDN-113 and Angrignon (LAS) is 8.427958 km
# Distance between CDN-113 and Armand-Chaput (RDP) is 26.742805 km
# Distance between CDN-113 and Autoroute 13 (PRF) is 12.550246 km
# Distance between CDN-113 and Ch̢teau Pierrefonds (PRF) is 25.498082 km
# Distance between CDN-113 and Lafarge (sud) (MHM) is 23.965011999999998 km
# Distance between CDN-113 and Langelier (SLE) is 18.948549 km
# Distance between CDN-113 and Newman (S-O) is 9.936422 km
# Distance between CDN-113 and Ray-Lawson (ANJ) is 21.360109 km
# Distance between CDN-113 and Sartelon (SLA) is 11.662229 km
# Distance between CDN-113 and Thimens (SLA) is 9.682655 km
# Distance between CDN-114 and St-Michel - Charland (VSP) is 13.962268 km
# Distance between CDN-114 and St-Michel - Robert (VSP) is 12.514612999999999 km
# Distance between CDN-114 and St-Michel-17i̬me(Sous-Sol) is 13.094048 km
# Distance between CDN-114 and Butler (S-O) is 9.840525 km
# Distance between CDN-114 and De la Salle (MHM) is 16.867287 km
# Distance between CDN-114 and Fullum (VMA) is 13.836232 km
# Distance between CDN-114 and Iberville (PMR) is 15.619156 km
# Distance between CDN-114 and Jules-Poitras 1 (AHU) is 8.698242 km
# Distance between CDN-114 and Jules-Poitras 2 (SLA) is 8.533531 km
# Distance between CDN-114 and Lausanne (MTN) is 14.279901 km
# Distance between CDN-114 and Millen (AHU) is 10.936111 km
# Distance between CDN-114 and Riverside (VMA) is 12.003424 km
# Distance between CDN-114 and Saint-Pierre (LAC) is 7.870241 km
# Distance between CDN-114 and Sauv̩ (AHU) is 9.785515 km
# Distance between CDN-114 and Verdun (VER) is 10.10398 km
# Distance between CDN-114 and 46 ieme (LAC) is 11.266541 km
# Distance between CDN-114 and Angrignon (LAS) is 10.519309999999999 km
# Distance between CDN-114 and Armand-Chaput (RDP) is 24.952211 km
# Distance between CDN-114 and Autoroute 13 (PRF) is 10.759654000000001 km
# Distance between CDN-114 and Ch̢teau Pierrefonds (PRF) is 23.707488 km
# Distance between CDN-114 and Lafarge (sud) (MHM) is 21.950246 km
# Distance between CDN-114 and Langelier (SLE) is 17.157958999999998 km
# Distance between CDN-114 and Newman (S-O) is 12.027773 km
# Distance between CDN-114 and Ray-Lawson (ANJ) is 19.569518 km
# Distance between CDN-114 and Sartelon (SLA) is 9.871637 km
# Distance between CDN-114 and Thimens (SLA) is 7.892062 km
# Distance between CDN-115 and St-Michel - Charland (VSP) is 13.294704 km
# Distance between CDN-115 and St-Michel - Robert (VSP) is 11.847050999999999 km
# Distance between CDN-115 and St-Michel-17i̬me(Sous-Sol) is 12.426484 km
# Distance between CDN-115 and Butler (S-O) is 10.688745999999998 km
# Distance between CDN-115 and De la Salle (MHM) is 17.715506 km
# Distance between CDN-115 and Fullum (VMA) is 14.684451999999999 km
# Distance between CDN-115 and Iberville (PMR) is 16.467377 km
# Distance between CDN-115 and Jules-Poitras 1 (AHU) is 7.084261000000001 km
# Distance between CDN-115 and Jules-Poitras 2 (SLA) is 6.541310999999999 km
# Distance between CDN-115 and Lausanne (MTN) is 13.651394 km
# Distance between CDN-115 and Millen (AHU) is 10.307602999999999 km
# Distance between CDN-115 and Riverside (VMA) is 12.851644 km
# Distance between CDN-115 and Saint-Pierre (LAC) is 8.718461 km
# Distance between CDN-115 and Sauv̩ (AHU) is 7.890156 km
# Distance between CDN-115 and Verdun (VER) is 10.952200000000001 km
# Distance between CDN-115 and 46 ieme (LAC) is 11.549106 km
# Distance between CDN-115 and Angrignon (LAS) is 11.367529000000001 km
# Distance between CDN-115 and Armand-Chaput (RDP) is 24.284648 km
# Distance between CDN-115 and Autoroute 13 (PRF) is 11.607873 km
# Distance between CDN-115 and Ch̢teau Pierrefonds (PRF) is 24.555706999999998 km
# Distance between CDN-115 and Lafarge (sud) (MHM) is 21.282684 km
# Distance between CDN-115 and Langelier (SLE) is 16.490395 km
# Distance between CDN-115 and Newman (S-O) is 12.875994 km
# Distance between CDN-115 and Ray-Lawson (ANJ) is 18.901955 km
# Distance between CDN-115 and Sartelon (SLA) is 10.136154000000001 km
# Distance between CDN-115 and Thimens (SLA) is 8.740281999999999 km
# Distance between CDN-116 and St-Michel - Charland (VSP) is 12.999562 km
# Distance between CDN-116 and St-Michel - Robert (VSP) is 11.551908 km
# Distance between CDN-116 and St-Michel-17i̬me(Sous-Sol) is 12.131342 km
# Distance between CDN-116 and Butler (S-O) is 10.393604 km
# Distance between CDN-116 and De la Salle (MHM) is 17.420365 km
# Distance between CDN-116 and Fullum (VMA) is 14.389308999999999 km
# Distance between CDN-116 and Iberville (PMR) is 16.172235 km
# Distance between CDN-116 and Jules-Poitras 1 (AHU) is 6.7891189999999995 km
# Distance between CDN-116 and Jules-Poitras 2 (SLA) is 6.246168 km
# Distance between CDN-116 and Lausanne (MTN) is 13.356251 km
# Distance between CDN-116 and Millen (AHU) is 10.012462 km
# Distance between CDN-116 and Riverside (VMA) is 12.556501 km
# Distance between CDN-116 and Saint-Pierre (LAC) is 8.423318 km
# Distance between CDN-116 and Sauv̩ (AHU) is 7.595014 km
# Distance between CDN-116 and Verdun (VER) is 10.657058000000001 km
# Distance between CDN-116 and 46 ieme (LAC) is 11.253964 km
# Distance between CDN-116 and Angrignon (LAS) is 11.072388 km
# Distance between CDN-116 and Armand-Chaput (RDP) is 23.989506000000002 km
# Distance between CDN-116 and Autoroute 13 (PRF) is 11.31273 km
# Distance between CDN-116 and Ch̢teau Pierrefonds (PRF) is 24.260565999999997 km
# Distance between CDN-116 and Lafarge (sud) (MHM) is 20.987541 km
# Distance between CDN-116 and Langelier (SLE) is 16.195252 km
# Distance between CDN-116 and Newman (S-O) is 12.580852 km
# Distance between CDN-116 and Ray-Lawson (ANJ) is 18.606812 km
# Distance between CDN-116 and Sartelon (SLA) is 9.841012000000001 km
# Distance between CDN-116 and Thimens (SLA) is 8.445139999999999 km
# Distance between CDN-301 and St-Michel - Charland (VSP) is 16.347364 km
# Distance between CDN-301 and St-Michel - Robert (VSP) is 14.899709999999999 km
# Distance between CDN-301 and St-Michel-17i̬me(Sous-Sol) is 15.479144 km
# Distance between CDN-301 and Butler (S-O) is 7.526794 km
# Distance between CDN-301 and De la Salle (MHM) is 14.553555000000001 km
# Distance between CDN-301 and Fullum (VMA) is 11.5225 km
# Distance between CDN-301 and Iberville (PMR) is 13.305425 km
# Distance between CDN-301 and Jules-Poitras 1 (AHU) is 11.083338 km
# Distance between CDN-301 and Jules-Poitras 2 (SLA) is 10.918628 km
# Distance between CDN-301 and Lausanne (MTN) is 16.664998 km
# Distance between CDN-301 and Millen (AHU) is 13.321207000000001 km
# Distance between CDN-301 and Riverside (VMA) is 9.689691999999999 km
# Distance between CDN-301 and Saint-Pierre (LAC) is 5.556509 km
# Distance between CDN-301 and Sauv̩ (AHU) is 12.170611999999998 km
# Distance between CDN-301 and Verdun (VER) is 7.790249 km
# Distance between CDN-301 and 46 ieme (LAC) is 15.966129 km
# Distance between CDN-301 and Angrignon (LAS) is 8.205578 km
# Distance between CDN-301 and Armand-Chaput (RDP) is 27.337305 km
# Distance between CDN-301 and Autoroute 13 (PRF) is 13.14475 km
# Distance between CDN-301 and Ch̢teau Pierrefonds (PRF) is 26.092584 km
# Distance between CDN-301 and Lafarge (sud) (MHM) is 23.742631000000003 km
# Distance between CDN-301 and Langelier (SLE) is 19.543055 km
# Distance between CDN-301 and Newman (S-O) is 9.714042 km
# Distance between CDN-301 and Ray-Lawson (ANJ) is 21.954613000000002 km
# Distance between CDN-301 and Sartelon (SLA) is 12.256733 km
# Distance between CDN-301 and Thimens (SLA) is 10.277159 km
# Distance between IBI-301 and St-Michel - Charland (VSP) is 40.723004 km
# Distance between IBI-301 and St-Michel - Robert (VSP) is 36.937781 km
# Distance between IBI-301 and St-Michel-17i̬me(Sous-Sol) is 37.517219 km
# Distance between IBI-301 and Butler (S-O) is 36.217031000000006 km
# Distance between IBI-301 and De la Salle (MHM) is 43.576766000000006 km
# Distance between IBI-301 and Fullum (VMA) is 40.545714999999994 km
# Distance between IBI-301 and Iberville (PMR) is 42.328637 km
# Distance between IBI-301 and Jules-Poitras 1 (AHU) is 26.732725 km
# Distance between IBI-301 and Jules-Poitras 2 (SLA) is 27.530281 km
# Distance between IBI-301 and Lausanne (MTN) is 39.475319999999996 km
# Distance between IBI-301 and Millen (AHU) is 30.422838 km
# Distance between IBI-301 and Riverside (VMA) is 38.712906000000004 km
# Distance between IBI-301 and Saint-Pierre (LAC) is 32.959633000000004 km
# Distance between IBI-301 and Sauv̩ (AHU) is 29.272243999999997 km
# Distance between IBI-301 and Verdun (VER) is 36.480487999999994 km
# Distance between IBI-301 and 46 ieme (LAC) is 23.978303 km
# Distance between IBI-301 and Angrignon (LAS) is 31.735756000000002 km
# Distance between IBI-301 and Armand-Chaput (RDP) is 54.109961000000006 km
# Distance between IBI-301 and Autoroute 13 (PRF) is 15.84259 km
# Distance between IBI-301 and Ch̢teau Pierrefonds (PRF) is 9.638986999999998 km
# Distance between IBI-301 and Lafarge (sud) (MHM) is 54.00993 km
# Distance between IBI-301 and Langelier (SLE) is 47.388487999999995 km
# Distance between IBI-301 and Newman (S-O) is 33.244218999999994 km
# Distance between IBI-301 and Ray-Lawson (ANJ) is 47.972801 km
# Distance between IBI-301 and Sartelon (SLA) is 22.276061000000002 km
# Distance between IBI-301 and Thimens (SLA) is 21.431514 km
# Distance between LAC-102 and St-Michel - Charland (VSP) is 19.687703000000003 km
# Distance between LAC-102 and St-Michel - Robert (VSP) is 18.240051 km
# Distance between LAC-102 and St-Michel-17i̬me(Sous-Sol) is 18.819484 km
# Distance between LAC-102 and Butler (S-O) is 14.111374 km
# Distance between LAC-102 and De la Salle (MHM) is 21.471111 km
# Distance between LAC-102 and Fullum (VMA) is 18.440057 km
# Distance between LAC-102 and Iberville (PMR) is 20.22298 km
# Distance between LAC-102 and Jules-Poitras 1 (AHU) is 14.057888 km
# Distance between LAC-102 and Jules-Poitras 2 (SLA) is 14.258968999999999 km
# Distance between LAC-102 and Lausanne (MTN) is 20.005338 km
# Distance between LAC-102 and Millen (AHU) is 16.661549 km
# Distance between LAC-102 and Riverside (VMA) is 16.60725 km
# Distance between LAC-102 and Saint-Pierre (LAC) is 10.853976000000001 km
# Distance between LAC-102 and Sauv̩ (AHU) is 15.510952 km
# Distance between LAC-102 and Verdun (VER) is 14.374827999999999 km
# Distance between LAC-102 and 46 ieme (LAC) is 1.738221 km
# Distance between LAC-102 and Angrignon (LAS) is 9.630098 km
# Distance between LAC-102 and Armand-Chaput (RDP) is 30.677646 km
# Distance between LAC-102 and Autoroute 13 (PRF) is 10.906324 km
# Distance between LAC-102 and Ch̢teau Pierrefonds (PRF) is 17.009891 km
# Distance between LAC-102 and Lafarge (sud) (MHM) is 30.660187999999998 km
# Distance between LAC-102 and Langelier (SLE) is 22.883395 km
# Distance between LAC-102 and Newman (S-O) is 11.138562 km
# Distance between LAC-102 and Ray-Lawson (ANJ) is 25.294953 km
# Distance between LAC-102 and Sartelon (SLA) is 12.487053 km
# Distance between LAC-102 and Thimens (SLA) is 7.504378 km
# Distance between LAC-104 and St-Michel - Charland (VSP) is 17.230641 km
# Distance between LAC-104 and St-Michel - Robert (VSP) is 15.782986999999999 km
# Distance between LAC-104 and St-Michel-17i̬me(Sous-Sol) is 16.362421 km
# Distance between LAC-104 and Butler (S-O) is 15.653629 km
# Distance between LAC-104 and De la Salle (MHM) is 22.680388999999998 km
# Distance between LAC-104 and Fullum (VMA) is 19.649335999999998 km
# Distance between LAC-104 and Iberville (PMR) is 21.432258 km
# Distance between LAC-104 and Jules-Poitras 1 (AHU) is 10.559109000000001 km
# Distance between LAC-104 and Jules-Poitras 2 (SLA) is 11.801905000000001 km
# Distance between LAC-104 and Lausanne (MTN) is 17.548275 km
# Distance between LAC-104 and Millen (AHU) is 14.204485 km
# Distance between LAC-104 and Riverside (VMA) is 17.816526999999997 km
# Distance between LAC-104 and Saint-Pierre (LAC) is 13.148965 km
# Distance between LAC-104 and Sauv̩ (AHU) is 13.053889999999999 km
# Distance between LAC-104 and Verdun (VER) is 15.917084000000001 km
# Distance between LAC-104 and 46 ieme (LAC) is 4.685883 km
# Distance between LAC-104 and Angrignon (LAS) is 11.925087 km
# Distance between LAC-104 and Armand-Chaput (RDP) is 28.220582 km
# Distance between LAC-104 and Autoroute 13 (PRF) is 8.292947 km
# Distance between LAC-104 and Ch̢teau Pierrefonds (PRF) is 21.420445 km
# Distance between LAC-104 and Lafarge (sud) (MHM) is 25.218621 km
# Distance between LAC-104 and Langelier (SLE) is 20.426332 km
# Distance between LAC-104 and Newman (S-O) is 13.433551 km
# Distance between LAC-104 and Ray-Lawson (ANJ) is 22.837891 km
# Distance between LAC-104 and Sartelon (SLA) is 8.318624 km
# Distance between LAC-104 and Thimens (SLA) is 5.243611 km
# Distance between LAC-305 and St-Michel - Charland (VSP) is 30.132866999999997 km
# Distance between LAC-305 and St-Michel - Robert (VSP) is 17.674566 km
# Distance between LAC-305 and St-Michel-17i̬me(Sous-Sol) is 18.254002 km
# Distance between LAC-305 and Butler (S-O) is 17.525416 km
# Distance between LAC-305 and De la Salle (MHM) is 24.885154 km
# Distance between LAC-305 and Fullum (VMA) is 21.8541 km
# Distance between LAC-305 and Iberville (PMR) is 23.637025 km
# Distance between LAC-305 and Jules-Poitras 1 (AHU) is 11.191282 km
# Distance between LAC-305 and Jules-Poitras 2 (SLA) is 11.988837 km
# Distance between LAC-305 and Lausanne (MTN) is 28.885182 km
# Distance between LAC-305 and Millen (AHU) is 14.881396 km
# Distance between LAC-305 and Riverside (VMA) is 20.021291 km
# Distance between LAC-305 and Saint-Pierre (LAC) is 14.268019 km
# Distance between LAC-305 and Sauv̩ (AHU) is 13.730801999999999 km
# Distance between LAC-305 and Verdun (VER) is 17.788869 km
# Distance between LAC-305 and 46 ieme (LAC) is 4.912329 km
# Distance between LAC-305 and Angrignon (LAS) is 13.044141 km
# Distance between LAC-305 and Armand-Chaput (RDP) is 43.519824 km
# Distance between LAC-305 and Autoroute 13 (PRF) is 5.1538900000000005 km
# Distance between LAC-305 and Ch̢teau Pierrefonds (PRF) is 18.281387 km
# Distance between LAC-305 and Lafarge (sud) (MHM) is 43.419793 km
# Distance between LAC-305 and Langelier (SLE) is 36.798352 km
# Distance between LAC-305 and Newman (S-O) is 14.552603999999999 km
# Distance between LAC-305 and Ray-Lawson (ANJ) is 37.382667999999995 km
# Distance between LAC-305 and Sartelon (SLA) is 6.734618 km
# Distance between LAC-305 and Thimens (SLA) is 5.151369 km
# Distance between LAC-306 and St-Michel - Charland (VSP) is 20.337898000000003 km
# Distance between LAC-306 and St-Michel - Robert (VSP) is 18.890245999999998 km
# Distance between LAC-306 and St-Michel-17i̬me(Sous-Sol) is 19.46968 km
# Distance between LAC-306 and Butler (S-O) is 13.899808 km
# Distance between LAC-306 and De la Salle (MHM) is 21.259545 km
# Distance between LAC-306 and Fullum (VMA) is 18.228488000000002 km
# Distance between LAC-306 and Iberville (PMR) is 20.011416 km
# Distance between LAC-306 and Jules-Poitras 1 (AHU) is 16.067169 km
# Distance between LAC-306 and Jules-Poitras 2 (SLA) is 14.909162 km
# Distance between LAC-306 and Lausanne (MTN) is 32.941668 km
# Distance between LAC-306 and Millen (AHU) is 17.311742 km
# Distance between LAC-306 and Riverside (VMA) is 16.395682 km
# Distance between LAC-306 and Saint-Pierre (LAC) is 10.642408999999999 km
# Distance between LAC-306 and Sauv̩ (AHU) is 16.161148 km
# Distance between LAC-306 and Verdun (VER) is 14.163263 km
# Distance between LAC-306 and 46 ieme (LAC) is 4.447362 km
# Distance between LAC-306 and Angrignon (LAS) is 9.41853 km
# Distance between LAC-306 and Armand-Chaput (RDP) is 31.327842 km
# Distance between LAC-306 and Autoroute 13 (PRF) is 9.210377000000001 km
# Distance between LAC-306 and Ch̢teau Pierrefonds (PRF) is 19.682125 km
# Distance between LAC-306 and Lafarge (sud) (MHM) is 28.325881000000003 km
# Distance between LAC-306 and Langelier (SLE) is 23.53359 km
# Distance between LAC-306 and Newman (S-O) is 10.926994 km
# Distance between LAC-306 and Ray-Lawson (ANJ) is 41.439152 km
# Distance between LAC-306 and Sartelon (SLA) is 10.791105 km
# Distance between LAC-306 and Thimens (SLA) is 9.207856 km
# Distance between LAS-321 and St-Michel - Charland (VSP) is 23.858768 km
# Distance between LAS-321 and St-Michel - Robert (VSP) is 23.155602 km
# Distance between LAS-321 and St-Michel-17i̬me(Sous-Sol) is 22.990548999999998 km
# Distance between LAS-321 and Butler (S-O) is 5.733257 km
# Distance between LAS-321 and De la Salle (MHM) is 16.143995 km
# Distance between LAS-321 and Fullum (VMA) is 13.112938 km
# Distance between LAS-321 and Iberville (PMR) is 14.895864 km
# Distance between LAS-321 and Jules-Poitras 1 (AHU) is 18.573990000000002 km
# Distance between LAS-321 and Jules-Poitras 2 (SLA) is 18.409278999999998 km
# Distance between LAS-321 and Lausanne (MTN) is 25.335566 km
# Distance between LAS-321 and Millen (AHU) is 20.811857 km
# Distance between LAS-321 and Riverside (VMA) is 8.625741 km
# Distance between LAS-321 and Saint-Pierre (LAC) is 3.982974 km
# Distance between LAS-321 and Sauv̩ (AHU) is 19.661261999999997 km
# Distance between LAS-321 and Verdun (VER) is 5.9967120000000005 km
# Distance between LAS-321 and 46 ieme (LAC) is 13.515633 km
# Distance between LAS-321 and Angrignon (LAS) is 3.999564 km
# Distance between LAS-321 and Armand-Chaput (RDP) is 32.486125 km
# Distance between LAS-321 and Autoroute 13 (PRF) is 18.224330000000002 km
# Distance between LAS-321 and Ch̢teau Pierrefonds (PRF) is 28.750396000000002 km
# Distance between LAS-321 and Lafarge (sud) (MHM) is 25.333068 km
# Distance between LAS-321 and Langelier (SLE) is 27.010377000000002 km
# Distance between LAS-321 and Newman (S-O) is 3.562122 km
# Distance between LAS-321 and Ray-Lawson (ANJ) is 28.898535 km
# Distance between LAS-321 and Sartelon (SLA) is 19.805057 km
# Distance between LAS-321 and Thimens (SLA) is 18.221809 km
# Distance between LAS-323 and St-Michel - Charland (VSP) is 25.324977 km
# Distance between LAS-323 and St-Michel - Robert (VSP) is 24.621811 km
# Distance between LAS-323 and St-Michel-17i̬me(Sous-Sol) is 24.456756000000002 km
# Distance between LAS-323 and Butler (S-O) is 7.199465 km
# Distance between LAS-323 and De la Salle (MHM) is 17.610203000000002 km
# Distance between LAS-323 and Fullum (VMA) is 14.579147 km
# Distance between LAS-323 and Iberville (PMR) is 16.362072 km
# Distance between LAS-323 and Jules-Poitras 1 (AHU) is 24.118261999999998 km
# Distance between LAS-323 and Jules-Poitras 2 (SLA) is 22.960254 km
# Distance between LAS-323 and Lausanne (MTN) is 40.992762 km
# Distance between LAS-323 and Millen (AHU) is 25.362834 km
# Distance between LAS-323 and Riverside (VMA) is 10.091949000000001 km
# Distance between LAS-323 and Saint-Pierre (LAC) is 5.32383 km
# Distance between LAS-323 and Sauv̩ (AHU) is 24.21224 km
# Distance between LAS-323 and Verdun (VER) is 7.46292 km
# Distance between LAS-323 and 46 ieme (LAC) is 12.552772000000001 km
# Distance between LAS-323 and Angrignon (LAS) is 5.016519000000001 km
# Distance between LAS-323 and Armand-Chaput (RDP) is 33.952336 km
# Distance between LAS-323 and Autoroute 13 (PRF) is 17.261469 km
# Distance between LAS-323 and Ch̢teau Pierrefonds (PRF) is 27.787537 km
# Distance between LAS-323 and Lafarge (sud) (MHM) is 26.799275 km
# Distance between LAS-323 and Langelier (SLE) is 28.476588 km
# Distance between LAS-323 and Newman (S-O) is 4.579076 km
# Distance between LAS-323 and Ray-Lawson (ANJ) is 30.364743999999998 km
# Distance between LAS-323 and Sartelon (SLA) is 18.842197 km
# Distance between LAS-323 and Thimens (SLA) is 17.258949 km
# Distance between LAS-325 and St-Michel - Charland (VSP) is 26.154314 km
# Distance between LAS-325 and St-Michel - Robert (VSP) is 24.706662 km
# Distance between LAS-325 and St-Michel-17i̬me(Sous-Sol) is 25.286094000000002 km
# Distance between LAS-325 and Butler (S-O) is 10.876578 km
# Distance between LAS-325 and De la Salle (MHM) is 18.236314 km
# Distance between LAS-325 and Fullum (VMA) is 15.205262000000001 km
# Distance between LAS-325 and Iberville (PMR) is 16.988186000000002 km
# Distance between LAS-325 and Jules-Poitras 1 (AHU) is 21.883586 km
# Distance between LAS-325 and Jules-Poitras 2 (SLA) is 20.725578000000002 km
# ...
# Distance between VMA-306 and St-Michel - Charland (VSP) is 10.745433 km
# Distance between VMA-306 and St-Michel - Robert (VSP) is 9.297778000000001 km
# Distance between VMA-306 and St-Michel-17i̬me(Sous-Sol) is 9.877212 km
# Distance between VMA-306 and Butler (S-O) is 7.372439999999999 km
# Distance between VMA-306 and De la Salle (MHM) is 5.97168 km
# Distance between VMA-306 and Fullum (VMA) is 2.940625 km
# Distance between VMA-306 and Iberville (PMR) is 2.555964 km
# Distance between VMA-306 and Jules-Poitras 1 (AHU) is 14.450336 km
# Distance between VMA-306 and Jules-Poitras 2 (SLA) is 11.422023999999999 km
# Distance between VMA-306 and Lausanne (MTN) is 12.222228999999999 km
# Distance between VMA-306 and Millen (AHU) is 9.734013999999998 km
# Distance between VMA-306 and Riverside (VMA) is 4.699408 km
# Distance between VMA-306 and Saint-Pierre (LAC) is 9.793175999999999 km
# Distance between VMA-306 and Sauv̩ (AHU) is 10.346119 km
# Distance between VMA-306 and Verdun (VER) is 8.815467 km
# Distance between VMA-306 and 46 ieme (LAC) is 20.229301 km
# Distance between VMA-306 and Angrignon (LAS) is 12.468748999999999 km
# Distance between VMA-306 and Armand-Chaput (RDP) is 18.883221000000002 km
# Distance between VMA-306 and Autoroute 13 (PRF) is 24.938 km
# Distance between VMA-306 and Ch̢teau Pierrefonds (PRF) is 35.464065999999995 km
# Distance between VMA-306 and Lafarge (sud) (MHM) is 11.730164 km
# Distance between VMA-306 and Langelier (SLE) is 13.097824000000001 km
# Distance between VMA-306 and Newman (S-O) is 11.700384 km
# Distance between VMA-306 and Ray-Lawson (ANJ) is 15.12298 km
# Distance between VMA-306 and Sartelon (SLA) is 16.193699000000002 km
# Distance between VMA-306 and Thimens (SLA) is 19.713307 km
# Distance between VMA-307 and St-Michel - Charland (VSP) is 11.364016 km
# Distance between VMA-307 and St-Michel - Robert (VSP) is 9.916361 km
# Distance between VMA-307 and St-Michel-17i̬me(Sous-Sol) is 10.495795 km
# Distance between VMA-307 and Butler (S-O) is 7.168719 km
# Distance between VMA-307 and De la Salle (MHM) is 5.819286 km
# Distance between VMA-307 and Fullum (VMA) is 2.788231 km
# Distance between VMA-307 and Iberville (PMR) is 3.1745479999999997 km
# Distance between VMA-307 and Jules-Poitras 1 (AHU) is 14.871993 km
# Distance between VMA-307 and Jules-Poitras 2 (SLA) is 11.843682000000001 km
# Distance between VMA-307 and Lausanne (MTN) is 12.840812 km
# Distance between VMA-307 and Millen (AHU) is 10.155671 km
# Distance between VMA-307 and Riverside (VMA) is 4.495686 km
# Distance between VMA-307 and Saint-Pierre (LAC) is 9.589454 km
# Distance between VMA-307 and Sauv̩ (AHU) is 10.731242 km
# Distance between VMA-307 and Verdun (VER) is 8.611745999999998 km
# Distance between VMA-307 and 46 ieme (LAC) is 20.02558 km
# Distance between VMA-307 and Angrignon (LAS) is 12.265028000000001 km
# Distance between VMA-307 and Armand-Chaput (RDP) is 19.501805 km
# Distance between VMA-307 and Autoroute 13 (PRF) is 24.734277 km
# Distance between VMA-307 and Ch̢teau Pierrefonds (PRF) is 35.26034 km
# Distance between VMA-307 and Lafarge (sud) (MHM) is 12.348747999999999 km
# Distance between VMA-307 and Langelier (SLE) is 13.716408 km
# Distance between VMA-307 and Newman (S-O) is 11.496663 km
# Distance between VMA-307 and Ray-Lawson (ANJ) is 15.741563 km
# Distance between VMA-307 and Sartelon (SLA) is 26.315004000000002 km
# Distance between VMA-307 and Thimens (SLA) is 19.509586 km
# Distance between VSP-103 and St-Michel - Charland (VSP) is 6.3431750000000005 km
# Distance between VSP-103 and St-Michel - Robert (VSP) is 4.895521 km
# Distance between VSP-103 and St-Michel-17i̬me(Sous-Sol) is 5.474955 km
# Distance between VSP-103 and Butler (S-O) is 17.788227 km
# Distance between VSP-103 and De la Salle (MHM) is 10.350738 km
# Distance between VSP-103 and Fullum (VMA) is 8.965202999999999 km
# Distance between VSP-103 and Iberville (PMR) is 7.679383 km
# Distance between VSP-103 and Jules-Poitras 1 (AHU) is 9.652223 km
# Distance between VSP-103 and Jules-Poitras 2 (SLA) is 6.8632219999999995 km
# Distance between VSP-103 and Lausanne (MTN) is 7.297469 km
# Distance between VSP-103 and Millen (AHU) is 3.7575 km
# Distance between VSP-103 and Riverside (VMA) is 13.637848 km
# Distance between VSP-103 and Saint-Pierre (LAC) is 15.817941999999999 km
# Distance between VSP-103 and Sauv̩ (AHU) is 4.981299 km
# Distance between VSP-103 and Verdun (VER) is 18.051682 km
# Distance between VSP-103 and 46 ieme (LAC) is 16.301319 km
# Distance between VSP-103 and Angrignon (LAS) is 18.46701 km
# Distance between VSP-103 and Armand-Chaput (RDP) is 17.333119 km
# Distance between VSP-103 and Autoroute 13 (PRF) is 15.794433000000001 km
# Distance between VSP-103 and Ch̢teau Pierrefonds (PRF) is 28.742266 km
# Distance between VSP-103 and Lafarge (sud) (MHM) is 14.331154 km
# Distance between VSP-103 and Langelier (SLE) is 9.538865 km
# Distance between VSP-103 and Newman (S-O) is 19.975475 km
# Distance between VSP-103 and Ray-Lawson (ANJ) is 11.950424000000002 km
# Distance between VSP-103 and Sartelon (SLA) is 11.634896000000001 km
# Distance between VSP-103 and Thimens (SLA) is 12.92684 km
# Distance between VSP-104 and St-Michel - Charland (VSP) is 2.245922 km
# Distance between VSP-104 and St-Michel - Robert (VSP) is 4.854672 km
# Distance between VSP-104 and St-Michel-17i̬me(Sous-Sol) is 3.092189 km
# Distance between VSP-104 and Butler (S-O) is 19.522457 km
# Distance between VSP-104 and De la Salle (MHM) is 11.187972 km
# Distance between VSP-104 and Fullum (VMA) is 10.019787 km
# Distance between VSP-104 and Iberville (PMR) is 8.802506 km
# Distance between VSP-104 and Jules-Poitras 1 (AHU) is 7.710612 km
# Distance between VSP-104 and Jules-Poitras 2 (SLA) is 6.33654 km
# Distance between VSP-104 and Lausanne (MTN) is 3.358806 km
# Distance between VSP-104 and Millen (AHU) is 2.817987 km
# Distance between VSP-104 and Riverside (VMA) is 13.556719 km
# Distance between VSP-104 and Saint-Pierre (LAC) is 17.552172 km
# Distance between VSP-104 and Sauv̩ (AHU) is 4.167451 km
# Distance between VSP-104 and Verdun (VER) is 19.785912 km
# Distance between VSP-104 and 46 ieme (LAC) is 18.035549 km
# Distance between VSP-104 and Angrignon (LAS) is 20.201240000000002 km
# Distance between VSP-104 and Armand-Chaput (RDP) is 16.692451000000002 km
# Distance between VSP-104 and Autoroute 13 (PRF) is 25.024832 km
# Distance between VSP-104 and Ch̢teau Pierrefonds (PRF) is 30.476498 km
# Distance between VSP-104 and Lafarge (sud) (MHM) is 15.470013000000002 km
# Distance between VSP-104 and Langelier (SLE) is 6.650604 km
# Distance between VSP-104 and Newman (S-O) is 21.709705000000003 km
# Distance between VSP-104 and Ray-Lawson (ANJ) is 10.555290999999999 km
# Distance between VSP-104 and Sartelon (SLA) is 11.108215 km
# Distance between VSP-104 and Thimens (SLA) is 14.661071 km
# Distance between VSP-107 and St-Michel - Charland (VSP) is 4.37234 km
# Distance between VSP-107 and St-Michel - Robert (VSP) is 2.9246849999999998 km
# Distance between VSP-107 and St-Michel-17i̬me(Sous-Sol) is 3.504119 km
# Distance between VSP-107 and Butler (S-O) is 17.53268 km
# Distance between VSP-107 and De la Salle (MHM) is 8.451165000000001 km
# Distance between VSP-107 and Fullum (VMA) is 7.819063 km
# Distance between VSP-107 and Iberville (PMR) is 6.065698 km
# Distance between VSP-107 and Jules-Poitras 1 (AHU) is 10.450130999999999 km
# Distance between VSP-107 and Jules-Poitras 2 (SLA) is 7.66113 km
# Distance between VSP-107 and Lausanne (MTN) is 5.911692 km
# Distance between VSP-107 and Millen (AHU) is 4.5565240000000005 km
# Distance between VSP-107 and Riverside (VMA) is 11.355996999999999 km
# Distance between VSP-107 and Saint-Pierre (LAC) is 15.562396000000001 km
# Distance between VSP-107 and Sauv̩ (AHU) is 5.829838 km
# Distance between VSP-107 and Verdun (VER) is 17.796135 km
# Distance between VSP-107 and 46 ieme (LAC) is 16.045772 km
# Distance between VSP-107 and Angrignon (LAS) is 18.211465 km
# Distance between VSP-107 and Armand-Chaput (RDP) is 15.735168999999999 km
# Distance between VSP-107 and Autoroute 13 (PRF) is 15.538885 km
# Distance between VSP-107 and Ch̢teau Pierrefonds (PRF) is 28.486719 km
# Distance between VSP-107 and Lafarge (sud) (MHM) is 12.733206000000001 km
# Distance between VSP-107 and Langelier (SLE) is 7.9409160000000005 km
# Distance between VSP-107 and Newman (S-O) is 19.71993 km
# Distance between VSP-107 and Ray-Lawson (ANJ) is 10.352476000000001 km
# Distance between VSP-107 and Sartelon (SLA) is 12.432805 km
# Distance between VSP-107 and Thimens (SLA) is 12.671293 km
# Distance between VSP-108 and St-Michel - Charland (VSP) is 7.5818 km
# Distance between VSP-108 and St-Michel - Robert (VSP) is 6.134145999999999 km
# Distance between VSP-108 and St-Michel-17i̬me(Sous-Sol) is 6.713578999999999 km
# Distance between VSP-108 and Butler (S-O) is 19.026851999999998 km
# Distance between VSP-108 and De la Salle (MHM) is 11.297339 km
# Distance between VSP-108 and Fullum (VMA) is 10.203828999999999 km
# Distance between VSP-108 and Iberville (PMR) is 8.918007 km
# Distance between VSP-108 and Jules-Poitras 1 (AHU) is 10.890848 km
# Distance between VSP-108 and Jules-Poitras 2 (SLA) is 8.101848 km
# Distance between VSP-108 and Lausanne (MTN) is 8.536093000000001 km
# Distance between VSP-108 and Millen (AHU) is 4.996124 km
# Distance between VSP-108 and Riverside (VMA) is 14.876473 km
# Distance between VSP-108 and Saint-Pierre (LAC) is 17.056566 km
# Distance between VSP-108 and Sauv̩ (AHU) is 6.219924 km
# Distance between VSP-108 and Verdun (VER) is 19.290307000000002 km
# Distance between VSP-108 and 46 ieme (LAC) is 17.539943 km
# Distance between VSP-108 and Angrignon (LAS) is 19.705634999999997 km
# Distance between VSP-108 and Armand-Chaput (RDP) is 18.571741999999997 km
# Distance between VSP-108 and Autoroute 13 (PRF) is 17.033057 km
# Distance between VSP-108 and Ch̢teau Pierrefonds (PRF) is 29.980893000000002 km
# Distance between VSP-108 and Lafarge (sud) (MHM) is 15.569778 km
# Distance between VSP-108 and Langelier (SLE) is 10.777489 km
# Distance between VSP-108 and Newman (S-O) is 21.2141 km
# Distance between VSP-108 and Ray-Lawson (ANJ) is 13.189048000000001 km
# Distance between VSP-108 and Sartelon (SLA) is 12.873521 km
# Distance between VSP-108 and Thimens (SLA) is 14.165465 km
# Distance between VSP-109 and St-Michel - Charland (VSP) is 8.545598 km
# Distance between VSP-109 and St-Michel - Robert (VSP) is 7.097943 km
# Distance between VSP-109 and St-Michel-17i̬me(Sous-Sol) is 7.677377000000001 km
# Distance between VSP-109 and Butler (S-O) is 14.826593 km
# Distance between VSP-109 and De la Salle (MHM) is 12.553161 km
# Distance between VSP-109 and Fullum (VMA) is 18.822298999999997 km
# Distance between VSP-109 and Iberville (PMR) is 9.881806000000001 km
# Distance between VSP-109 and Jules-Poitras 1 (AHU) is 7.732667999999999 km
# Distance between VSP-109 and Jules-Poitras 2 (SLA) is 4.943668 km
# Distance between VSP-109 and Lausanne (MTN) is 7.417542 km
# Distance between VSP-109 and Millen (AHU) is 4.07375 km
# Distance between VSP-109 and Riverside (VMA) is 16.98949 km
# Distance between VSP-109 and Saint-Pierre (LAC) is 12.856308 km
# Distance between VSP-109 and Sauv̩ (AHU) is 3.1227579999999997 km
# Distance between VSP-109 and Verdun (VER) is 15.090047 km
# Distance between VSP-109 and 46 ieme (LAC) is 13.339685 km
# Distance between VSP-109 and Angrignon (LAS) is 15.505376 km
# Distance between VSP-109 and Armand-Chaput (RDP) is 19.535541000000002 km
# Distance between VSP-109 and Autoroute 13 (PRF) is 12.832797000000001 km
# Distance between VSP-109 and Ch̢teau Pierrefonds (PRF) is 25.780633 km
# Distance between VSP-109 and Lafarge (sud) (MHM) is 16.533576 km
# Distance between VSP-109 and Langelier (SLE) is 11.741287 km
# Distance between VSP-109 and Newman (S-O) is 17.013840000000002 km
# Distance between VSP-109 and Ray-Lawson (ANJ) is 14.152848 km
# Distance between VSP-109 and Sartelon (SLA) is 9.715343 km
# Distance between VSP-109 and Thimens (SLA) is 9.965205 km
# Distance between VSP-205 and St-Michel - Charland (VSP) is 0.42172699999999996 km
# Distance between VSP-205 and St-Michel - Robert (VSP) is 3.030478 km
# Distance between VSP-205 and St-Michel-17i̬me(Sous-Sol) is 1.325681 km
# Distance between VSP-205 and Butler (S-O) is 20.6035 km
# Distance between VSP-205 and De la Salle (MHM) is 10.131112 km
# Distance between VSP-205 and Fullum (VMA) is 11.000958 km
# Distance between VSP-205 and Iberville (PMR) is 8.966751 km
# Distance between VSP-205 and Jules-Poitras 1 (AHU) is 9.697372 km
# Distance between VSP-205 and Jules-Poitras 2 (SLA) is 8.323300999999999 km
# Distance between VSP-205 and Lausanne (MTN) is 1.932957 km
# Distance between VSP-205 and Millen (AHU) is 4.804747 km
# Distance between VSP-205 and Riverside (VMA) is 14.516665000000001 km
# Distance between VSP-205 and Saint-Pierre (LAC) is 18.633217000000002 km
# Distance between VSP-205 and Sauv̩ (AHU) is 7.3072740000000005 km
# Distance between VSP-205 and Verdun (VER) is 20.866955 km
# Distance between VSP-205 and 46 ieme (LAC) is 19.116592 km
# Distance between VSP-205 and Angrignon (LAS) is 21.282283 km
# Distance between VSP-205 and Armand-Chaput (RDP) is 14.080448 km
# Distance between VSP-205 and Autoroute 13 (PRF) is 26.449150000000003 km
# Distance between VSP-205 and Ch̢teau Pierrefonds (PRF) is 31.557539000000002 km
# Distance between VSP-205 and Lafarge (sud) (MHM) is 14.362802 km
# Distance between VSP-205 and Langelier (SLE) is 4.826409 km
# Distance between VSP-205 and Newman (S-O) is 22.790748 km
# Distance between VSP-205 and Ray-Lawson (ANJ) is 7.943288 km
# Distance between VSP-205 and Sartelon (SLA) is 13.094975 km
# Distance between VSP-205 and Thimens (SLA) is 15.742113999999999 km
# Distance between VSP-206 and St-Michel - Charland (VSP) is 3.654585 km
# Distance between VSP-206 and St-Michel - Robert (VSP) is 2.206931 km
# Distance between VSP-206 and St-Michel-17i̬me(Sous-Sol) is 2.786365 km
# Distance between VSP-206 and Butler (S-O) is 18.296125 km
# Distance between VSP-206 and De la Salle (MHM) is 7.370124 km
# Distance between VSP-206 and Fullum (VMA) is 7.55075 km
# Distance between VSP-206 and Iberville (PMR) is 5.5165429999999995 km
# Distance between VSP-206 and Jules-Poitras 1 (AHU) is 11.213576 km
# Distance between VSP-206 and Jules-Poitras 2 (SLA) is 8.424575999999998 km
# Distance between VSP-206 and Lausanne (MTN) is 5.131381 km
# Distance between VSP-206 and Millen (AHU) is 5.319433 km
# Distance between VSP-206 and Riverside (VMA) is 11.475007999999999 km
# Distance between VSP-206 and Saint-Pierre (LAC) is 16.325842 km
# Distance between VSP-206 and Sauv̩ (AHU) is 6.593284 km
# Distance between VSP-206 and Verdun (VER) is 15.591068 km
# Distance between VSP-206 and 46 ieme (LAC) is 16.809219000000002 km
# Distance between VSP-206 and Angrignon (LAS) is 18.97491 km
# Distance between VSP-206 and Armand-Chaput (RDP) is 14.654129000000001 km
# Distance between VSP-206 and Autoroute 13 (PRF) is 16.30233 km
# Distance between VSP-206 and Ch̢teau Pierrefonds (PRF) is 29.250164 km
# Distance between VSP-206 and Lafarge (sud) (MHM) is 11.652164 km
# Distance between VSP-206 and Langelier (SLE) is 6.859875 km
# Distance between VSP-206 and Newman (S-O) is 20.483373 km
# Distance between VSP-206 and Ray-Lawson (ANJ) is 9.271434 km
# Distance between VSP-206 and Sartelon (SLA) is 13.196251 km
# Distance between VSP-206 and Thimens (SLA) is 13.434738 km
#      Removal Site                Disposal Site   Distance
# 0         AHU-101   St-Michel - Charland (VSP)  10.195564
# 1         AHU-101     St-Michel - Robert (VSP)  13.140525
# 2         AHU-101  St-Michel-17i̬me(Sous-Sol)  11.041832
# 3         AHU-101                 Butler (S-O)  18.758260
# 4         AHU-101            De la Salle (MHM)  18.303719
# ...           ...                          ...        ...
# 2751      VSP-206              Langelier (SLE)   6.859875
# 2752      VSP-206                 Newman (S-O)  20.483373
# 2753      VSP-206             Ray-Lawson (ANJ)   9.271434
# 2754      VSP-206               Sartelon (SLA)  13.196251
# 2755      VSP-206                Thimens (SLA)  13.434738
#
# [2756 rows x 3 columns]

# %%
#swapping start and end locations
for i in range(len(removal_sites_longitudes)):
        for j in range(len(disposal_sites_longitudes)):
                end_location = f"{removal_sites_longitudes[i]},{removal_sites_latitudes[i]}"
                end_name=df_removal_sites['NomSecteur'][i]

                start_location = f"{disposal_sites_longitudes[j]},{disposal_sites_latitudes[j]}" 
                start_name=df_disposal_sites['NomDepot'][j]  

                distance=main(start_location, end_location, mapbox_token)
                print(f"Distance between {start_name} and {end_name} is {distance} km")
                new_row = {'Disposal Site': start_name, 'Removal Site': end_name, 'Distance': distance}
                new_row_df = pd.DataFrame([new_row])
                final_df = pd.concat([final_df, new_row_df], ignore_index=True)


# start_location = f"{removal_sites_longitudes[0]},{removal_sites_latitudes[0]}"
# end_location = f"{disposal_sites_longitudes[0]},{disposal_sites_latitudes[0]}"    
# print(main(start_location, end_location, mapbox_token))
print(final_df)
final_df.to_excel('Distance_output.xlsx',index=False)
# Out:
# Distance between St-Michel - Charland (VSP) and AHU-101 is 10.224407 km
# Distance between St-Michel - Robert (VSP) and AHU-101 is 12.989324 km
# Distance between St-Michel-17i̬me(Sous-Sol) and AHU-101 is 11.075102999999999 km
# Distance between Butler (S-O) and AHU-101 is 20.729691 km
# Distance between De la Salle (MHM) and AHU-101 is 18.818641 km
# Distance between Fullum (VMA) and AHU-101 is 23.863721 km
# Distance between Iberville (PMR) and AHU-101 is 16.375431 km
# Distance between Jules-Poitras 1 (AHU) and AHU-101 is 3.020478 km
# Distance between Jules-Poitras 2 (SLA) and AHU-101 is 3.8663879999999997 km
# Distance between Lausanne (MTN) and AHU-101 is 8.83079 km
# Distance between Millen (AHU) and AHU-101 is 3.773251 km
# Distance between Riverside (VMA) and AHU-101 is 22.421117 km
# Distance between Saint-Pierre (LAC) and AHU-101 is 16.870169999999998 km
# Distance between Sauv̩ (AHU) and AHU-101 is 4.078887 km
# Distance between Verdun (VER) and AHU-101 is 21.34757 km
# Distance between 46 ieme (LAC) and AHU-101 is 16.884434000000002 km
# Distance between Angrignon (LAS) and AHU-101 is 24.737574000000002 km
# Distance between Armand-Chaput (RDP) and AHU-101 is 25.779039 km
# Distance between Autoroute 13 (PRF) and AHU-101 is 10.066711 km
# Distance between Ch̢teau Pierrefonds (PRF) and AHU-101 is 22.803678 km
# Distance between Lafarge (sud) (MHM) and AHU-101 is 25.690578000000002 km
# Distance between Langelier (SLE) and AHU-101 is 14.179803 km
# Distance between Newman (S-O) and AHU-101 is 19.138898 km
# Distance between Ray-Lawson (ANJ) and AHU-101 is 20.171342 km
# Distance between Sartelon (SLA) and AHU-101 is 6.565605 km
# Distance between Thimens (SLA) and AHU-101 is 7.941164 km
# Distance between St-Michel - Charland (VSP) and AHU-102 is 9.911377 km
# Distance between St-Michel - Robert (VSP) and AHU-102 is 12.676293 km
# Distance between St-Michel-17i̬me(Sous-Sol) and AHU-102 is 10.762073000000001 km
# Distance between Butler (S-O) and AHU-102 is 20.41666 km
# Distance between De la Salle (MHM) and AHU-102 is 18.505609 km
# Distance between Fullum (VMA) and AHU-102 is 23.550689 km
# Distance between Iberville (PMR) and AHU-102 is 16.130421000000002 km
# Distance between Jules-Poitras 1 (AHU) and AHU-102 is 2.707448 km
# Distance between Jules-Poitras 2 (SLA) and AHU-102 is 3.728085 km
# Distance between Lausanne (MTN) and AHU-102 is 8.51776 km
# Distance between Millen (AHU) and AHU-102 is 3.41844 km
# Distance between Riverside (VMA) and AHU-102 is 22.108088 km
# Distance between Saint-Pierre (LAC) and AHU-102 is 16.557143 km
# Distance between Sauv̩ (AHU) and AHU-102 is 3.765857 km
# Distance between Verdun (VER) and AHU-102 is 21.034541 km
# Distance between 46 ieme (LAC) and AHU-102 is 16.571403999999998 km
# Distance between Angrignon (LAS) and AHU-102 is 24.424545 km
# Distance between Armand-Chaput (RDP) and AHU-102 is 25.466009999999997 km
# Distance between Autoroute 13 (PRF) and AHU-102 is 9.928406 km
# Distance between Ch̢teau Pierrefonds (PRF) and AHU-102 is 22.770906 km
# Distance between Lafarge (sud) (MHM) and AHU-102 is 25.377551 km
# Distance between Langelier (SLE) and AHU-102 is 13.866772000000001 km
# Distance between Newman (S-O) and AHU-102 is 18.825868999999997 km
# Distance between Ray-Lawson (ANJ) and AHU-102 is 19.858311 km
# Distance between Sartelon (SLA) and AHU-102 is 6.427302 km
# Distance between Thimens (SLA) and AHU-102 is 7.908390000000001 km
# Distance between St-Michel - Charland (VSP) and AHU-103 is 10.224407 km
# Distance between St-Michel - Robert (VSP) and AHU-103 is 12.989324 km
# Distance between St-Michel-17i̬me(Sous-Sol) and AHU-103 is 11.075102999999999 km
# Distance between Butler (S-O) and AHU-103 is 20.729691 km
# Distance between De la Salle (MHM) and AHU-103 is 18.818641 km
# Distance between Fullum (VMA) and AHU-103 is 23.863721 km
# Distance between Iberville (PMR) and AHU-103 is 16.375431 km
# Distance between Jules-Poitras 1 (AHU) and AHU-103 is 3.020478 km
# Distance between Jules-Poitras 2 (SLA) and AHU-103 is 3.8663879999999997 km
# Distance between Lausanne (MTN) and AHU-103 is 8.83079 km
# Distance between Millen (AHU) and AHU-103 is 3.773251 km
# Distance between Riverside (VMA) and AHU-103 is 22.421117 km
# Distance between Saint-Pierre (LAC) and AHU-103 is 16.870169999999998 km
# Distance between Sauv̩ (AHU) and AHU-103 is 4.078887 km
# Distance between Verdun (VER) and AHU-103 is 21.34757 km
# Distance between 46 ieme (LAC) and AHU-103 is 16.884434000000002 km
# Distance between Angrignon (LAS) and AHU-103 is 24.737574000000002 km
# Distance between Armand-Chaput (RDP) and AHU-103 is 25.779039 km
# Distance between Autoroute 13 (PRF) and AHU-103 is 10.066711 km
# Distance between Ch̢teau Pierrefonds (PRF) and AHU-103 is 22.803678 km
# Distance between Lafarge (sud) (MHM) and AHU-103 is 25.690578000000002 km
# Distance between Langelier (SLE) and AHU-103 is 14.179803 km
# Distance between Newman (S-O) and AHU-103 is 19.138898 km
# Distance between Ray-Lawson (ANJ) and AHU-103 is 20.171342 km
# Distance between Sartelon (SLA) and AHU-103 is 6.565605 km
# Distance between Thimens (SLA) and AHU-103 is 7.941164 km
# Distance between St-Michel - Charland (VSP) and AHU-104 is 7.981301 km
# Distance between St-Michel - Robert (VSP) and AHU-104 is 12.670596 km
# Distance between St-Michel-17i̬me(Sous-Sol) and AHU-104 is 8.831998 km
# Distance between Butler (S-O) and AHU-104 is 20.410965 km
# Distance between De la Salle (MHM) and AHU-104 is 18.49991 km
# Distance between Fullum (VMA) and AHU-104 is 23.544991999999997 km
# Distance between Iberville (PMR) and AHU-104 is 16.056703 km
# Distance between Jules-Poitras 1 (AHU) and AHU-104 is 2.70175 km
# Distance between Jules-Poitras 2 (SLA) and AHU-104 is 3.827917 km
# Distance between Lausanne (MTN) and AHU-104 is 6.587683 km
# Distance between Millen (AHU) and AHU-104 is 2.50474 km
# Distance between Riverside (VMA) and AHU-104 is 22.102389 km
# Distance between Saint-Pierre (LAC) and AHU-104 is 16.551443 km
# Distance between Sauv̩ (AHU) and AHU-104 is 3.76016 km
# Distance between Verdun (VER) and AHU-104 is 21.028844 km
# Distance between 46 ieme (LAC) and AHU-104 is 16.565707 km
# Distance between Angrignon (LAS) and AHU-104 is 24.418848 km
# Distance between Armand-Chaput (RDP) and AHU-104 is 25.460312000000002 km
# Distance between Autoroute 13 (PRF) and AHU-104 is 19.373789000000002 km
# Distance between Ch̢teau Pierrefonds (PRF) and AHU-104 is 22.765207 km
# Distance between Lafarge (sud) (MHM) and AHU-104 is 25.371854 km
# Distance between Langelier (SLE) and AHU-104 is 11.936696 km
# Distance between Newman (S-O) and AHU-104 is 18.820172 km
# Distance between Ray-Lawson (ANJ) and AHU-104 is 13.786172 km
# Distance between Sartelon (SLA) and AHU-104 is 6.527134 km
# Distance between Thimens (SLA) and AHU-104 is 7.902692 km
# Distance between St-Michel - Charland (VSP) and AHU-105 is 4.845878 km
# Distance between St-Michel - Robert (VSP) and AHU-105 is 6.99922 km
# Distance between St-Michel-17i̬me(Sous-Sol) and AHU-105 is 5.696575 km
# Distance between Butler (S-O) and AHU-105 is 18.9095 km
# Distance between De la Salle (MHM) and AHU-105 is 12.828536 km
# Distance between Fullum (VMA) and AHU-105 is 11.436188 km
# Distance between Iberville (PMR) and AHU-105 is 10.385328 km
# Distance between Jules-Poitras 1 (AHU) and AHU-105 is 4.7437309999999995 km
# Distance between Jules-Poitras 2 (SLA) and AHU-105 is 4.860934 km
# Distance between Lausanne (MTN) and AHU-105 is 6.1313509999999996 km
# Distance between Millen (AHU) and AHU-105 is 2.6107150000000003 km
# Distance between Riverside (VMA) and AHU-105 is 12.892111000000002 km
# Distance between Saint-Pierre (LAC) and AHU-105 is 15.049980999999999 km
# Distance between Sauv̩ (AHU) and AHU-105 is 2.13487 km
# Distance between Verdun (VER) and AHU-105 is 16.027412 km
# Distance between 46 ieme (LAC) and AHU-105 is 15.064243000000001 km
# Distance between Angrignon (LAS) and AHU-105 is 22.917383 km
# Distance between Armand-Chaput (RDP) and AHU-105 is 19.788936000000003 km
# Distance between Autoroute 13 (PRF) and AHU-105 is 11.126166999999999 km
# Distance between Ch̢teau Pierrefonds (PRF) and AHU-105 is 24.389074 km
# Distance between Lafarge (sud) (MHM) and AHU-105 is 19.700477 km
# Distance between Langelier (SLE) and AHU-105 is 9.489849 km
# Distance between Newman (S-O) and AHU-105 is 17.318709 km
# Distance between Ray-Lawson (ANJ) and AHU-105 is 14.181237 km
# Distance between Sartelon (SLA) and AHU-105 is 8.173112 km
# Distance between Thimens (SLA) and AHU-105 is 9.54867 km
# Distance between St-Michel - Charland (VSP) and AHU-106 is 3.8344 km
# Distance between St-Michel - Robert (VSP) and AHU-106 is 6.269482 km
# Distance between St-Michel-17i̬me(Sous-Sol) and AHU-106 is 4.685096 km
# Distance between Butler (S-O) and AHU-106 is 18.446676 km
# Distance between De la Salle (MHM) and AHU-106 is 12.667404000000001 km
# Distance between Fullum (VMA) and AHU-106 is 11.26381 km
# Distance between Iberville (PMR) and AHU-106 is 10.212948 km
# Distance between Jules-Poitras 1 (AHU) and AHU-106 is 6.938921000000001 km
# Distance between Jules-Poitras 2 (SLA) and AHU-106 is 7.096947 km
# Distance between Lausanne (MTN) and AHU-106 is 2.440782 km
# Distance between Millen (AHU) and AHU-106 is 2.306003 km
# Distance between Riverside (VMA) and AHU-106 is 17.200373 km
# Distance between Saint-Pierre (LAC) and AHU-106 is 18.191945 km
# Distance between Sauv̩ (AHU) and AHU-106 is 6.4691 km
# Distance between Verdun (VER) and AHU-106 is 19.609035 km
# Distance between 46 ieme (LAC) and AHU-106 is 18.206208999999998 km
# Distance between Angrignon (LAS) and AHU-106 is 26.059352 km
# Distance between Armand-Chaput (RDP) and AHU-106 is 15.844895000000001 km
# Distance between Autoroute 13 (PRF) and AHU-106 is 23.212957 km
# Distance between Ch̢teau Pierrefonds (PRF) and AHU-106 is 26.647199 km
# Distance between Lafarge (sud) (MHM) and AHU-106 is 19.543396 km
# Distance between Langelier (SLE) and AHU-106 is 7.789794 km
# Distance between Newman (S-O) and AHU-106 is 20.460673999999997 km
# Distance between Ray-Lawson (ANJ) and AHU-106 is 9.75544 km
# Distance between Sartelon (SLA) and AHU-106 is 10.409125 km
# Distance between Thimens (SLA) and AHU-106 is 11.784683999999999 km
# Distance between St-Michel - Charland (VSP) and AHU-107 is 3.9833760000000002 km
# Distance between St-Michel - Robert (VSP) and AHU-107 is 6.089928 km
# Distance between St-Michel-17i̬me(Sous-Sol) and AHU-107 is 4.664289 km
# Distance between Butler (S-O) and AHU-107 is 18.528855 km
# Distance between De la Salle (MHM) and AHU-107 is 11.919243 km
# Distance between Fullum (VMA) and AHU-107 is 10.526897000000002 km
# Distance between Iberville (PMR) and AHU-107 is 9.476035 km
# Distance between Jules-Poitras 1 (AHU) and AHU-107 is 6.202221 km
# Distance between Jules-Poitras 2 (SLA) and AHU-107 is 6.360246 km
# Distance between Lausanne (MTN) and AHU-107 is 5.690676000000001 km
# Distance between Millen (AHU) and AHU-107 is 2.43988 km
# Distance between Riverside (VMA) and AHU-107 is 13.034565 km
# Distance between Saint-Pierre (LAC) and AHU-107 is 14.669336 km
# Distance between Sauv̩ (AHU) and AHU-107 is 3.2982150000000003 km
# Distance between Verdun (VER) and AHU-107 is 16.169864 km
# Distance between 46 ieme (LAC) and AHU-107 is 14.683599000000001 km
# Distance between Angrignon (LAS) and AHU-107 is 22.53674 km
# Distance between Armand-Chaput (RDP) and AHU-107 is 18.879643 km
# Distance between Autoroute 13 (PRF) and AHU-107 is 12.625478999999999 km
# Distance between Ch̢teau Pierrefonds (PRF) and AHU-107 is 25.910498 km
# Distance between Lafarge (sud) (MHM) and AHU-107 is 18.791184 km
# Distance between Langelier (SLE) and AHU-107 is 8.627347 km
# Distance between Newman (S-O) and AHU-107 is 16.938063999999997 km
# Distance between Ray-Lawson (ANJ) and AHU-107 is 13.271945 km
# Distance between Sartelon (SLA) and AHU-107 is 9.672424000000001 km
# Distance between Thimens (SLA) and AHU-107 is 11.047983 km
# Distance between St-Michel - Charland (VSP) and AHU-201 is 5.403774 km
# Distance between St-Michel - Robert (VSP) and AHU-201 is 7.838857 km
# Distance between St-Michel-17i̬me(Sous-Sol) and AHU-201 is 6.254471 km
# Distance between Butler (S-O) and AHU-201 is 20.718043 km
# Distance between De la Salle (MHM) and AHU-201 is 13.475638 km
# Distance between Fullum (VMA) and AHU-201 is 12.083291 km
# Distance between Iberville (PMR) and AHU-201 is 11.03243 km
# Distance between Jules-Poitras 1 (AHU) and AHU-201 is 5.605499 km
# Distance between Jules-Poitras 2 (SLA) and AHU-201 is 5.763524 km
# Distance between Lausanne (MTN) and AHU-201 is 4.010157 km
# Distance between Millen (AHU) and AHU-201 is 0.7818099999999999 km
# Distance between Riverside (VMA) and AHU-201 is 15.282274 km
# Distance between Saint-Pierre (LAC) and AHU-201 is 16.858523 km
# Distance between Sauv̩ (AHU) and AHU-201 is 5.1356779999999995 km
# Distance between Verdun (VER) and AHU-201 is 21.335922 km
# Distance between 46 ieme (LAC) and AHU-201 is 16.872785 km
# Distance between Angrignon (LAS) and AHU-201 is 24.725928 km
# Distance between Armand-Chaput (RDP) and AHU-201 is 17.414270000000002 km
# Distance between Autoroute 13 (PRF) and AHU-201 is 12.028756999999999 km
# Distance between Ch̢teau Pierrefonds (PRF) and AHU-201 is 25.313775 km
# Distance between Lafarge (sud) (MHM) and AHU-201 is 20.347578000000002 km
# Distance between Langelier (SLE) and AHU-201 is 9.35917 km
# Distance between Newman (S-O) and AHU-201 is 19.12725 km
# Distance between Ray-Lawson (ANJ) and AHU-201 is 11.324815000000001 km
# Distance between Sartelon (SLA) and AHU-201 is 9.075702999999999 km
# Distance between Thimens (SLA) and AHU-201 is 10.451261 km
# Distance between St-Michel - Charland (VSP) and AHU-202 is 6.729191 km
# Distance between St-Michel - Robert (VSP) and AHU-202 is 9.164273 km
# Distance between St-Michel-17i̬me(Sous-Sol) and AHU-202 is 7.579886999999999 km
# Distance between Butler (S-O) and AHU-202 is 19.572902 km
# Distance between De la Salle (MHM) and AHU-202 is 14.624687 km
# Distance between Fullum (VMA) and AHU-202 is 13.23234 km
# Distance between Iberville (PMR) and AHU-202 is 12.181479 km
# Distance between Jules-Poitras 1 (AHU) and AHU-202 is 4.460359 km
# Distance between Jules-Poitras 2 (SLA) and AHU-202 is 4.618384 km
# Distance between Lausanne (MTN) and AHU-202 is 5.335573999999999 km
# Distance between Millen (AHU) and AHU-202 is 1.368801 km
# Distance between Riverside (VMA) and AHU-202 is 14.537052 km
# Distance between Saint-Pierre (LAC) and AHU-202 is 15.713383 km
# Distance between Sauv̩ (AHU) and AHU-202 is 3.990537 km
# Distance between Verdun (VER) and AHU-202 is 20.190783 km
# Distance between 46 ieme (LAC) and AHU-202 is 15.727646 km
# Distance between Angrignon (LAS) and AHU-202 is 23.580785 km
# Distance between Armand-Chaput (RDP) and AHU-202 is 18.739686000000003 km
# Distance between Autoroute 13 (PRF) and AHU-202 is 10.883616 km
# Distance between Ch̢teau Pierrefonds (PRF) and AHU-202 is 24.255469 km
# Distance between Lafarge (sud) (MHM) and AHU-202 is 21.496627 km
# Distance between Langelier (SLE) and AHU-202 is 10.684586 km
# Distance between Newman (S-O) and AHU-202 is 17.982111 km
# Distance between Ray-Lawson (ANJ) and AHU-202 is 12.650232 km
# Distance between Sartelon (SLA) and AHU-202 is 7.930562 km
# Distance between Thimens (SLA) and AHU-202 is 9.30612 km
# Distance between St-Michel - Charland (VSP) and ANJ-101 is 10.593532999999999 km
# Distance between St-Michel - Robert (VSP) and ANJ-101 is 10.412790000000001 km
# Distance between St-Michel-17i̬me(Sous-Sol) and ANJ-101 is 13.138461 km
# Distance between Butler (S-O) and ANJ-101 is 24.031226999999998 km
# Distance between De la Salle (MHM) and ANJ-101 is 14.136365 km
# Distance between Fullum (VMA) and ANJ-101 is 16.848359000000002 km
# Distance between Iberville (PMR) and ANJ-101 is 17.377508000000002 km
# Distance between Jules-Poitras 1 (AHU) and ANJ-101 is 20.923711 km
# Distance between Jules-Poitras 2 (SLA) and ANJ-101 is 20.257296999999998 km
# Distance between Lausanne (MTN) and ANJ-101 is 10.477965 km
# Distance between Millen (AHU) and ANJ-101 is 14.407530000000001 km
# Distance between Riverside (VMA) and ANJ-101 is 22.784924 km
# Distance between Saint-Pierre (LAC) and ANJ-101 is 26.516486 km
# Distance between Sauv̩ (AHU) and ANJ-101 is 17.221664 km
# Distance between Verdun (VER) and ANJ-101 is 25.920221 km
# Distance between 46 ieme (LAC) and ANJ-101 is 26.588164 km
# Distance between Angrignon (LAS) and ANJ-101 is 29.418529 km
# Distance between Armand-Chaput (RDP) and ANJ-101 is 5.9659070000000005 km
# Distance between Autoroute 13 (PRF) and ANJ-101 is 37.173961000000006 km
# Distance between Ch̢teau Pierrefonds (PRF) and ANJ-101 is 39.965593999999996 km
# Distance between Lafarge (sud) (MHM) and ANJ-101 is 6.421568000000001 km
# Distance between Langelier (SLE) and ANJ-101 is 6.881189999999999 km
# Distance between Newman (S-O) and ANJ-101 is 28.423699 km
# Distance between Ray-Lawson (ANJ) and ANJ-101 is 3.428223 km
# Distance between Sartelon (SLA) and ANJ-101 is 23.569474999999997 km
# Distance between Thimens (SLA) and ANJ-101 is 24.764619 km
# Distance between St-Michel - Charland (VSP) and ANJ-309 is 9.208938 km
# Distance between St-Michel - Robert (VSP) and ANJ-309 is 6.934279999999999 km
# Distance between St-Michel-17i̬me(Sous-Sol) and ANJ-309 is 9.660543 km
# Distance between Butler (S-O) and ANJ-309 is 19.146441 km
# Distance between De la Salle (MHM) and ANJ-309 is 9.251577 km
# Distance between Fullum (VMA) and ANJ-309 is 11.963572000000001 km
# Distance between Iberville (PMR) and ANJ-309 is 12.492721 km
# Distance between Jules-Poitras 1 (AHU) and ANJ-309 is 17.445793000000002 km
# Distance between Jules-Poitras 2 (SLA) and ANJ-309 is 16.779379000000002 km
# Distance between Lausanne (MTN) and ANJ-309 is 10.643695 km
# Distance between Millen (AHU) and ANJ-309 is 12.508889 km
# Distance between Riverside (VMA) and ANJ-309 is 17.900136999999997 km
# Distance between Saint-Pierre (LAC) and ANJ-309 is 21.631699 km
# Distance between Sauv̩ (AHU) and ANJ-309 is 13.743746 km
# Distance between Verdun (VER) and ANJ-309 is 29.382889 km
# Distance between 46 ieme (LAC) and ANJ-309 is 23.110243999999998 km
# Distance between Angrignon (LAS) and ANJ-309 is 24.53374 km
# Distance between Armand-Chaput (RDP) and ANJ-309 is 9.504704 km
# Distance between Autoroute 13 (PRF) and ANJ-309 is 35.304184 km
# Distance between Ch̢teau Pierrefonds (PRF) and ANJ-309 is 36.487676 km
# Distance between Lafarge (sud) (MHM) and ANJ-309 is 5.056184 km
# Distance between Langelier (SLE) and ANJ-309 is 5.176796 km
# Distance between Newman (S-O) and ANJ-309 is 23.53891 km
# Distance between Ray-Lawson (ANJ) and ANJ-309 is 3.454557 km
# Distance between Sartelon (SLA) and ANJ-309 is 20.091557 km
# Distance between Thimens (SLA) and ANJ-309 is 21.286701 km
# Distance between St-Michel - Charland (VSP) and ANJ-310 is 9.718471 km
# Distance between St-Michel - Robert (VSP) and ANJ-310 is 7.258309000000001 km
# Distance between St-Michel-17i̬me(Sous-Sol) and ANJ-310 is 9.983899 km
# Distance between Butler (S-O) and ANJ-310 is 17.488713 km
# Distance between De la Salle (MHM) and ANJ-310 is 7.593850000000001 km
# Distance between Fullum (VMA) and ANJ-310 is 10.305847 km
# Distance between Iberville (PMR) and ANJ-310 is 8.529736999999999 km
# Distance between Jules-Poitras 1 (AHU) and ANJ-310 is 17.76915 km
# Distance between Jules-Poitras 2 (SLA) and ANJ-310 is 17.102736 km
# Distance between Lausanne (MTN) and ANJ-310 is 11.633929 km
# Distance between Millen (AHU) and ANJ-310 is 12.832244000000001 km
# Distance between Riverside (VMA) and ANJ-310 is 16.242411 km
# Distance between Saint-Pierre (LAC) and ANJ-310 is 19.973973 km
# Distance between Sauv̩ (AHU) and ANJ-310 is 14.067102 km
# Distance between Verdun (VER) and ANJ-310 is 19.377710999999998 km
# Distance between 46 ieme (LAC) and ANJ-310 is 23.4336 km
# Distance between Angrignon (LAS) and ANJ-310 is 22.876016 km
# Distance between Armand-Chaput (RDP) and ANJ-310 is 12.297406 km
# Distance between Autoroute 13 (PRF) and ANJ-310 is 36.294413999999996 km
# Distance between Ch̢teau Pierrefonds (PRF) and ANJ-310 is 36.915711 km
# Distance between Lafarge (sud) (MHM) and ANJ-310 is 5.182542000000001 km
# Distance between Langelier (SLE) and ANJ-310 is 5.768252 km
# Distance between Newman (S-O) and ANJ-310 is 21.881182 km
# Distance between Ray-Lawson (ANJ) and ANJ-310 is 6.6897079999999995 km
# Distance between Sartelon (SLA) and ANJ-310 is 20.414914 km
# Distance between Thimens (SLA) and ANJ-310 is 21.610059 km
# Distance between St-Michel - Charland (VSP) and ANJ-311 is 7.637804 km
# Distance between St-Michel - Robert (VSP) and ANJ-311 is 5.445104000000001 km
# Distance between St-Michel-17i̬me(Sous-Sol) and ANJ-311 is 8.841857 km
# Distance between Butler (S-O) and ANJ-311 is 23.587563999999997 km
# Distance between De la Salle (MHM) and ANJ-311 is 13.692701 km
# Distance between Fullum (VMA) and ANJ-311 is 16.404697 km
# Distance between Iberville (PMR) and ANJ-311 is 10.915531999999999 km
# Distance between Jules-Poitras 1 (AHU) and ANJ-311 is 16.627107 km
# Distance between Jules-Poitras 2 (SLA) and ANJ-311 is 15.960694 km
# Distance between Lausanne (MTN) and ANJ-311 is 9.059789 km
# Distance between Millen (AHU) and ANJ-311 is 11.690203 km
# Distance between Riverside (VMA) and ANJ-311 is 22.341262 km
# Distance between Saint-Pierre (LAC) and ANJ-311 is 26.072822 km
# Distance between Sauv̩ (AHU) and ANJ-311 is 12.925062 km
# Distance between Verdun (VER) and ANJ-311 is 25.476561 km
# Distance between 46 ieme (LAC) and ANJ-311 is 22.291557 km
# Distance between Angrignon (LAS) and ANJ-311 is 28.974865 km
# Distance between Armand-Chaput (RDP) and ANJ-311 is 10.172661 km
# Distance between Autoroute 13 (PRF) and ANJ-311 is 33.733961 km
# Distance between Ch̢teau Pierrefonds (PRF) and ANJ-311 is 35.668991999999996 km
# Distance between Lafarge (sud) (MHM) and ANJ-311 is 7.195158999999999 km
# Distance between Langelier (SLE) and ANJ-311 is 3.6056619999999997 km
# Distance between Newman (S-O) and ANJ-311 is 27.980031 km
# Distance between Ray-Lawson (ANJ) and ANJ-311 is 4.316148 km
# Distance between Sartelon (SLA) and ANJ-311 is 19.272873 km
# Distance between Thimens (SLA) and ANJ-311 is 20.468018 km
# Distance between St-Michel - Charland (VSP) and ANJ-312 is 5.150087 km
# Distance between St-Michel - Robert (VSP) and ANJ-312 is 5.766832999999999 km
# Distance between St-Michel-17i̬me(Sous-Sol) and ANJ-312 is 6.878672 km
# Distance between Butler (S-O) and ANJ-312 is 23.251528999999998 km
# Distance between De la Salle (MHM) and ANJ-312 is 13.356667 km
# Distance between Fullum (VMA) and ANJ-312 is 16.068663 km
# Distance between Iberville (PMR) and ANJ-312 is 16.597811 km
# Distance between Jules-Poitras 1 (AHU) and ANJ-312 is 14.033532 km
# Distance between Jules-Poitras 2 (SLA) and ANJ-312 is 14.191557000000001 km
# Distance between Lausanne (MTN) and ANJ-312 is 5.4710469999999995 km
# Distance between Millen (AHU) and ANJ-312 is 9.400613 km
# Distance between Riverside (VMA) and ANJ-312 is 22.005226999999998 km
# Distance between Saint-Pierre (LAC) and ANJ-312 is 25.736787 km
# Distance between Sauv̩ (AHU) and ANJ-312 is 13.563709999999999 km
# Distance between Verdun (VER) and ANJ-312 is 25.140525 km
# Distance between 46 ieme (LAC) and ANJ-312 is 23.662736000000002 km
# Distance between Angrignon (LAS) and ANJ-312 is 28.638831999999997 km
# Distance between Armand-Chaput (RDP) and ANJ-312 is 8.773995000000001 km
# Distance between Autoroute 13 (PRF) and ANJ-312 is 30.705461 km
# Distance between Ch̢teau Pierrefonds (PRF) and ANJ-312 is 49.097027000000004 km
# Distance between Lafarge (sud) (MHM) and ANJ-312 is 11.964664 km
# Distance between Langelier (SLE) and ANJ-312 is 1.181211 km
# Distance between Newman (S-O) and ANJ-312 is 27.643998 km
# Distance between Ray-Lawson (ANJ) and ANJ-312 is 2.684542 km
# Distance between Sartelon (SLA) and ANJ-312 is 17.503736 km
# Distance between Thimens (SLA) and ANJ-312 is 34.358875 km
# Distance between St-Michel - Charland (VSP) and CDN-111 is 17.141072 km
# Distance between St-Michel - Robert (VSP) and CDN-111 is 15.697781 km
# Distance between St-Michel-17i̬me(Sous-Sol) and CDN-111 is 16.829531 km
# Distance between Butler (S-O) and CDN-111 is 6.569329 km
# Distance between De la Salle (MHM) and CDN-111 is 11.992465 km
# Distance between Fullum (VMA) and CDN-111 is 9.703357 km
# Distance between Iberville (PMR) and CDN-111 is 10.044998 km
# Distance between Jules-Poitras 1 (AHU) and CDN-111 is 10.856983 km
# Distance between Jules-Poitras 2 (SLA) and CDN-111 is 10.533946 km
# Distance between Lausanne (MTN) and CDN-111 is 17.716445 km
# Distance between Millen (AHU) and CDN-111 is 14.958369000000001 km
# Distance between Riverside (VMA) and CDN-111 is 8.260755 km
# Distance between Saint-Pierre (LAC) and CDN-111 is 2.848954 km
# Distance between Sauv̩ (AHU) and CDN-111 is 10.946566 km
# Distance between Verdun (VER) and CDN-111 is 7.326353 km
# Distance between 46 ieme (LAC) and CDN-111 is 13.573064 km
# Distance between Angrignon (LAS) and CDN-111 is 6.631289 km
# Distance between Armand-Chaput (RDP) and CDN-111 is 28.487496 km
# Distance between Autoroute 13 (PRF) and CDN-111 is 14.044851000000001 km
# Distance between Ch̢teau Pierrefonds (PRF) and CDN-111 is 26.950494 km
# Distance between Lafarge (sud) (MHM) and CDN-111 is 20.609477 km
# Distance between Langelier (SLE) and CDN-111 is 20.630576 km
# Distance between Newman (S-O) and CDN-111 is 5.117681999999999 km
# Distance between Ray-Lawson (ANJ) and CDN-111 is 22.879799 km
# Distance between Sartelon (SLA) and CDN-111 is 16.266863 km
# Distance between Thimens (SLA) and CDN-111 is 11.749524 km
# Distance between St-Michel - Charland (VSP) and CDN-112 is 15.4215 km
# Distance between St-Michel - Robert (VSP) and CDN-112 is 13.978211 km
# Distance between St-Michel-17i̬me(Sous-Sol) and CDN-112 is 15.109959 km
# Distance between Butler (S-O) and CDN-112 is 8.570154 km
# Distance between De la Salle (MHM) and CDN-112 is 13.99329 km
# Distance between Fullum (VMA) and CDN-112 is 11.704183 km
# Distance between Iberville (PMR) and CDN-112 is 12.045823 km
# Distance between Jules-Poitras 1 (AHU) and CDN-112 is 9.137413 km
# Distance between Jules-Poitras 2 (SLA) and CDN-112 is 8.814375 km
# Distance between Lausanne (MTN) and CDN-112 is 15.996874 km
# Distance between Millen (AHU) and CDN-112 is 13.2388 km
# Distance between Riverside (VMA) and CDN-112 is 10.261579 km
# Distance between Saint-Pierre (LAC) and CDN-112 is 4.710634 km
# Distance between Sauv̩ (AHU) and CDN-112 is 9.226995 km
# Distance between Verdun (VER) and CDN-112 is 9.188032999999999 km
# Distance between 46 ieme (LAC) and CDN-112 is 11.853495 km
# Distance between Angrignon (LAS) and CDN-112 is 8.941989 km
# Distance between Armand-Chaput (RDP) and CDN-112 is 26.767928 km
# Distance between Autoroute 13 (PRF) and CDN-112 is 12.325279 km
# Distance between Ch̢teau Pierrefonds (PRF) and CDN-112 is 25.230926 km
# Distance between Lafarge (sud) (MHM) and CDN-112 is 22.610303 km
# Distance between Langelier (SLE) and CDN-112 is 18.911008000000002 km
# Distance between Newman (S-O) and CDN-112 is 6.979362 km
# Distance between Ray-Lawson (ANJ) and CDN-112 is 21.160229 km
# Distance between Sartelon (SLA) and CDN-112 is 14.547293999999999 km
# Distance between Thimens (SLA) and CDN-112 is 10.029952999999999 km
# Distance between St-Michel - Charland (VSP) and CDN-113 is 15.929748 km
# Distance between St-Michel - Robert (VSP) and CDN-113 is 14.48646 km
# Distance between St-Michel-17i̬me(Sous-Sol) and CDN-113 is 15.618208000000001 km
# Distance between Butler (S-O) and CDN-113 is 9.526627000000001 km
# Distance between De la Salle (MHM) and CDN-113 is 14.949763 km
# Distance between Fullum (VMA) and CDN-113 is 12.660655 km
# Distance between Iberville (PMR) and CDN-113 is 13.002297 km
# Distance between Jules-Poitras 1 (AHU) and CDN-113 is 9.645661 km
# Distance between Jules-Poitras 2 (SLA) and CDN-113 is 9.322623 km
# Distance between Lausanne (MTN) and CDN-113 is 16.505121 km
# Distance between Millen (AHU) and CDN-113 is 13.747047 km
# Distance between Riverside (VMA) and CDN-113 is 11.218052 km
# Distance between Saint-Pierre (LAC) and CDN-113 is 5.6671059999999995 km
# Distance between Sauv̩ (AHU) and CDN-113 is 9.735245 km
# Distance between Verdun (VER) and CDN-113 is 10.144506 km
# Distance between 46 ieme (LAC) and CDN-113 is 12.361742 km
# Distance between Angrignon (LAS) and CDN-113 is 9.898462 km
# Distance between Armand-Chaput (RDP) and CDN-113 is 27.276173999999997 km
# Distance between Autoroute 13 (PRF) and CDN-113 is 12.833527 km
# Distance between Ch̢teau Pierrefonds (PRF) and CDN-113 is 25.739176 km
# Distance between Lafarge (sud) (MHM) and CDN-113 is 23.566773 km
# Distance between Langelier (SLE) and CDN-113 is 19.419254000000002 km
# Distance between Newman (S-O) and CDN-113 is 7.935834 km
# Distance between Ray-Lawson (ANJ) and CDN-113 is 21.668477 km
# Distance between Sartelon (SLA) and CDN-113 is 15.055541 km
# Distance between Thimens (SLA) and CDN-113 is 10.538200000000002 km
# Distance between St-Michel - Charland (VSP) and CDN-114 is 13.863421 km
# Distance between St-Michel - Robert (VSP) and CDN-114 is 12.420131999999999 km
# Distance between St-Michel-17i̬me(Sous-Sol) and CDN-114 is 13.551879999999999 km
# Distance between Butler (S-O) and CDN-114 is 10.576688 km
# Distance between De la Salle (MHM) and CDN-114 is 16.025603999999998 km
# Distance between Fullum (VMA) and CDN-114 is 13.736495000000001 km
# Distance between Iberville (PMR) and CDN-114 is 14.052357 km
# Distance between Jules-Poitras 1 (AHU) and CDN-114 is 7.579332999999999 km
# Distance between Jules-Poitras 2 (SLA) and CDN-114 is 7.256296 km
# Distance between Lausanne (MTN) and CDN-114 is 14.438795 km
# Distance between Millen (AHU) and CDN-114 is 11.680721 km
# Distance between Riverside (VMA) and CDN-114 is 12.268113999999999 km
# Distance between Saint-Pierre (LAC) and CDN-114 is 6.717168 km
# Distance between Sauv̩ (AHU) and CDN-114 is 7.668917 km
# Distance between Verdun (VER) and CDN-114 is 11.194567 km
# Distance between 46 ieme (LAC) and CDN-114 is 10.295415 km
# Distance between Angrignon (LAS) and CDN-114 is 9.133832 km
# Distance between Armand-Chaput (RDP) and CDN-114 is 25.209846000000002 km
# Distance between Autoroute 13 (PRF) and CDN-114 is 10.7672 km
# Distance between Ch̢teau Pierrefonds (PRF) and CDN-114 is 23.672848000000002 km
# Distance between Lafarge (sud) (MHM) and CDN-114 is 25.121387 km
# Distance between Langelier (SLE) and CDN-114 is 17.352926 km
# Distance between Newman (S-O) and CDN-114 is 9.458277 km
# Distance between Ray-Lawson (ANJ) and CDN-114 is 19.60215 km
# Distance between Sartelon (SLA) and CDN-114 is 12.989215 km
# Distance between Thimens (SLA) and CDN-114 is 8.471873 km
# Distance between St-Michel - Charland (VSP) and CDN-115 is 13.553904000000001 km
# Distance between St-Michel - Robert (VSP) and CDN-115 is 12.110616 km
# Distance between St-Michel-17i̬me(Sous-Sol) and CDN-115 is 13.242365 km
# Distance between Butler (S-O) and CDN-115 is 7.857658000000001 km
# Distance between De la Salle (MHM) and CDN-115 is 17.068443 km
# Distance between Fullum (VMA) and CDN-115 is 14.779335999999999 km
# Distance between Iberville (PMR) and CDN-115 is 15.120978 km
# Distance between Jules-Poitras 1 (AHU) and CDN-115 is 7.269729999999999 km
# Distance between Jules-Poitras 2 (SLA) and CDN-115 is 6.946693 km
# Distance between Lausanne (MTN) and CDN-115 is 14.129279 km
# Distance between Millen (AHU) and CDN-115 is 10.232406000000001 km
# Distance between Riverside (VMA) and CDN-115 is 9.696215 km
# Distance between Saint-Pierre (LAC) and CDN-115 is 7.785787 km
# Distance between Sauv̩ (AHU) and CDN-115 is 7.356104 km
# Distance between Verdun (VER) and CDN-115 is 9.651251 km
# Distance between 46 ieme (LAC) and CDN-115 is 11.559893 km
# Distance between Angrignon (LAS) and CDN-115 is 10.886646 km
# Distance between Armand-Chaput (RDP) and CDN-115 is 24.900332 km
# Distance between Autoroute 13 (PRF) and CDN-115 is 12.031679 km
# Distance between Ch̢teau Pierrefonds (PRF) and CDN-115 is 24.937324 km
# Distance between Lafarge (sud) (MHM) and CDN-115 is 24.811873 km
# Distance between Langelier (SLE) and CDN-115 is 17.043412 km
# Distance between Newman (S-O) and CDN-115 is 10.054516 km
# Distance between Ray-Lawson (ANJ) and CDN-115 is 19.292633000000002 km
# Distance between Sartelon (SLA) and CDN-115 is 10.273151 km
# Distance between Thimens (SLA) and CDN-115 is 9.736352 km
# Distance between St-Michel - Charland (VSP) and CDN-116 is 13.353843000000001 km
# Distance between St-Michel - Robert (VSP) and CDN-116 is 11.910554 km
# Distance between St-Michel-17i̬me(Sous-Sol) and CDN-116 is 13.042302 km
# Distance between Butler (S-O) and CDN-116 is 8.640856 km
# Distance between De la Salle (MHM) and CDN-116 is 17.913473000000003 km
# Distance between Fullum (VMA) and CDN-116 is 15.624367 km
# Distance between Iberville (PMR) and CDN-116 is 15.966006 km
# Distance between Jules-Poitras 1 (AHU) and CDN-116 is 7.069669 km
# Distance between Jules-Poitras 2 (SLA) and CDN-116 is 6.746631000000001 km
# Distance between Lausanne (MTN) and CDN-116 is 12.973422000000001 km
# Distance between Millen (AHU) and CDN-116 is 9.452786 km
# Distance between Riverside (VMA) and CDN-116 is 10.479413000000001 km
# Distance between Saint-Pierre (LAC) and CDN-116 is 8.630816999999999 km
# Distance between Sauv̩ (AHU) and CDN-116 is 6.725194 km
# Distance between Verdun (VER) and CDN-116 is 10.434449 km
# Distance between 46 ieme (LAC) and CDN-116 is 11.359831 km
# Distance between Angrignon (LAS) and CDN-116 is 12.862173 km
# Distance between Armand-Chaput (RDP) and CDN-116 is 24.700268 km
# Distance between Autoroute 13 (PRF) and CDN-116 is 11.831616 km
# Distance between Ch̢teau Pierrefonds (PRF) and CDN-116 is 24.737264 km
# Distance between Lafarge (sud) (MHM) and CDN-116 is 24.611811000000003 km
# Distance between Langelier (SLE) and CDN-116 is 16.843349999999997 km
# Distance between Newman (S-O) and CDN-116 is 10.899546 km
# Distance between Ray-Lawson (ANJ) and CDN-116 is 19.09257 km
# Distance between Sartelon (SLA) and CDN-116 is 10.07309 km
# Distance between Thimens (SLA) and CDN-116 is 9.536290000000001 km
# Distance between St-Michel - Charland (VSP) and CDN-301 is 16.238619 km
# Distance between St-Michel - Robert (VSP) and CDN-301 is 14.79533 km
# Distance between St-Michel-17i̬me(Sous-Sol) and CDN-301 is 15.927078 km
# Distance between Butler (S-O) and CDN-301 is 9.365613 km
# Distance between De la Salle (MHM) and CDN-301 is 14.788749 km
# Distance between Fullum (VMA) and CDN-301 is 12.499642 km
# Distance between Iberville (PMR) and CDN-301 is 12.841282999999999 km
# Distance between Jules-Poitras 1 (AHU) and CDN-301 is 9.954531000000001 km
# Distance between Jules-Poitras 2 (SLA) and CDN-301 is 9.631493 km
# Distance between Lausanne (MTN) and CDN-301 is 16.813992 km
# Distance between Millen (AHU) and CDN-301 is 14.055916999999999 km
# Distance between Riverside (VMA) and CDN-301 is 11.057039000000001 km
# Distance between Saint-Pierre (LAC) and CDN-301 is 5.506093 km
# Distance between Sauv̩ (AHU) and CDN-301 is 10.044115 km
# Distance between Verdun (VER) and CDN-301 is 12.344215 km
# Distance between 46 ieme (LAC) and CDN-301 is 12.670611999999998 km
# Distance between Angrignon (LAS) and CDN-301 is 6.692455 km
# Distance between Armand-Chaput (RDP) and CDN-301 is 27.585044999999997 km
# Distance between Autoroute 13 (PRF) and CDN-301 is 13.142397 km
# Distance between Ch̢teau Pierrefonds (PRF) and CDN-301 is 26.048047 km
# Distance between Lafarge (sud) (MHM) and CDN-301 is 23.405762 km
# Distance between Langelier (SLE) and CDN-301 is 19.728125 km
# Distance between Newman (S-O) and CDN-301 is 7.016902 km
# Distance between Ray-Lawson (ANJ) and CDN-301 is 21.977346 km
# Distance between Sartelon (SLA) and CDN-301 is 15.364411 km
# Distance between Thimens (SLA) and CDN-301 is 10.84707 km
# Distance between St-Michel - Charland (VSP) and IBI-301 is 37.794285 km
# Distance between St-Michel - Robert (VSP) and IBI-301 is 36.350992 km
# Distance between St-Michel-17i̬me(Sous-Sol) and IBI-301 is 37.482742 km
# Distance between Butler (S-O) and IBI-301 is 36.504352 km
# Distance between De la Salle (MHM) and IBI-301 is 43.798199000000004 km
# Distance between Fullum (VMA) and IBI-301 is 41.50908999999999 km
# Distance between Iberville (PMR) and IBI-301 is 41.850730000000006 km
# Distance between Jules-Poitras 1 (AHU) and IBI-301 is 25.202039 km
# Distance between Jules-Poitras 2 (SLA) and IBI-301 is 24.879004000000002 km
# Distance between Lausanne (MTN) and IBI-301 is 33.152746 km
# Distance between Millen (AHU) and IBI-301 is 29.632113 km
# Distance between Riverside (VMA) and IBI-301 is 40.537219 km
# Distance between Saint-Pierre (LAC) and IBI-301 is 33.000983999999995 km
# Distance between Sauv̩ (AHU) and IBI-301 is 28.357135 km
# Distance between Verdun (VER) and IBI-301 is 37.752336 km
# Distance between 46 ieme (LAC) and IBI-301 is 23.875723 km
# Distance between Angrignon (LAS) and IBI-301 is 32.100938 km
# Distance between Armand-Chaput (RDP) and IBI-301 is 49.140711 km
# Distance between Autoroute 13 (PRF) and IBI-301 is 15.854815 km
# Distance between Ch̢teau Pierrefonds (PRF) and IBI-301 is 9.680594999999999 km
# Distance between Lafarge (sud) (MHM) and IBI-301 is 49.052254 km
# Distance between Langelier (SLE) and IBI-301 is 41.283792999999996 km
# Distance between Newman (S-O) and IBI-301 is 32.425385 km
# Distance between Ray-Lawson (ANJ) and IBI-301 is 48.587223 km
# Distance between Sartelon (SLA) and IBI-301 is 20.772423999999997 km
# Distance between Thimens (SLA) and IBI-301 is 21.049636999999997 km
# Distance between St-Michel - Charland (VSP) and LAC-102 is 20.219939 km
# Distance between St-Michel - Robert (VSP) and LAC-102 is 18.776652 km
# Distance between St-Michel-17i̬me(Sous-Sol) and LAC-102 is 19.9084 km
# Distance between Butler (S-O) and LAC-102 is 14.403756999999999 km
# Distance between De la Salle (MHM) and LAC-102 is 21.697604 km
# Distance between Fullum (VMA) and LAC-102 is 19.408496 km
# Distance between Iberville (PMR) and LAC-102 is 19.750137 km
# Distance between Jules-Poitras 1 (AHU) and LAC-102 is 13.963795 km
# Distance between Jules-Poitras 2 (SLA) and LAC-102 is 13.640756999999999 km
# Distance between Lausanne (MTN) and LAC-102 is 35.680237999999996 km
# Distance between Millen (AHU) and LAC-102 is 18.037238000000002 km
# Distance between Riverside (VMA) and LAC-102 is 18.436627 km
# Distance between Saint-Pierre (LAC) and LAC-102 is 10.900390999999999 km
# Distance between Sauv̩ (AHU) and LAC-102 is 14.025437 km
# Distance between Verdun (VER) and LAC-102 is 15.651741 km
# Distance between 46 ieme (LAC) and LAC-102 is 1.738221 km
# Distance between Angrignon (LAS) and LAC-102 is 10.000343 km
# Distance between Armand-Chaput (RDP) and LAC-102 is 31.566365 km
# Distance between Autoroute 13 (PRF) and LAC-102 is 10.234008 km
# Distance between Ch̢teau Pierrefonds (PRF) and LAC-102 is 16.953719 km
# Distance between Lafarge (sud) (MHM) and LAC-102 is 30.314617 km
# Distance between Langelier (SLE) and LAC-102 is 23.709445 km
# Distance between Newman (S-O) and LAC-102 is 10.324789 km
# Distance between Ray-Lawson (ANJ) and LAC-102 is 42.888656000000005 km
# Distance between Sartelon (SLA) and LAC-102 is 12.456021 km
# Distance between Thimens (SLA) and LAC-102 is 10.477108 km
# Distance between St-Michel - Charland (VSP) and LAC-104 is 17.565236000000002 km
# Distance between St-Michel - Robert (VSP) and LAC-104 is 16.121948 km
# Distance between St-Michel-17i̬me(Sous-Sol) and LAC-104 is 17.253697 km
# Distance between Butler (S-O) and LAC-104 is 16.355269 km
# Distance between De la Salle (MHM) and LAC-104 is 23.649115000000002 km
# Distance between Fullum (VMA) and LAC-104 is 21.360008 km
# Distance between Iberville (PMR) and LAC-104 is 21.701646 km
# Distance between Jules-Poitras 1 (AHU) and LAC-104 is 10.530666 km
# Distance between Jules-Poitras 2 (SLA) and LAC-104 is 10.207629 km
# Distance between Lausanne (MTN) and LAC-104 is 17.559039000000002 km
# Distance between Millen (AHU) and LAC-104 is 14.038403 km
# Distance between Riverside (VMA) and LAC-104 is 20.388137 km
# Distance between Saint-Pierre (LAC) and LAC-104 is 12.851901 km
# Distance between Sauv̩ (AHU) and LAC-104 is 11.370734 km
# Distance between Verdun (VER) and LAC-104 is 17.603252 km
# Distance between 46 ieme (LAC) and LAC-104 is 4.68737 km
# Distance between Angrignon (LAS) and LAC-104 is 11.951853999999999 km
# Distance between Armand-Chaput (RDP) and LAC-104 is 28.911662 km
# Distance between Autoroute 13 (PRF) and LAC-104 is 8.517433 km
# Distance between Ch̢teau Pierrefonds (PRF) and LAC-104 is 20.983224999999997 km
# Distance between Lafarge (sud) (MHM) and LAC-104 is 28.823203000000003 km
# Distance between Langelier (SLE) and LAC-104 is 21.054744 km
# Distance between Newman (S-O) and LAC-104 is 12.276299999999999 km
# Distance between Ray-Lawson (ANJ) and LAC-104 is 23.303965 km
# Distance between Sartelon (SLA) and LAC-104 is 10.739446 km
# Distance between Thimens (SLA) and LAC-104 is 5.7667790000000005 km
# Distance between St-Michel - Charland (VSP) and LAC-305 is 18.992918000000003 km
# Distance between St-Michel - Robert (VSP) and LAC-305 is 17.549629 km
# Distance between St-Michel-17i̬me(Sous-Sol) and LAC-305 is 18.681377 km
# Distance between Butler (S-O) and LAC-305 is 15.696786 km
# Distance between De la Salle (MHM) and LAC-305 is 22.990631 km
# Distance between Fullum (VMA) and LAC-305 is 20.701525 km
# Distance between Iberville (PMR) and LAC-305 is 21.043166 km
# Distance between Jules-Poitras 1 (AHU) and LAC-305 is 13.1636 km
# Distance between Jules-Poitras 2 (SLA) and LAC-305 is 12.840562 km
# Distance between Lausanne (MTN) and LAC-305 is 31.958203 km
# Distance between Millen (AHU) and LAC-305 is 16.671336 km
# Distance between Riverside (VMA) and LAC-305 is 19.729654 km
# Distance between Saint-Pierre (LAC) and LAC-305 is 12.193419 km
# Distance between Sauv̩ (AHU) and LAC-305 is 12.798414000000001 km
# Distance between Verdun (VER) and LAC-305 is 16.944770000000002 km
# Distance between 46 ieme (LAC) and LAC-305 is 3.9474810000000002 km
# Distance between Angrignon (LAS) and LAC-305 is 11.293370999999999 km
# Distance between Armand-Chaput (RDP) and LAC-305 is 30.339342000000002 km
# Distance between Autoroute 13 (PRF) and LAC-305 is 6.511971 km
# Distance between Ch̢teau Pierrefonds (PRF) and LAC-305 is 19.558336 km
# Distance between Lafarge (sud) (MHM) and LAC-305 is 31.607645 km
# Distance between Langelier (SLE) and LAC-305 is 35.001766 km
# Distance between Newman (S-O) and LAC-305 is 11.617816999999999 km
# Distance between Ray-Lawson (ANJ) and LAC-305 is 39.166616999999995 km
# Distance between Sartelon (SLA) and LAC-305 is 8.733984 km
# Distance between Thimens (SLA) and LAC-305 is 6.755072 km
# Distance between St-Michel - Charland (VSP) and LAC-306 is 23.875768 km
# Distance between St-Michel - Robert (VSP) and LAC-306 is 22.432479 km
# Distance between St-Michel-17i̬me(Sous-Sol) and LAC-306 is 23.564227 km
# Distance between Butler (S-O) and LAC-306 is 16.063793 km
# Distance between De la Salle (MHM) and LAC-306 is 23.357639 km
# Distance between Fullum (VMA) and LAC-306 is 21.068533 km
# Distance between Iberville (PMR) and LAC-306 is 21.410173999999998 km
# Distance between Jules-Poitras 1 (AHU) and LAC-306 is 17.619621 km
# Distance between Jules-Poitras 2 (SLA) and LAC-306 is 17.296584 km
# Distance between Lausanne (MTN) and LAC-306 is 37.340273 km
# Distance between Millen (AHU) and LAC-306 is 21.693065999999998 km
# Distance between Riverside (VMA) and LAC-306 is 20.096662000000002 km
# Distance between Saint-Pierre (LAC) and LAC-306 is 12.560426999999999 km
# Distance between Sauv̩ (AHU) and LAC-306 is 17.681264 km
# Distance between Verdun (VER) and LAC-306 is 17.311777 km
# Distance between 46 ieme (LAC) and LAC-306 is 3.434169 km
# Distance between Angrignon (LAS) and LAC-306 is 11.660379 km
# Distance between Armand-Chaput (RDP) and LAC-306 is 35.222191 km
# Distance between Autoroute 13 (PRF) and LAC-306 is 11.894044 km
# Distance between Ch̢teau Pierrefonds (PRF) and LAC-306 is 18.515241999999997 km
# Distance between Lafarge (sud) (MHM) and LAC-306 is 31.974652 km
# Distance between Langelier (SLE) and LAC-306 is 27.365273000000002 km
# Distance between Newman (S-O) and LAC-306 is 11.984825 km
# Distance between Ray-Lawson (ANJ) and LAC-306 is 29.614494 km
# Distance between Sartelon (SLA) and LAC-306 is 14.116059 km
# Distance between Thimens (SLA) and LAC-306 is 12.137145 km
# Distance between St-Michel - Charland (VSP) and LAS-321 is 23.288072 km
# Distance between St-Michel - Robert (VSP) and LAS-321 is 21.844783 km
# Distance between St-Michel-17i̬me(Sous-Sol) and LAS-321 is 22.976530999999998 km
# Distance between Butler (S-O) and LAS-321 is 5.976544 km
# Distance between De la Salle (MHM) and LAS-321 is 16.625434000000002 km
# Distance between Fullum (VMA) and LAS-321 is 14.336324000000001 km
# Distance between Iberville (PMR) and LAS-321 is 14.677966 km
# Distance between Jules-Poitras 1 (AHU) and LAS-321 is 17.003984 km
# Distance between Jules-Poitras 2 (SLA) and LAS-321 is 16.680947 km
# Distance between Lausanne (MTN) and LAS-321 is 23.863447 km
# Distance between Millen (AHU) and LAS-321 is 21.105370999999998 km
# Distance between Riverside (VMA) and LAS-321 is 10.009412000000001 km
# Distance between Saint-Pierre (LAC) and LAS-321 is 3.9827399999999997 km
# Distance between Sauv̩ (AHU) and LAS-321 is 17.093567999999998 km
# Distance between Verdun (VER) and LAS-321 is 7.224528 km
# Distance between 46 ieme (LAC) and LAS-321 is 14.218512 km
# Distance between Angrignon (LAS) and LAS-321 is 4.363823 km
# Distance between Armand-Chaput (RDP) and LAS-321 is 34.073906 km
# Distance between Autoroute 13 (PRF) and LAS-321 is 19.060067999999998 km
# Distance between Ch̢teau Pierrefonds (PRF) and LAS-321 is 29.299584 km
# Distance between Lafarge (sud) (MHM) and LAS-321 is 25.242445 km
# Distance between Langelier (SLE) and LAS-321 is 26.777576 km
# Distance between Newman (S-O) and LAS-321 is 3.5808649999999997 km
# Distance between Ray-Lawson (ANJ) and LAS-321 is 28.466206999999997 km
# Distance between Sartelon (SLA) and LAS-321 is 21.282082 km
# Distance between Thimens (SLA) and LAS-321 is 19.303168000000003 km
# Distance between St-Michel - Charland (VSP) and LAS-323 is 24.762848 km
# Distance between St-Michel - Robert (VSP) and LAS-323 is 23.319559 km
# Distance between St-Michel-17i̬me(Sous-Sol) and LAS-323 is 24.451307 km
# Distance between Butler (S-O) and LAS-323 is 7.45132 km
# Distance between De la Salle (MHM) and LAS-323 is 18.100206999999997 km
# Distance between Fullum (VMA) and LAS-323 is 15.8111 km
# Distance between Iberville (PMR) and LAS-323 is 16.15274 km
# Distance between Jules-Poitras 1 (AHU) and LAS-323 is 18.478759999999998 km
# Distance between Jules-Poitras 2 (SLA) and LAS-323 is 18.155721 km
# Distance between Lausanne (MTN) and LAS-323 is 25.338221 km
# Distance between Millen (AHU) and LAS-323 is 22.580145 km
# Distance between Riverside (VMA) and LAS-323 is 11.484187 km
# Distance between Saint-Pierre (LAC) and LAS-323 is 5.332799 km
# Distance between Sauv̩ (AHU) and LAS-323 is 18.568342 km
# Distance between Verdun (VER) and LAS-323 is 8.699303 km
# Distance between 46 ieme (LAC) and LAS-323 is 11.798216 km
# Distance between Angrignon (LAS) and LAS-323 is 5.330010000000001 km
# Distance between Armand-Chaput (RDP) and LAS-323 is 35.54868 km
# Distance between Autoroute 13 (PRF) and LAS-323 is 16.639771 km
# Distance between Ch̢teau Pierrefonds (PRF) and LAS-323 is 26.879291000000002 km
# Distance between Lafarge (sud) (MHM) and LAS-323 is 26.717221000000002 km
# Distance between Langelier (SLE) and LAS-323 is 28.252354 km
# Distance between Newman (S-O) and LAS-323 is 4.547052 km
# Distance between Ray-Lawson (ANJ) and LAS-323 is 29.940981999999998 km
# Distance between Sartelon (SLA) and LAS-323 is 18.861787 km
# Distance between Thimens (SLA) and LAS-323 is 16.882873 km
# Distance between St-Michel - Charland (VSP) and LAS-325 is 25.244725 km
# Distance between St-Michel - Robert (VSP) and LAS-325 is 23.801436000000002 km
# Distance between St-Michel-17i̬me(Sous-Sol) and LAS-325 is 24.933184 km
# Distance between Butler (S-O) and LAS-325 is 9.952694 km
# Distance between De la Salle (MHM) and LAS-325 is 18.528578000000003 km
# Distance between Fullum (VMA) and LAS-325 is 16.239472 km
# Distance between Iberville (PMR) and LAS-325 is 16.581109 km
# Distance between Jules-Poitras 1 (AHU) and LAS-325 is 22.357526999999997 km
# Distance between Jules-Poitras 2 (SLA) and LAS-325 is 22.034488 km
# Distance between Lausanne (MTN) and LAS-325 is 40.505523000000004 km
# ...
# Distance between Newman (S-O) and VMA-111 is 10.743992 km
# Distance between Ray-Lawson (ANJ) and VMA-111 is 15.101307 km
# Distance between Sartelon (SLA) and VMA-111 is 16.00934 km
# Distance between Thimens (SLA) and VMA-111 is 17.168865 km
# Distance between St-Michel - Charland (VSP) and VMA-306 is 10.640569 km
# Distance between St-Michel - Robert (VSP) and VMA-306 is 9.465176999999999 km
# Distance between St-Michel-17i̬me(Sous-Sol) and VMA-306 is 10.329029 km
# Distance between Butler (S-O) and VMA-306 is 6.408306 km
# Distance between De la Salle (MHM) and VMA-306 is 5.6574219999999995 km
# Distance between Fullum (VMA) and VMA-306 is 3.368315 km
# Distance between Iberville (PMR) and VMA-306 is 2.1392469999999997 km
# Distance between Jules-Poitras 1 (AHU) and VMA-306 is 14.247319 km
# Distance between Jules-Poitras 2 (SLA) and VMA-306 is 13.580906 km
# Distance between Lausanne (MTN) and VMA-306 is 12.064713 km
# Distance between Millen (AHU) and VMA-306 is 11.652133 km
# Distance between Riverside (VMA) and VMA-306 is 5.520237 km
# Distance between Saint-Pierre (LAC) and VMA-306 is 9.525549999999999 km
# Distance between Sauv̩ (AHU) and VMA-306 is 10.586364 km
# Distance between Verdun (VER) and VMA-306 is 8.655537 km
# Distance between 46 ieme (LAC) and VMA-306 is 20.035699 km
# Distance between Angrignon (LAS) and VMA-306 is 12.427592 km
# Distance between Armand-Chaput (RDP) and VMA-306 is 19.850389 km
# Distance between Autoroute 13 (PRF) and VMA-306 is 24.877256000000003 km
# Distance between Ch̢teau Pierrefonds (PRF) and VMA-306 is 35.116773 km
# Distance between Lafarge (sud) (MHM) and VMA-306 is 11.614265999999999 km
# Distance between Langelier (SLE) and VMA-306 is 12.886298 km
# Distance between Newman (S-O) and VMA-306 is 11.43276 km
# Distance between Ray-Lawson (ANJ) and VMA-306 is 14.242692 km
# Distance between Sartelon (SLA) and VMA-306 is 27.099271 km
# Distance between Thimens (SLA) and VMA-306 is 25.120357 km
# Distance between St-Michel - Charland (VSP) and VMA-307 is 11.434295 km
# Distance between St-Michel - Robert (VSP) and VMA-307 is 10.258901 km
# Distance between St-Michel-17i̬me(Sous-Sol) and VMA-307 is 11.122754 km
# Distance between Butler (S-O) and VMA-307 is 6.457147 km
# Distance between De la Salle (MHM) and VMA-307 is 5.211863999999999 km
# Distance between Fullum (VMA) and VMA-307 is 2.9227559999999997 km
# Distance between Iberville (PMR) and VMA-307 is 2.612109 km
# Distance between Jules-Poitras 1 (AHU) and VMA-307 is 18.698535 km
# Distance between Jules-Poitras 2 (SLA) and VMA-307 is 18.375498 km
# Distance between Lausanne (MTN) and VMA-307 is 12.858438 km
# Distance between Millen (AHU) and VMA-307 is 10.430689000000001 km
# Distance between Riverside (VMA) and VMA-307 is 5.210845 km
# Distance between Saint-Pierre (LAC) and VMA-307 is 8.942407999999999 km
# Distance between Sauv̩ (AHU) and VMA-307 is 11.140482 km
# Distance between Verdun (VER) and VMA-307 is 8.346144 km
# Distance between 46 ieme (LAC) and VMA-307 is 19.452559 km
# Distance between Angrignon (LAS) and VMA-307 is 11.84445 km
# Distance between Armand-Chaput (RDP) and VMA-307 is 22.660338 km
# Distance between Autoroute 13 (PRF) and VMA-307 is 24.294115 km
# Distance between Ch̢teau Pierrefonds (PRF) and VMA-307 is 34.533633 km
# Distance between Lafarge (sud) (MHM) and VMA-307 is 13.828876000000001 km
# Distance between Langelier (SLE) and VMA-307 is 15.771182000000001 km
# Distance between Newman (S-O) and VMA-307 is 10.849617 km
# Distance between Ray-Lawson (ANJ) and VMA-307 is 17.052639 km
# Distance between Sartelon (SLA) and VMA-307 is 26.516129 km
# Distance between Thimens (SLA) and VMA-307 is 24.537217000000002 km
# Distance between St-Michel - Charland (VSP) and VSP-103 is 9.089458 km
# Distance between St-Michel - Robert (VSP) and VSP-103 is 7.6461689999999995 km
# Distance between St-Michel-17i̬me(Sous-Sol) and VSP-103 is 8.777918 km
# Distance between Butler (S-O) and VSP-103 is 17.223727 km
# Distance between De la Salle (MHM) and VSP-103 is 13.475485 km
# Distance between Fullum (VMA) and VSP-103 is 12.083139 km
# Distance between Iberville (PMR) and VSP-103 is 11.032277 km
# Distance between Jules-Poitras 1 (AHU) and VSP-103 is 7.714018 km
# Distance between Jules-Poitras 2 (SLA) and VSP-103 is 7.047604000000001 km
# Distance between Lausanne (MTN) and VSP-103 is 9.287604 km
# Distance between Millen (AHU) and VSP-103 is 5.766967999999999 km
# Distance between Riverside (VMA) and VSP-103 is 13.196043 km
# Distance between Saint-Pierre (LAC) and VSP-103 is 13.364205 km
# Distance between Sauv̩ (AHU) and VSP-103 is 4.01197 km
# Distance between Verdun (VER) and VSP-103 is 19.017318 km
# Distance between 46 ieme (LAC) and VSP-103 is 13.378467 km
# Distance between Angrignon (LAS) and VSP-103 is 21.234391 km
# Distance between Armand-Chaput (RDP) and VSP-103 is 20.435885 km
# Distance between Autoroute 13 (PRF) and VSP-103 is 13.850254000000001 km
# Distance between Ch̢teau Pierrefonds (PRF) and VSP-103 is 26.7559 km
# Distance between Lafarge (sud) (MHM) and VSP-103 is 20.347426 km
# Distance between Langelier (SLE) and VSP-103 is 12.578964 km
# Distance between Newman (S-O) and VSP-103 is 15.632933000000001 km
# Distance between Ray-Lawson (ANJ) and VSP-103 is 14.828187 km
# Distance between Sartelon (SLA) and VSP-103 is 10.359782 km
# Distance between Thimens (SLA) and VSP-103 is 11.554926 km
# Distance between St-Michel - Charland (VSP) and VSP-104 is 1.993345 km
# Distance between St-Michel - Robert (VSP) and VSP-104 is 5.046344 km
# Distance between St-Michel-17i̬me(Sous-Sol) and VSP-104 is 2.674257 km
# Distance between Butler (S-O) and VSP-104 is 16.920938 km
# Distance between De la Salle (MHM) and VSP-104 is 11.141665999999999 km
# Distance between Fullum (VMA) and VSP-104 is 9.73807 km
# Distance between Iberville (PMR) and VSP-104 is 8.687209000000001 km
# Distance between Jules-Poitras 1 (AHU) and VSP-104 is 8.004754 km
# Distance between Jules-Poitras 2 (SLA) and VSP-104 is 8.162779 km
# Distance between Lausanne (MTN) and VSP-104 is 3.417489 km
# Distance between Millen (AHU) and VSP-104 is 3.371835 km
# Distance between Riverside (VMA) and VSP-104 is 15.674634 km
# Distance between Saint-Pierre (LAC) and VSP-104 is 17.302865 km
# Distance between Sauv̩ (AHU) and VSP-104 is 5.078100999999999 km
# Distance between Verdun (VER) and VSP-104 is 18.809936 km
# Distance between 46 ieme (LAC) and VSP-104 is 17.317129 km
# Distance between Angrignon (LAS) and VSP-104 is 22.308238000000003 km
# Distance between Armand-Chaput (RDP) and VSP-104 is 18.106116999999998 km
# Distance between Autoroute 13 (PRF) and VSP-104 is 24.075633000000003 km
# Distance between Ch̢teau Pierrefonds (PRF) and VSP-104 is 30.694562 km
# Distance between Lafarge (sud) (MHM) and VSP-104 is 18.017658 km
# Distance between Langelier (SLE) and VSP-104 is 6.637316 km
# Distance between Newman (S-O) and VSP-104 is 19.571594 km
# Distance between Ray-Lawson (ANJ) and VSP-104 is 9.594588 km
# Distance between Sartelon (SLA) and VSP-104 is 11.474957 km
# Distance between Thimens (SLA) and VSP-104 is 12.850515999999999 km
# Distance between St-Michel - Charland (VSP) and VSP-107 is 4.314897 km
# Distance between St-Michel - Robert (VSP) and VSP-107 is 2.871609 km
# Distance between St-Michel-17i̬me(Sous-Sol) and VSP-107 is 4.003357 km
# Distance between Butler (S-O) and VSP-107 is 14.746201 km
# Distance between De la Salle (MHM) and VSP-107 is 8.966931 km
# Distance between Fullum (VMA) and VSP-107 is 7.563335 km
# Distance between Iberville (PMR) and VSP-107 is 6.512474 km
# Distance between Jules-Poitras 1 (AHU) and VSP-107 is 9.771929 km
# Distance between Jules-Poitras 2 (SLA) and VSP-107 is 9.105516 km
# Distance between Lausanne (MTN) and VSP-107 is 5.739042 km
# Distance between Millen (AHU) and VSP-107 is 5.813362 km
# Distance between Riverside (VMA) and VSP-107 is 13.499899 km
# Distance between Saint-Pierre (LAC) and VSP-107 is 15.422116 km
# Distance between Sauv̩ (AHU) and VSP-107 is 6.069882 km
# Distance between Verdun (VER) and VSP-107 is 15.908562 km
# Distance between 46 ieme (LAC) and VSP-107 is 15.43638 km
# Distance between Angrignon (LAS) and VSP-107 is 20.133504000000002 km
# Distance between Armand-Chaput (RDP) and VSP-107 is 15.931381 km
# Distance between Autoroute 13 (PRF) and VSP-107 is 15.908165 km
# Distance between Ch̢teau Pierrefonds (PRF) and VSP-107 is 28.813811 km
# Distance between Lafarge (sud) (MHM) and VSP-107 is 15.842922 km
# Distance between Langelier (SLE) and VSP-107 is 8.074461 km
# Distance between Newman (S-O) and VSP-107 is 17.690846 km
# Distance between Ray-Lawson (ANJ) and VSP-107 is 10.323683 km
# Distance between Sartelon (SLA) and VSP-107 is 12.417694 km
# Distance between Thimens (SLA) and VSP-107 is 13.612839 km
# Distance between St-Michel - Charland (VSP) and VSP-108 is 12.692308 km
# Distance between St-Michel - Robert (VSP) and VSP-108 is 14.345075999999999 km
# Distance between St-Michel-17i̬me(Sous-Sol) and VSP-108 is 13.543004000000002 km
# Distance between Butler (S-O) and VSP-108 is 15.985101 km
# Distance between De la Salle (MHM) and VSP-108 is 21.408238 km
# Distance between Fullum (VMA) and VSP-108 is 19.119129 km
# Distance between Iberville (PMR) and VSP-108 is 19.46077 km
# Distance between Jules-Poitras 1 (AHU) and VSP-108 is 6.475393 km
# Distance between Jules-Poitras 2 (SLA) and VSP-108 is 5.808979 km
# Distance between Lausanne (MTN) and VSP-108 is 11.298689 km
# Distance between Millen (AHU) and VSP-108 is 7.778054 km
# Distance between Riverside (VMA) and VSP-108 is 17.676525 km
# Distance between Saint-Pierre (LAC) and VSP-108 is 12.125581 km
# Distance between Sauv̩ (AHU) and VSP-108 is 6.557175 km
# Distance between Verdun (VER) and VSP-108 is 17.778693 km
# Distance between 46 ieme (LAC) and VSP-108 is 12.139843 km
# Distance between Angrignon (LAS) and VSP-108 is 19.995766 km
# Distance between Armand-Chaput (RDP) and VSP-108 is 27.134791 km
# Distance between Autoroute 13 (PRF) and VSP-108 is 12.611629 km
# Distance between Ch̢teau Pierrefonds (PRF) and VSP-108 is 25.517275 km
# Distance between Lafarge (sud) (MHM) and VSP-108 is 27.046332 km
# Distance between Langelier (SLE) and VSP-108 is 16.647701 km
# Distance between Newman (S-O) and VSP-108 is 14.394308 km
# Distance between Ray-Lawson (ANJ) and VSP-108 is 18.613348000000002 km
# Distance between Sartelon (SLA) and VSP-108 is 9.121156999999998 km
# Distance between Thimens (SLA) and VSP-108 is 10.316302 km
# Distance between St-Michel - Charland (VSP) and VSP-109 is 8.392428 km
# Distance between St-Michel - Robert (VSP) and VSP-109 is 6.949139 km
# Distance between St-Michel-17i̬me(Sous-Sol) and VSP-109 is 8.080888 km
# Distance between Butler (S-O) and VSP-109 is 16.523732 km
# Distance between De la Salle (MHM) and VSP-109 is 12.778455 km
# Distance between Fullum (VMA) and VSP-109 is 11.386106999999999 km
# Distance between Iberville (PMR) and VSP-109 is 10.335246 km
# Distance between Jules-Poitras 1 (AHU) and VSP-109 is 6.1633130000000005 km
# Distance between Jules-Poitras 2 (SLA) and VSP-109 is 6.355139 km
# Distance between Lausanne (MTN) and VSP-109 is 7.659521 km
# Distance between Millen (AHU) and VSP-109 is 4.138885 km
# Distance between Riverside (VMA) and VSP-109 is 11.3738 km
# Distance between Saint-Pierre (LAC) and VSP-109 is 12.664212 km
# Distance between Sauv̩ (AHU) and VSP-109 is 3.31494 km
# Distance between Verdun (VER) and VSP-109 is 14.509099 km
# Distance between 46 ieme (LAC) and VSP-109 is 12.678474 km
# Distance between Angrignon (LAS) and VSP-109 is 20.534396 km
# Distance between Armand-Chaput (RDP) and VSP-109 is 19.738854 km
# Distance between Autoroute 13 (PRF) and VSP-109 is 13.150259 km
# Distance between Ch̢teau Pierrefonds (PRF) and VSP-109 is 26.055906 km
# Distance between Lafarge (sud) (MHM) and VSP-109 is 19.650395 km
# Distance between Langelier (SLE) and VSP-109 is 11.881935 km
# Distance between Newman (S-O) and VSP-109 is 14.932939000000001 km
# Distance between Ray-Lawson (ANJ) and VSP-109 is 14.131156 km
# Distance between Sartelon (SLA) and VSP-109 is 9.667316999999999 km
# Distance between Thimens (SLA) and VSP-109 is 10.854933 km
# Distance between St-Michel - Charland (VSP) and VSP-205 is 0.42172699999999996 km
# Distance between St-Michel - Robert (VSP) and VSP-205 is 3.6154699999999997 km
# Distance between St-Michel-17i̬me(Sous-Sol) and VSP-205 is 1.306857 km
# Distance between Butler (S-O) and VSP-205 is 17.184330000000003 km
# Distance between De la Salle (MHM) and VSP-205 is 10.251393 km
# Distance between Fullum (VMA) and VSP-205 is 10.001464 km
# Distance between Iberville (PMR) and VSP-205 is 8.950603 km
# Distance between Jules-Poitras 1 (AHU) and VSP-205 is 9.644814 km
# Distance between Jules-Poitras 2 (SLA) and VSP-205 is 9.80284 km
# Distance between Lausanne (MTN) and VSP-205 is 1.903557 km
# Distance between Millen (AHU) and VSP-205 is 5.011896 km
# Distance between Riverside (VMA) and VSP-205 is 15.938027 km
# Distance between Saint-Pierre (LAC) and VSP-205 is 19.285652 km
# Distance between Sauv̩ (AHU) and VSP-205 is 6.083575 km
# Distance between Verdun (VER) and VSP-205 is 19.073326 km
# Distance between 46 ieme (LAC) and VSP-205 is 19.299916 km
# Distance between Angrignon (LAS) and VSP-205 is 22.571633000000002 km
# Distance between Armand-Chaput (RDP) and VSP-205 is 17.215844 km
# Distance between Autoroute 13 (PRF) and VSP-205 is 24.646645 km
# Distance between Ch̢teau Pierrefonds (PRF) and VSP-205 is 32.677346 km
# Distance between Lafarge (sud) (MHM) and VSP-205 is 17.127384999999997 km
# Distance between Langelier (SLE) and VSP-205 is 5.0656989999999995 km
# Distance between Newman (S-O) and VSP-205 is 21.554381000000003 km
# Distance between Ray-Lawson (ANJ) and VSP-205 is 8.022971 km
# Distance between Sartelon (SLA) and VSP-205 is 13.115019 km
# Distance between Thimens (SLA) and VSP-205 is 14.490575999999999 km
# Distance between St-Michel - Charland (VSP) and VSP-206 is 3.517627 km
# Distance between St-Michel - Robert (VSP) and VSP-206 is 2.074338 km
# Distance between St-Michel-17i̬me(Sous-Sol) and VSP-206 is 3.206086 km
# Distance between Butler (S-O) and VSP-206 is 14.277361 km
# Distance between De la Salle (MHM) and VSP-206 is 7.903654 km
# Distance between Fullum (VMA) and VSP-206 is 7.094496 km
# Distance between Iberville (PMR) and VSP-206 is 6.043634 km
# Distance between Jules-Poitras 1 (AHU) and VSP-206 is 10.500138999999999 km
# Distance between Jules-Poitras 2 (SLA) and VSP-206 is 9.833724 km
# Distance between Lausanne (MTN) and VSP-206 is 4.941771 km
# Distance between Millen (AHU) and VSP-206 is 5.563233 km
# Distance between Riverside (VMA) and VSP-206 is 13.03106 km
# Distance between Saint-Pierre (LAC) and VSP-206 is 16.150326 km
# Distance between Sauv̩ (AHU) and VSP-206 is 6.798091 km
# Distance between Verdun (VER) and VSP-206 is 16.166357 km
# Distance between 46 ieme (LAC) and VSP-206 is 16.164589 km
# Distance between Angrignon (LAS) and VSP-206 is 19.664666 km
# Distance between Armand-Chaput (RDP) and VSP-206 is 14.868103999999999 km
# Distance between Autoroute 13 (PRF) and VSP-206 is 16.636373 km
# Distance between Ch̢teau Pierrefonds (PRF) and VSP-206 is 29.54202 km
# Distance between Lafarge (sud) (MHM) and VSP-206 is 14.779646000000001 km
# Distance between Langelier (SLE) and VSP-206 is 7.011185 km
# Distance between Newman (S-O) and VSP-206 is 18.419055 km
# Distance between Ray-Lawson (ANJ) and VSP-206 is 9.260406000000001 km
# Distance between Sartelon (SLA) and VSP-206 is 13.145903 km
# Distance between Thimens (SLA) and VSP-206 is 14.341047 km
#      Removal Site                Disposal Site   Distance
# 0         AHU-101   St-Michel - Charland (VSP)  10.195564
# 1         AHU-101     St-Michel - Robert (VSP)  13.140525
# 2         AHU-101  St-Michel-17i̬me(Sous-Sol)  11.041832
# 3         AHU-101                 Butler (S-O)  18.758260
# 4         AHU-101            De la Salle (MHM)  18.303719
# ...           ...                          ...        ...
# 5507      VSP-206              Langelier (SLE)   7.011185
# 5508      VSP-206                 Newman (S-O)  18.419055
# 5509      VSP-206             Ray-Lawson (ANJ)   9.260406
# 5510      VSP-206               Sartelon (SLA)  13.145903
# 5511      VSP-206                Thimens (SLA)  14.341047
#
# [5512 rows x 3 columns]

# %%
final_df3 = pd.DataFrame(columns=['Removal Site 1', 'Removal Site 2', 'Distance'])

#Distances between removal sites among themselves
for i in range(len(removal_sites_longitudes)):
        for j in range(len(removal_sites_longitudes)):
                end_location = f"{removal_sites_longitudes[i]},{removal_sites_latitudes[i]}"
                end_name=df_removal_sites['NomSecteur'][i]

                start_location = f"{removal_sites_longitudes[j]},{removal_sites_latitudes[j]}" 
                start_name=df_removal_sites['NomSecteur'][j] 

                distance=main(start_location, end_location, mapbox_token)
                print(f"Distance between {start_name} and {end_name} is {distance} km")
                new_row = {'Removal Site 1': start_name, 'Removal Site 2': end_name, 'Distance': distance}
                new_row_df = pd.DataFrame([new_row])
                final_df3 = pd.concat([final_df3, new_row_df], ignore_index=True)


# start_location = f"{removal_sites_longitudes[0]},{removal_sites_latitudes[0]}"
# end_location = f"{disposal_sites_longitudes[0]},{disposal_sites_latitudes[0]}"    
# print(main(start_location, end_location, mapbox_token))
print(final_df3)
final_df3.to_excel('Distance_output.xlsx',index=False)
# Out:
# Distance between AHU-101 and AHU-101 is 0.0 km
# Distance between AHU-102 and AHU-101 is 0.354811 km
# Distance between AHU-103 and AHU-101 is 0.0 km
# Distance between AHU-104 and AHU-101 is 1.268511 km
# Distance between AHU-105 and AHU-101 is 4.929787 km
# Distance between AHU-106 and AHU-101 is 9.587783 km
# Distance between AHU-107 and AHU-101 is 6.067825 km
# Distance between AHU-201 and AHU-101 is 5.560923 km
# Distance between AHU-202 and AHU-101 is 2.74669 km
# Distance between ANJ-101 and AHU-101 is 20.401934 km
# Distance between ANJ-309 and AHU-101 is 19.169863 km
# Distance between ANJ-310 and AHU-101 is 18.498266 km
# Distance between ANJ-311 and AHU-101 is 16.139084 km
# Distance between ANJ-312 and AHU-101 is 18.613028999999997 km
# Distance between CDN-111 and AHU-101 is 14.443950999999998 km
# Distance between CDN-112 and AHU-101 is 12.530284 km
# Distance between CDN-113 and AHU-101 is 12.915651 km
# Distance between CDN-114 and AHU-101 is 11.125058999999998 km
# Distance between CDN-115 and AHU-101 is 11.973279 km
# Distance between CDN-116 and AHU-101 is 11.678136 km
# Distance between CDN-301 and AHU-101 is 13.510154 km
# Distance between IBI-301 and AHU-101 is 35.548230000000004 km
# Distance between LAC-102 and AHU-101 is 16.850493999999998 km
# Distance between LAC-104 and AHU-101 is 14.393433000000002 km
# Distance between LAC-305 and AHU-101 is 17.014307000000002 km
# Distance between LAC-306 and AHU-101 is 17.500691 km
# Distance between LAS-321 and AHU-101 is 20.58165 km
# Distance between LAS-323 and AHU-101 is 25.551783 km
# Distance between LAS-325 and AHU-101 is 23.219082 km
# Distance between LAS-326 and AHU-101 is 22.868781 km
# Distance between LAS-327 and AHU-101 is 22.688453000000003 km
# Distance between LAS-328 and AHU-101 is 23.166533 km
# Distance between LAS-329 and AHU-101 is 20.885705 km
# Distance between LAS-330 and AHU-101 is 22.931609 km
# Distance between LAS-333 and AHU-101 is 23.715711 km
# Distance between MHM-105 and AHU-101 is 20.493223 km
# Distance between MHM-106 and AHU-101 is 21.424764 km
# Distance between MHM-107 and AHU-101 is 18.231123 km
# Distance between MHM-108 and AHU-101 is 16.448115 km
# Distance between MHM-109 and AHU-101 is 16.331191999999998 km
# Distance between MHM-209 and AHU-101 is 16.713693 km
# Distance between MHM-210 and AHU-101 is 16.459326 km
# Distance between MHM-211 and AHU-101 is 19.057988 km
# Distance between MTN-102 and AHU-101 is 20.002938999999998 km
# Distance between MTN-103 and AHU-101 is 25.414236000000002 km
# Distance between MTN-104 and AHU-101 is 11.697689 km
# Distance between MTN-305 and AHU-101 is 10.259897 km
# Distance between MTN-307 and AHU-101 is 20.386129 km
# Distance between OUT-101 and AHU-101 is 10.103854 km
# Distance between PMR-101 and AHU-101 is 11.675707000000001 km
# Distance between PMR-102 and AHU-101 is 11.974596 km
# Distance between PMR-203 and AHU-101 is 12.316685999999999 km
# Distance between PMR-204 and AHU-101 is 14.754405 km
# Distance between PRF-304B and AHU-101 is 27.815969000000003 km
# Distance between PRF-304C and AHU-101 is 27.768324 km
# Distance between PRF-304D and AHU-101 is 25.814432 km
# Distance between PRF-304E and AHU-101 is 23.999776999999998 km
# Distance between PRF-304F and AHU-101 is 8.121041 km
# Distance between RDP-101 and AHU-101 is 27.702303 km
# Distance between RDP-102 and AHU-101 is 21.849107 km
# Distance between RDP-103 and AHU-101 is 27.702303 km
# Distance between RDP-105 and AHU-101 is 28.544338 km
# Distance between RDP-106 and AHU-101 is 28.258072 km
# Distance between RDP-107 and AHU-101 is 25.483531 km
# Distance between RDP-201 and AHU-101 is 23.800543 km
# Distance between RDP-202 and AHU-101 is 24.125369 km
# Distance between RDP-203 and AHU-101 is 25.483531 km
# Distance between RPP-101 and AHU-101 is 9.88134 km
# Distance between RPP-102 and AHU-101 is 13.73015 km
# Distance between RPP-103 and AHU-101 is 14.332795 km
# Distance between RPP-104 and AHU-101 is 15.526724 km
# Distance between RPP-201 and AHU-101 is 11.486679 km
# Distance between RPP-204 and AHU-101 is 11.708395000000001 km
# Distance between RPP-205 and AHU-101 is 13.766442 km
# Distance between SLA-363 and AHU-101 is 3.3239270000000003 km
# Distance between SLA-364 and AHU-101 is 4.977514 km
# Distance between SLA-365 and AHU-101 is 5.678895000000001 km
# Distance between SLA-366 and AHU-101 is 3.646531 km
# Distance between SLA-367 and AHU-101 is 3.745311 km
# Distance between SLA-368 and AHU-101 is 6.143485 km
# Distance between SLA-369 and AHU-101 is 6.0815079999999995 km
# Distance between SLA-370 and AHU-101 is 7.478233 km
# Distance between SLA-371 and AHU-101 is 4.907177 km
# Distance between SLE-109 and AHU-101 is 14.785968 km
# Distance between SLE-110 and AHU-101 is 16.427111 km
# Distance between SLE-111 and AHU-101 is 17.2054 km
# Distance between SLE-303 and AHU-101 is 16.572623 km
# Distance between SLE-304 and AHU-101 is 16.572623 km
# Distance between S-O-103 and AHU-101 is 22.112666 km
# Distance between S-O-104 and AHU-101 is 20.047044999999997 km
# Distance between S-O-201A and AHU-101 is 18.784217 km
# Distance between S-O-201B and AHU-101 is 17.60034 km
# Distance between VER-310A and AHU-101 is 20.517242 km
# Distance between VER-310B and AHU-101 is 22.665014 km
# Distance between VMA-109 and AHU-101 is 23.033715 km
# Distance between VMA-110 and AHU-101 is 19.600150000000003 km
# Distance between VMA-111 and AHU-101 is 14.063503 km
# Distance between VMA-306 and AHU-101 is 14.252861999999999 km
# Distance between VMA-307 and AHU-101 is 14.674519 km
# Distance between VSP-103 and AHU-101 is 10.508204 km
# Distance between VSP-104 and AHU-101 is 7.731603 km
# Distance between VSP-107 and AHU-101 is 10.252657 km
# Distance between VSP-108 and AHU-101 is 11.746829 km
# Distance between VSP-109 and AHU-101 is 7.535194000000001 km
# Distance between VSP-205 and AHU-101 is 9.802679 km
# Distance between VSP-206 and AHU-101 is 11.016103 km
# Distance between AHU-101 and AHU-102 is 0.296408 km
# Distance between AHU-102 and AHU-102 is 0.0 km
# Distance between AHU-103 and AHU-102 is 0.296408 km
# Distance between AHU-104 and AHU-102 is 0.9137000000000001 km
# Distance between AHU-105 and AHU-102 is 4.6167560000000005 km
# Distance between AHU-106 and AHU-102 is 9.274753 km
# Distance between AHU-107 and AHU-102 is 5.7547939999999995 km
# Distance between AHU-201 and AHU-102 is 5.2478940000000005 km
# Distance between AHU-202 and AHU-102 is 2.391879 km
# Distance between ANJ-101 and AHU-102 is 20.088901999999997 km
# Distance between ANJ-309 and AHU-102 is 18.856831999999997 km
# Distance between ANJ-310 and AHU-102 is 18.185234 km
# Distance between ANJ-311 and AHU-102 is 15.826056000000001 km
# Distance between ANJ-312 and AHU-102 is 18.3 km
# Distance between CDN-111 and AHU-102 is 14.130922 km
# Distance between CDN-112 and AHU-102 is 12.217254 km
# Distance between CDN-113 and AHU-102 is 12.602621 km
# Distance between CDN-114 and AHU-102 is 10.812029 km
# Distance between CDN-115 and AHU-102 is 11.660248 km
# Distance between CDN-116 and AHU-102 is 11.365105999999999 km
# Distance between CDN-301 and AHU-102 is 13.197125 km
# Distance between IBI-301 and AHU-102 is 35.235199 km
# Distance between LAC-102 and AHU-102 is 16.537467 km
# Distance between LAC-104 and AHU-102 is 14.080401 km
# Distance between LAC-305 and AHU-102 is 16.701275000000003 km
# Distance between LAC-306 and AHU-102 is 17.18766 km
# Distance between LAS-321 and AHU-102 is 20.268617 km
# Distance between LAS-323 and AHU-102 is 25.238752 km
# Distance between LAS-325 and AHU-102 is 22.906050999999998 km
# Distance between LAS-326 and AHU-102 is 22.555754 km
# Distance between LAS-327 and AHU-102 is 22.375422 km
# Distance between LAS-328 and AHU-102 is 22.8535 km
# Distance between LAS-329 and AHU-102 is 20.572678 km
# Distance between LAS-330 and AHU-102 is 22.61858 km
# Distance between LAS-333 and AHU-102 is 23.402684 km
# Distance between MHM-105 and AHU-102 is 20.180193 km
# Distance between MHM-106 and AHU-102 is 19.821479 km
# Distance between MHM-107 and AHU-102 is 17.918092 km
# Distance between MHM-108 and AHU-102 is 16.135084 km
# Distance between MHM-109 and AHU-102 is 16.018159999999998 km
# Distance between MHM-209 and AHU-102 is 16.400662 km
# Distance between MHM-210 and AHU-102 is 16.146298 km
# Distance between MHM-211 and AHU-102 is 18.744957 km
# Distance between MTN-102 and AHU-102 is 19.68991 km
# Distance between MTN-103 and AHU-102 is 25.101207 km
# Distance between MTN-104 and AHU-102 is 11.38466 km
# Distance between MTN-305 and AHU-102 is 9.946867000000001 km
# Distance between MTN-307 and AHU-102 is 20.0731 km
# Distance between OUT-101 and AHU-102 is 9.790825 km
# Distance between PMR-101 and AHU-102 is 11.362675999999999 km
# Distance between PMR-102 and AHU-102 is 11.661566 km
# Distance between PMR-203 and AHU-102 is 12.003655 km
# Distance between PMR-204 and AHU-102 is 14.441375 km
# Distance between PRF-304B and AHU-102 is 27.502941 km
# Distance between PRF-304C and AHU-102 is 27.455293 km
# Distance between PRF-304D and AHU-102 is 25.501403999999997 km
# Distance between PRF-304E and AHU-102 is 23.686746 km
# Distance between PRF-304F and AHU-102 is 8.088267 km
# Distance between RDP-101 and AHU-102 is 27.389275 km
# Distance between RDP-102 and AHU-102 is 21.536078 km
# Distance between RDP-103 and AHU-102 is 27.389275 km
# Distance between RDP-105 and AHU-102 is 28.231309 km
# Distance between RDP-106 and AHU-102 is 27.945043000000002 km
# Distance between RDP-107 and AHU-102 is 25.170502 km
# Distance between RDP-201 and AHU-102 is 23.487512 km
# Distance between RDP-202 and AHU-102 is 23.812342 km
# Distance between RDP-203 and AHU-102 is 25.170502 km
# Distance between RPP-101 and AHU-102 is 9.56831 km
# Distance between RPP-102 and AHU-102 is 13.417119000000001 km
# Distance between RPP-103 and AHU-102 is 14.019765 km
# Distance between RPP-104 and AHU-102 is 15.213693 km
# Distance between RPP-201 and AHU-102 is 11.173647 km
# Distance between RPP-204 and AHU-102 is 11.395363999999999 km
# Distance between RPP-205 and AHU-102 is 13.453412 km
# Distance between SLA-363 and AHU-102 is 3.185624 km
# Distance between SLA-364 and AHU-102 is 5.789004 km
# Distance between SLA-365 and AHU-102 is 5.540591 km
# Distance between SLA-366 and AHU-102 is 3.333501 km
# Distance between SLA-367 and AHU-102 is 3.607008 km
# Distance between SLA-368 and AHU-102 is 6.005182 km
# Distance between SLA-369 and AHU-102 is 5.929815 km
# Distance between SLA-370 and AHU-102 is 7.44546 km
# Distance between SLA-371 and AHU-102 is 4.594145999999999 km
# Distance between SLE-109 and AHU-102 is 14.472937 km
# Distance between SLE-110 and AHU-102 is 16.114082 km
# Distance between SLE-111 and AHU-102 is 16.892371 km
# Distance between SLE-303 and AHU-102 is 16.259594 km
# Distance between SLE-304 and AHU-102 is 16.259594 km
# Distance between S-O-103 and AHU-102 is 21.799636999999997 km
# Distance between S-O-104 and AHU-102 is 19.734014 km
# Distance between S-O-201A and AHU-102 is 18.471184 km
# Distance between S-O-201B and AHU-102 is 17.287311000000003 km
# Distance between VER-310A and AHU-102 is 20.204211 km
# Distance between VER-310B and AHU-102 is 22.351986 km
# Distance between VMA-109 and AHU-102 is 24.112849999999998 km
# Distance between VMA-110 and AHU-102 is 19.287121 km
# Distance between VMA-111 and AHU-102 is 13.750474 km
# Distance between VMA-306 and AHU-102 is 13.939832000000001 km
# Distance between VMA-307 and AHU-102 is 14.361488999999999 km
# Distance between VSP-103 and AHU-102 is 10.195174000000002 km
# Distance between VSP-104 and AHU-102 is 7.418573 km
# Distance between VSP-107 and AHU-102 is 9.939628 km
# Distance between VSP-108 and AHU-102 is 11.433799 km
# Distance between VSP-109 and AHU-102 is 7.222165 km
# Distance between VSP-205 and AHU-102 is 9.489649 km
# Distance between VSP-206 and AHU-102 is 10.703072 km
# Distance between AHU-101 and AHU-103 is 0.0 km
# Distance between AHU-102 and AHU-103 is 0.354811 km
# Distance between AHU-103 and AHU-103 is 0.0 km
# Distance between AHU-104 and AHU-103 is 1.268511 km
# Distance between AHU-105 and AHU-103 is 4.929787 km
# Distance between AHU-106 and AHU-103 is 9.587783 km
# Distance between AHU-107 and AHU-103 is 6.067825 km
# Distance between AHU-201 and AHU-103 is 5.560923 km
# Distance between AHU-202 and AHU-103 is 2.74669 km
# Distance between ANJ-101 and AHU-103 is 20.401934 km
# Distance between ANJ-309 and AHU-103 is 19.169863 km
# Distance between ANJ-310 and AHU-103 is 18.498266 km
# Distance between ANJ-311 and AHU-103 is 16.139084 km
# Distance between ANJ-312 and AHU-103 is 18.613028999999997 km
# Distance between CDN-111 and AHU-103 is 14.443950999999998 km
# Distance between CDN-112 and AHU-103 is 12.530284 km
# Distance between CDN-113 and AHU-103 is 12.915651 km
# Distance between CDN-114 and AHU-103 is 11.125058999999998 km
# Distance between CDN-115 and AHU-103 is 11.973279 km
# Distance between CDN-116 and AHU-103 is 11.678136 km
# Distance between CDN-301 and AHU-103 is 13.510154 km
# Distance between IBI-301 and AHU-103 is 35.548230000000004 km
# Distance between LAC-102 and AHU-103 is 16.850493999999998 km
# Distance between LAC-104 and AHU-103 is 14.393433000000002 km
# Distance between LAC-305 and AHU-103 is 17.014307000000002 km
# Distance between LAC-306 and AHU-103 is 17.500691 km
# Distance between LAS-321 and AHU-103 is 20.58165 km
# Distance between LAS-323 and AHU-103 is 25.551783 km
# Distance between LAS-325 and AHU-103 is 23.219082 km
# Distance between LAS-326 and AHU-103 is 22.868781 km
# Distance between LAS-327 and AHU-103 is 22.688453000000003 km
# Distance between LAS-328 and AHU-103 is 23.166533 km
# Distance between LAS-329 and AHU-103 is 20.885705 km
# Distance between LAS-330 and AHU-103 is 22.931609 km
# Distance between LAS-333 and AHU-103 is 23.715711 km
# Distance between MHM-105 and AHU-103 is 20.493223 km
# Distance between MHM-106 and AHU-103 is 21.424764 km
# Distance between MHM-107 and AHU-103 is 18.231123 km
# Distance between MHM-108 and AHU-103 is 16.448115 km
# Distance between MHM-109 and AHU-103 is 16.331191999999998 km
# Distance between MHM-209 and AHU-103 is 16.713693 km
# Distance between MHM-210 and AHU-103 is 16.459326 km
# Distance between MHM-211 and AHU-103 is 19.057988 km
# Distance between MTN-102 and AHU-103 is 20.002938999999998 km
# Distance between MTN-103 and AHU-103 is 25.414236000000002 km
# Distance between MTN-104 and AHU-103 is 11.697689 km
# Distance between MTN-305 and AHU-103 is 10.259897 km
# Distance between MTN-307 and AHU-103 is 20.386129 km
# Distance between OUT-101 and AHU-103 is 10.103854 km
# Distance between PMR-101 and AHU-103 is 11.675707000000001 km
# Distance between PMR-102 and AHU-103 is 11.974596 km
# Distance between PMR-203 and AHU-103 is 12.316685999999999 km
# Distance between PMR-204 and AHU-103 is 14.754405 km
# Distance between PRF-304B and AHU-103 is 27.815969000000003 km
# Distance between PRF-304C and AHU-103 is 27.768324 km
# Distance between PRF-304D and AHU-103 is 25.814432 km
# Distance between PRF-304E and AHU-103 is 23.999776999999998 km
# Distance between PRF-304F and AHU-103 is 8.121041 km
# Distance between RDP-101 and AHU-103 is 27.702303 km
# Distance between RDP-102 and AHU-103 is 21.849107 km
# Distance between RDP-103 and AHU-103 is 27.702303 km
# Distance between RDP-105 and AHU-103 is 28.544338 km
# Distance between RDP-106 and AHU-103 is 28.258072 km
# Distance between RDP-107 and AHU-103 is 25.483531 km
# Distance between RDP-201 and AHU-103 is 23.800543 km
# Distance between RDP-202 and AHU-103 is 24.125369 km
# Distance between RDP-203 and AHU-103 is 25.483531 km
# Distance between RPP-101 and AHU-103 is 9.88134 km
# Distance between RPP-102 and AHU-103 is 13.73015 km
# Distance between RPP-103 and AHU-103 is 14.332795 km
# Distance between RPP-104 and AHU-103 is 15.526724 km
# Distance between RPP-201 and AHU-103 is 11.486679 km
# Distance between RPP-204 and AHU-103 is 11.708395000000001 km
# Distance between RPP-205 and AHU-103 is 13.766442 km
# Distance between SLA-363 and AHU-103 is 3.3239270000000003 km
# Distance between SLA-364 and AHU-103 is 4.977514 km
# Distance between SLA-365 and AHU-103 is 5.678895000000001 km
# Distance between SLA-366 and AHU-103 is 3.646531 km
# Distance between SLA-367 and AHU-103 is 3.745311 km
# Distance between SLA-368 and AHU-103 is 6.143485 km
# Distance between SLA-369 and AHU-103 is 6.0815079999999995 km
# Distance between SLA-370 and AHU-103 is 7.478233 km
# Distance between SLA-371 and AHU-103 is 4.907177 km
# Distance between SLE-109 and AHU-103 is 14.785968 km
# Distance between SLE-110 and AHU-103 is 16.427111 km
# Distance between SLE-111 and AHU-103 is 17.2054 km
# Distance between SLE-303 and AHU-103 is 16.572623 km
# Distance between SLE-304 and AHU-103 is 16.572623 km
# Distance between S-O-103 and AHU-103 is 22.112666 km
# Distance between S-O-104 and AHU-103 is 20.047044999999997 km
# Distance between S-O-201A and AHU-103 is 18.784217 km
# Distance between S-O-201B and AHU-103 is 17.60034 km
# Distance between VER-310A and AHU-103 is 20.517242 km
# Distance between VER-310B and AHU-103 is 22.665014 km
# Distance between VMA-109 and AHU-103 is 23.033715 km
# Distance between VMA-110 and AHU-103 is 19.600150000000003 km
# Distance between VMA-111 and AHU-103 is 14.063503 km
# Distance between VMA-306 and AHU-103 is 14.252861999999999 km
# Distance between VMA-307 and AHU-103 is 14.674519 km
# Distance between VSP-103 and AHU-103 is 10.508204 km
# Distance between VSP-104 and AHU-103 is 7.731603 km
# Distance between VSP-107 and AHU-103 is 10.252657 km
# Distance between VSP-108 and AHU-103 is 11.746829 km
# Distance between VSP-109 and AHU-103 is 7.535194000000001 km
# Distance between VSP-205 and AHU-103 is 9.802679 km
# Distance between VSP-206 and AHU-103 is 11.016103 km
# Distance between AHU-101 and AHU-104 is 1.254601 km
# Distance between AHU-102 and AHU-104 is 0.958192 km
# Distance between AHU-103 and AHU-104 is 1.254601 km
# Distance between AHU-104 and AHU-104 is 0.0 km
# Distance between AHU-105 and AHU-104 is 3.0026610000000002 km
# Distance between AHU-106 and AHU-104 is 7.228506 km
# Distance between AHU-107 and AHU-104 is 3.708549 km
# Distance between AHU-201 and AHU-104 is 3.201647 km
# Distance between AHU-202 and AHU-104 is 1.47818 km
# Distance between ANJ-101 and AHU-104 is 20.083205000000003 km
# Distance between ANJ-309 and AHU-104 is 18.851133 km
# Distance between ANJ-310 and AHU-104 is 18.179537 km
# Distance between ANJ-311 and AHU-104 is 15.820358 km
# Distance between ANJ-312 and AHU-104 is 18.294303 km
# Distance between CDN-111 and AHU-104 is 14.125225 km
# Distance between CDN-112 and AHU-104 is 12.211557 km
# Distance between CDN-113 and AHU-104 is 12.596924000000001 km
# Distance between CDN-114 and AHU-104 is 10.806331 km
# Distance between CDN-115 and AHU-104 is 11.654551 km
# Distance between CDN-116 and AHU-104 is 11.359408 km
# Distance between CDN-301 and AHU-104 is 13.191427 km
# Distance between IBI-301 and AHU-104 is 35.2295 km
# Distance between LAC-102 and AHU-104 is 16.53177 km
# Distance between LAC-104 and AHU-104 is 14.074704 km
# Distance between LAC-305 and AHU-104 is 16.695578 km
# Distance between LAC-306 and AHU-104 is 17.181963 km
# Distance between LAS-321 and AHU-104 is 20.262919999999998 km
# Distance between LAS-323 and AHU-104 is 25.233055 km
# Distance between LAS-325 and AHU-104 is 22.900354 km
# Distance between LAS-326 and AHU-104 is 22.550057000000002 km
# Distance between LAS-327 and AHU-104 is 22.369725 km
# Distance between LAS-328 and AHU-104 is 22.847803 km
# Distance between LAS-329 and AHU-104 is 20.56698 km
# Distance between LAS-330 and AHU-104 is 22.612881 km
# Distance between LAS-333 and AHU-104 is 23.396986000000002 km
# Distance between MHM-105 and AHU-104 is 20.174494 km
# Distance between MHM-106 and AHU-104 is 19.815780999999998 km
# Distance between MHM-107 and AHU-104 is 17.912395 km
# Distance between MHM-108 and AHU-104 is 16.129387 km
# Distance between MHM-109 and AHU-104 is 16.012463 km
# Distance between MHM-209 and AHU-104 is 16.394965 km
# Distance between MHM-210 and AHU-104 is 16.140599 km
# Distance between MHM-211 and AHU-104 is 18.739259999999998 km
# Distance between MTN-102 and AHU-104 is 19.684210999999998 km
# Distance between MTN-103 and AHU-104 is 11.943451 km
# Distance between MTN-104 and AHU-104 is 9.338413000000001 km
# Distance between MTN-305 and AHU-104 is 7.900621 km
# Distance between MTN-307 and AHU-104 is 20.067401999999998 km
# Distance between OUT-101 and AHU-104 is 9.785127000000001 km
# Distance between PMR-101 and AHU-104 is 11.356978999999999 km
# Distance between PMR-102 and AHU-104 is 11.655868 km
# Distance between PMR-203 and AHU-104 is 11.997958 km
# Distance between PMR-204 and AHU-104 is 14.435677 km
# Distance between PRF-304B and AHU-104 is 27.497244 km
# Distance between PRF-304C and AHU-104 is 27.449594 km
# Distance between PRF-304D and AHU-104 is 25.495705 km
# Distance between PRF-304E and AHU-104 is 23.681048999999998 km
# Distance between PRF-304F and AHU-104 is 8.082569000000001 km
# Distance between RDP-101 and AHU-104 is 23.735293000000002 km
# Distance between RDP-102 and AHU-104 is 21.530381000000002 km
# Distance between RDP-103 and AHU-104 is 23.735293000000002 km
# Distance between RDP-105 and AHU-104 is 28.225611 km
# Distance between RDP-106 and AHU-104 is 27.939346 km
# Distance between RDP-107 and AHU-104 is 25.164805 km
# Distance between RDP-201 and AHU-104 is 23.481814 km
# Distance between RDP-202 and AHU-104 is 23.806643 km
# Distance between RDP-203 and AHU-104 is 25.164805 km
# Distance between RPP-101 and AHU-104 is 9.562612 km
# Distance between RPP-102 and AHU-104 is 13.411422 km
# Distance between RPP-103 and AHU-104 is 14.014068 km
# Distance between RPP-104 and AHU-104 is 15.207995 km
# Distance between RPP-201 and AHU-104 is 11.167950000000001 km
# Distance between RPP-204 and AHU-104 is 11.389667 km
# Distance between RPP-205 and AHU-104 is 13.447715 km
# Distance between SLA-363 and AHU-104 is 3.285457 km
# Distance between SLA-364 and AHU-104 is 5.783306 km
# Distance between SLA-365 and AHU-104 is 5.640423 km
# Distance between SLA-366 and AHU-104 is 3.327804 km
# Distance between SLA-367 and AHU-104 is 5.036063 km
# Distance between SLA-368 and AHU-104 is 6.105014 km
# Distance between SLA-369 and AHU-104 is 6.043037999999999 km
# Distance between SLA-370 and AHU-104 is 7.439763 km
# Distance between SLA-371 and AHU-104 is 4.58845 km
# Distance between SLE-109 and AHU-104 is 14.467239 km
# Distance between SLE-110 and AHU-104 is 16.108383 km
# Distance between SLE-111 and AHU-104 is 16.886674 km
# Distance between SLE-303 and AHU-104 is 16.253896 km
# Distance between SLE-304 and AHU-104 is 16.253896 km
# Distance between S-O-103 and AHU-104 is 21.793938999999998 km
# Distance between S-O-104 and AHU-104 is 19.728316 km
# Distance between S-O-201A and AHU-104 is 18.465486000000002 km
# Distance between S-O-201B and AHU-104 is 17.281613 km
# Distance between VER-310A and AHU-104 is 20.198514 km
# Distance between VER-310B and AHU-104 is 22.346289000000002 km
# Distance between VMA-109 and AHU-104 is 24.10715 km
# Distance between VMA-110 and AHU-104 is 19.281426 km
# Distance between VMA-111 and AHU-104 is 13.744774999999999 km
# Distance between VMA-306 and AHU-104 is 13.934135 km
# Distance between VMA-307 and AHU-104 is 14.355791 km
# Distance between VSP-103 and AHU-104 is 10.189476 km
# Distance between VSP-104 and AHU-104 is 5.372327 km
# Distance between VSP-107 and AHU-104 is 9.93393 km
# Distance between VSP-108 and AHU-104 is 11.428102 km
# Distance between VSP-109 and AHU-104 is 7.216467 km
# Distance between VSP-205 and AHU-104 is 7.443403 km
# Distance between VSP-206 and AHU-104 is 10.697375 km
# Distance between AHU-101 and AHU-105 is 4.8727529999999994 km
# Distance between AHU-102 and AHU-105 is 4.663962000000001 km
# Distance between AHU-103 and AHU-105 is 4.8727529999999994 km
# Distance between AHU-104 and AHU-105 is 4.126671999999999 km
# Distance between AHU-105 and AHU-105 is 0.0 km
# Distance between AHU-106 and AHU-105 is 6.888343 km
# Distance between AHU-107 and AHU-105 is 1.268989 km
# Distance between AHU-201 and AHU-105 is 2.861485 km
# Distance between AHU-202 and AHU-105 is 2.265872 km
# Distance between ANJ-101 and AHU-105 is 15.482558999999998 km
# Distance between ANJ-309 and AHU-105 is 14.250487 km
# Distance between ANJ-310 and AHU-105 is 13.578891 km
# Distance between ANJ-311 and AHU-105 is 11.21971 km
# Distance between ANJ-312 and AHU-105 is 13.693656 km
# Distance between CDN-111 and AHU-105 is 12.623762000000001 km
# Distance between CDN-112 and AHU-105 is 10.710094 km
# Distance between CDN-113 and AHU-105 is 11.095460999999998 km
# Distance between CDN-114 and AHU-105 is 9.304868 km
# Distance between CDN-115 and AHU-105 is 7.4296999999999995 km
# Distance between CDN-116 and AHU-105 is 7.134557 km
# Distance between CDN-301 and AHU-105 is 11.689964 km
# Distance between IBI-301 and AHU-105 is 33.728038999999995 km
# Distance between LAC-102 and AHU-105 is 15.030305 km
# Distance between LAC-104 and AHU-105 is 12.573242 km
# Distance between LAC-305 and AHU-105 is 15.194113999999999 km
# Distance between LAC-306 and AHU-105 is 15.680499 km
# Distance between LAS-321 and AHU-105 is 18.761459 km
# Distance between LAS-323 and AHU-105 is 23.731592 km
# Distance between LAS-325 and AHU-105 is 21.398889 km
# Distance between LAS-326 and AHU-105 is 21.048594 km
# Distance between LAS-327 and AHU-105 is 20.868261999999998 km
# Distance between LAS-328 and AHU-105 is 21.34634 km
# Distance between LAS-329 and AHU-105 is 19.065516 km
# Distance between LAS-330 and AHU-105 is 21.11142 km
# Distance between LAS-333 and AHU-105 is 21.895521000000002 km
# Distance between MHM-105 and AHU-105 is 15.573848 km
# Distance between MHM-106 and AHU-105 is 15.215134 km
# Distance between MHM-107 and AHU-105 is 13.311748 km
# Distance between MHM-108 and AHU-105 is 11.528739999999999 km
# Distance between MHM-109 and AHU-105 is 11.411816 km
# Distance between MHM-209 and AHU-105 is 11.794317999999999 km
# Distance between MHM-210 and AHU-105 is 11.539952 km
# Distance between MHM-211 and AHU-105 is 14.138613 km
# Distance between MTN-102 and AHU-105 is 15.083564 km
# Distance between MTN-103 and AHU-105 is 11.542991 km
# Distance between MTN-104 and AHU-105 is 8.998251 km
# Distance between MTN-305 and AHU-105 is 5.776428 km
# Distance between MTN-307 and AHU-105 is 15.466755 km
# Distance between OUT-101 and AHU-105 is 6.07737 km
# Distance between PMR-101 and AHU-105 is 6.215196 km
# Distance between PMR-102 and AHU-105 is 7.279935999999999 km
# Distance between PMR-203 and AHU-105 is 6.856175 km
# Distance between PMR-204 and AHU-105 is 9.835030000000001 km
# Distance between PRF-304B and AHU-105 is 25.995779 km
# Distance between PRF-304C and AHU-105 is 25.948133000000002 km
# Distance between PRF-304D and AHU-105 is 23.994244 km
# Distance between PRF-304E and AHU-105 is 22.179586 km
# Distance between PRF-304F and AHU-105 is 9.728547 km
# Distance between RDP-101 and AHU-105 is 23.334836 km
# Distance between RDP-102 and AHU-105 is 16.929732 km
# Distance between RDP-103 and AHU-105 is 23.334836 km
# Distance between RDP-105 and AHU-105 is 23.624963 km
# Distance between RDP-106 and AHU-105 is 23.338697 km
# Distance between RDP-107 and AHU-105 is 20.564158 km
# Distance between RDP-201 and AHU-105 is 18.881168000000002 km
# Distance between RDP-202 and AHU-105 is 19.205996 km
# Distance between RDP-203 and AHU-105 is 20.564158 km
# Distance between RPP-101 and AHU-105 is 4.5651530000000005 km
# Distance between RPP-102 and AHU-105 is 8.810775 km
# Distance between RPP-103 and AHU-105 is 9.413421 km
# Distance between RPP-104 and AHU-105 is 10.60735 km
# Distance between RPP-201 and AHU-105 is 4.546131999999999 km
# Distance between RPP-204 and AHU-105 is 5.718827 km
# Distance between RPP-205 and AHU-105 is 8.847068 km
# Distance between SLA-363 and AHU-105 is 5.5103990000000005 km
# Distance between SLA-364 and AHU-105 is 4.652988000000001 km
# Distance between SLA-365 and AHU-105 is 7.286401 km
# Distance between SLA-366 and AHU-105 is 3.832913 km
# Distance between SLA-367 and AHU-105 is 8.034791 km
# Distance between SLA-368 and AHU-105 is 7.750992 km
# Distance between SLA-369 and AHU-105 is 4.73034 km
# Distance between SLA-370 and AHU-105 is 6.617834 km
# Distance between SLA-371 and AHU-105 is 3.394672 km
# Distance between SLE-109 and AHU-105 is 9.866593 km
# Distance between SLE-110 and AHU-105 is 11.507736999999999 km
# Distance between SLE-111 and AHU-105 is 12.286026 km
# Distance between SLE-303 and AHU-105 is 11.653249 km
# Distance between SLE-304 and AHU-105 is 11.653249 km
# Distance between S-O-103 and AHU-105 is 20.292475 km
# Distance between S-O-104 and AHU-105 is 18.226854 km
# Distance between S-O-201A and AHU-105 is 16.964023 km
# Distance between S-O-201B and AHU-105 is 15.780149 km
# Distance between VER-310A and AHU-105 is 18.697051 km
# Distance between VER-310B and AHU-105 is 20.844824 km
# Distance between VMA-109 and AHU-105 is 11.656559 km
# Distance between VMA-110 and AHU-105 is 17.779961 km
# Distance between VMA-111 and AHU-105 is 8.255618 km
# Distance between VMA-306 and AHU-105 is 8.828885 km
# Distance between VMA-307 and AHU-105 is 9.456406999999999 km
# Distance between VSP-103 and AHU-105 is 3.464065 km
# Distance between VSP-104 and AHU-105 is 2.999831 km
# Distance between VSP-107 and AHU-105 is 4.26309 km
# Distance between VSP-108 and AHU-105 is 4.70269 km
# Distance between VSP-109 and AHU-105 is 1.9509210000000001 km
# Distance between VSP-205 and AHU-105 is 4.424151 km
# Distance between VSP-206 and AHU-105 is 6.096729 km
# Distance between AHU-101 and AHU-106 is 7.0679430000000005 km
# Distance between AHU-102 and AHU-106 is 6.859152 km
# Distance between AHU-103 and AHU-106 is 7.0679430000000005 km
# Distance between AHU-104 and AHU-106 is 5.448404 km
# Distance between AHU-105 and AHU-106 is 4.348122 km
# Distance between AHU-106 and AHU-106 is 0.0 km
# Distance between AHU-107 and AHU-106 is 3.488259 km
# Distance between AHU-201 and AHU-106 is 2.2869319999999997 km
# Distance between AHU-202 and AHU-106 is 3.587604 km
# Distance between ANJ-101 and AHU-106 is 14.254749 km
# Distance between ANJ-309 and AHU-106 is 13.022680000000001 km
# Distance between ANJ-310 and AHU-106 is 12.351083000000001 km
# Distance between ANJ-311 and AHU-106 is 11.362949 km
# Distance between ANJ-312 and AHU-106 is 7.887739 km
# Distance between CDN-111 and AHU-106 is 16.402386999999997 km
# Distance between CDN-112 and AHU-106 is 14.488719 km
# Distance between CDN-113 and AHU-106 is 14.874086 km
# Distance between CDN-114 and AHU-106 is 13.083492 km
# Distance between CDN-115 and AHU-106 is 13.931713 km
# Distance between CDN-116 and AHU-106 is 13.636571 km
# Distance between CDN-301 and AHU-106 is 15.468589 km
# Distance between IBI-301 and AHU-106 is 37.506660000000004 km
# Distance between LAC-102 and AHU-106 is 18.80893 km
# Distance between LAC-104 and AHU-106 is 16.351866 km
# Distance between LAC-305 and AHU-106 is 28.146762 km
# Distance between LAC-306 and AHU-106 is 19.459122999999998 km
# Distance between LAS-321 and AHU-106 is 22.540081999999998 km
# Distance between LAS-323 and AHU-106 is 27.510217 km
# Distance between LAS-325 and AHU-106 is 25.177516 km
# Distance between LAS-326 and AHU-106 is 24.827219 km
# Distance between LAS-327 and AHU-106 is 24.646887 km
# Distance between LAS-328 and AHU-106 is 25.124965 km
# Distance between LAS-329 and AHU-106 is 22.844141 km
# Distance between LAS-330 and AHU-106 is 24.890044999999997 km
# Distance between LAS-333 and AHU-106 is 25.674146 km
# Distance between MHM-105 and AHU-106 is 14.34604 km
# Distance between MHM-106 and AHU-106 is 13.987325 km
# Distance between MHM-107 and AHU-106 is 12.083939 km
# Distance between MHM-108 and AHU-106 is 10.300931 km
# Distance between MHM-109 and AHU-106 is 9.781691 km
# Distance between MHM-209 and AHU-106 is 10.562458000000001 km
# Distance between MHM-210 and AHU-106 is 10.308091000000001 km
# Distance between MHM-211 and AHU-106 is 12.910804 km
# Distance between MTN-102 and AHU-106 is 7.860653 km
# Distance between MTN-103 and AHU-106 is 7.852423 km
# Distance between MTN-104 and AHU-106 is 5.307683 km
# Distance between MTN-305 and AHU-106 is 3.86989 km
# Distance between MTN-307 and AHU-106 is 8.227032999999999 km
# Distance between OUT-101 and AHU-106 is 11.186319 km
# Distance between PMR-101 and AHU-106 is 7.759705 km
# Distance between PMR-102 and AHU-106 is 10.635326 km
# Distance between PMR-203 and AHU-106 is 8.008794 km
# Distance between PMR-204 and AHU-106 is 8.591921000000001 km
# Distance between PRF-304B and AHU-106 is 29.137742 km
# Distance between PRF-304C and AHU-106 is 29.090098 km
# Distance between PRF-304D and AHU-106 is 30.666471 km
# Distance between PRF-304E and AHU-106 is 28.701563999999998 km
# Distance between PRF-304F and AHU-106 is 11.964559999999999 km
# Distance between RDP-101 and AHU-106 is 10.960246 km
# Distance between RDP-102 and AHU-106 is 10.717807 km
# Distance between RDP-103 and AHU-106 is 10.960246 km
# Distance between RDP-105 and AHU-106 is 22.397153999999997 km
# Distance between RDP-106 and AHU-106 is 22.110886999999998 km
# Distance between RDP-107 and AHU-106 is 19.33635 km
# Distance between RDP-201 and AHU-106 is 11.772001 km
# Distance between RDP-202 and AHU-106 is 14.802955 km
# Distance between RDP-203 and AHU-106 is 19.33635 km
# Distance between RPP-101 and AHU-106 is 7.6250990000000005 km
# Distance between RPP-102 and AHU-106 is 7.578915 km
# Distance between RPP-103 and AHU-106 is 9.556661 km
# Distance between RPP-104 and AHU-106 is 9.375487999999999 km
# Distance between RPP-201 and AHU-106 is 6.1178680000000005 km
# Distance between RPP-204 and AHU-106 is 5.525926999999999 km
# Distance between RPP-205 and AHU-106 is 7.280923 km
# Distance between SLA-363 and AHU-106 is 7.746412 km
# Distance between SLA-364 and AHU-106 is 8.524429 km
# Distance between SLA-365 and AHU-106 is 9.522414000000001 km
# Distance between SLA-366 and AHU-106 is 6.068926 km
# Distance between SLA-367 and AHU-106 is 10.270804 km
# Distance between SLA-368 and AHU-106 is 9.987004 km
# Distance between SLA-369 and AHU-106 is 8.665239 km
# Distance between SLA-370 and AHU-106 is 11.321754 km
# Distance between SLA-371 and AHU-106 is 7.329572 km
# Distance between SLE-109 and AHU-106 is 8.638783 km
# Distance between SLE-110 and AHU-106 is 6.696939 km
# Distance between SLE-111 and AHU-106 is 7.475228 km
# Distance between SLE-303 and AHU-106 is 9.798903000000001 km
# Distance between SLE-304 and AHU-106 is 9.798903000000001 km
# Distance between S-O-103 and AHU-106 is 24.071099999999998 km
# Distance between S-O-104 and AHU-106 is 22.00548 km
# Distance between S-O-201A and AHU-106 is 20.742648000000003 km
# Distance between S-O-201B and AHU-106 is 19.558775 km
# Distance between VER-310A and AHU-106 is 22.475676 km
# Distance between VER-310B and AHU-106 is 19.281125 km
# Distance between VMA-109 and AHU-106 is 13.798799 km
# Distance between VMA-110 and AHU-106 is 21.558586 km
# Distance between VMA-111 and AHU-106 is 11.256126 km
# Distance between VMA-306 and AHU-106 is 10.518073000000001 km
# Distance between VMA-307 and AHU-106 is 11.136657 km
# Distance between VSP-103 and AHU-106 is 5.4643999999999995 km
# Distance between VSP-104 and AHU-106 is 1.525738 km
# Distance between VSP-107 and AHU-106 is 4.07019 km
# Distance between VSP-108 and AHU-106 is 6.703024999999999 km
# Distance between VSP-109 and AHU-106 is 5.588640000000001 km
# Distance between VSP-205 and AHU-106 is 3.412673 km
# Distance between VSP-206 and AHU-106 is 4.853619 km
# Distance between AHU-101 and AHU-107 is 6.331243000000001 km
# Distance between AHU-102 and AHU-107 is 4.906399 km
# Distance between AHU-103 and AHU-107 is 6.331243000000001 km
# Distance between AHU-104 and AHU-107 is 4.711704 km
# Distance between AHU-105 and AHU-107 is 1.62927 km
# Distance between AHU-106 and AHU-107 is 6.447668999999999 km
# Distance between AHU-107 and AHU-107 is 0.0 km
# Distance between AHU-201 and AHU-107 is 2.42081 km
# Distance between AHU-202 and AHU-107 is 2.850904 km
# Distance between ANJ-101 and AHU-107 is 13.502537 km
# Distance between ANJ-309 and AHU-107 is 12.270467 km
# Distance between ANJ-310 and AHU-107 is 11.598869 km
# Distance between ANJ-311 and AHU-107 is 9.239688 km
# Distance between ANJ-312 and AHU-107 is 11.713635 km
# Distance between CDN-111 and AHU-107 is 13.49276 km
# Distance between CDN-112 and AHU-107 is 11.579091 km
# Distance between CDN-113 and AHU-107 is 11.964458 km
# Distance between CDN-114 and AHU-107 is 10.173866 km
# Distance between CDN-115 and AHU-107 is 7.316771 km
# Distance between CDN-116 and AHU-107 is 7.02163 km
# Distance between CDN-301 and AHU-107 is 12.558962 km
# Distance between IBI-301 and AHU-107 is 34.597035000000005 km
# Distance between LAC-102 and AHU-107 is 15.899303 km
# Distance between LAC-104 and AHU-107 is 13.442238999999999 km
# Distance between LAC-305 and AHU-107 is 16.063112 km
# Distance between LAC-306 and AHU-107 is 16.549498 km
# Distance between LAS-321 and AHU-107 is 19.630455 km
# Distance between LAS-323 and AHU-107 is 24.60059 km
# Distance between LAS-325 and AHU-107 is 22.267889 km
# Distance between LAS-326 and AHU-107 is 21.917592 km
# Distance between LAS-327 and AHU-107 is 21.73726 km
# Distance between LAS-328 and AHU-107 is 22.215338 km
# Distance between LAS-329 and AHU-107 is 19.934516 km
# Distance between LAS-330 and AHU-107 is 21.980418 km
# Distance between LAS-333 and AHU-107 is 22.764521000000002 km
# Distance between MHM-105 and AHU-107 is 13.593827 km
# Distance between MHM-106 and AHU-107 is 13.235111000000002 km
# Distance between MHM-107 and AHU-107 is 11.331727 km
# Distance between MHM-108 and AHU-107 is 9.548718999999998 km
# Distance between MHM-109 and AHU-107 is 9.431795 km
# Distance between MHM-209 and AHU-107 is 9.814297 km
# Distance between MHM-210 and AHU-107 is 9.559931 km
# Distance between MHM-211 and AHU-107 is 12.158592 km
# Distance between MTN-102 and AHU-107 is 13.103545 km
# Distance between MTN-103 and AHU-107 is 15.000652 km
# Distance between MTN-104 and AHU-107 is 8.557575 km
# Distance between MTN-305 and AHU-107 is 4.913926 km
# Distance between MTN-307 and AHU-107 is 13.486734 km
# Distance between OUT-101 and AHU-107 is 6.907292999999999 km
# Distance between PMR-101 and AHU-107 is 5.514349 km
# Distance between PMR-102 and AHU-107 is 7.407107 km
# Distance between PMR-203 and AHU-107 is 6.155327000000001 km
# Distance between PMR-204 and AHU-107 is 7.85501 km
# Distance between PRF-304B and AHU-107 is 26.864779 km
# Distance between PRF-304C and AHU-107 is 26.817129 km
# Distance between PRF-304D and AHU-107 is 24.86324 km
# Distance between PRF-304E and AHU-107 is 23.048583999999998 km
# Distance between PRF-304F and AHU-107 is 11.227859 km
# Distance between RDP-101 and AHU-107 is 22.89416 km
# Distance between RDP-102 and AHU-107 is 14.949712 km
# Distance between RDP-103 and AHU-107 is 22.89416 km
# Distance between RDP-105 and AHU-107 is 21.644942999999998 km
# Distance between RDP-106 and AHU-107 is 21.358678 km
# Distance between RDP-107 and AHU-107 is 18.584135 km
# Distance between RDP-201 and AHU-107 is 16.901146 km
# Distance between RDP-202 and AHU-107 is 17.225975 km
# Distance between RDP-203 and AHU-107 is 18.584135 km
# Distance between RPP-101 and AHU-107 is 4.692323999999999 km
# Distance between RPP-102 and AHU-107 is 6.830754 km
# Distance between RPP-103 and AHU-107 is 7.4334 km
# Distance between RPP-104 and AHU-107 is 8.627327 km
# Distance between RPP-201 and AHU-107 is 3.673578 km
# Distance between RPP-204 and AHU-107 is 4.8095349999999994 km
# Distance between RPP-205 and AHU-107 is 6.8670469999999995 km
# Distance between SLA-363 and AHU-107 is 7.009712 km
# Distance between SLA-364 and AHU-107 is 5.816332999999999 km
# Distance between SLA-365 and AHU-107 is 8.785714 km
# Distance between SLA-366 and AHU-107 is 5.332225 km
# Distance between SLA-367 and AHU-107 is 9.534103 km
# Distance between SLA-368 and AHU-107 is 9.250305 km
# Distance between SLA-369 and AHU-107 is 5.8936850000000005 km
# Distance between SLA-370 and AHU-107 is 11.919062 km
# Distance between SLA-371 and AHU-107 is 4.5580169999999995 km
# Distance between SLE-109 and AHU-107 is 7.886571 km
# Distance between SLE-110 and AHU-107 is 9.527716 km
# Distance between SLE-111 and AHU-107 is 10.306004999999999 km
# Distance between SLE-303 and AHU-107 is 9.673228 km
# Distance between SLE-304 and AHU-107 is 9.673228 km
# Distance between S-O-103 and AHU-107 is 21.161475 km
# Distance between S-O-104 and AHU-107 is 19.095852 km
# Distance between S-O-201A and AHU-107 is 17.833021000000002 km
# Distance between S-O-201B and AHU-107 is 16.649146000000002 km
# Distance between VER-310A and AHU-107 is 25.81742 km
# Distance between VER-310B and AHU-107 is 21.713824 km
# Distance between VMA-109 and AHU-107 is 10.867937 km
# Distance between VMA-110 and AHU-107 is 18.648958999999998 km
# Distance between VMA-111 and AHU-107 is 8.382790000000002 km
# Distance between VMA-306 and AHU-107 is 8.091504 km
# Distance between VMA-307 and AHU-107 is 8.513161 km
# Distance between VSP-103 and AHU-107 is 2.554773 km
# Distance between VSP-104 and AHU-107 is 2.4741329999999997 km
# Distance between VSP-107 and AHU-107 is 3.353797 km
# Distance between VSP-108 and AHU-107 is 3.7933980000000003 km
# Distance between VSP-109 and AHU-107 is 2.1193310000000003 km
# Distance between VSP-205 and AHU-107 is 3.561649 km
# Distance between VSP-206 and AHU-107 is 4.116708 km
# Distance between AHU-101 and AHU-201 is 5.734521 km
# Distance between AHU-102 and AHU-201 is 3.918659 km
# Distance between AHU-103 and AHU-201 is 5.734521 km
# Distance between AHU-104 and AHU-201 is 3.7239630000000004 km
# Distance between AHU-105 and AHU-201 is 3.0146990000000002 km
# Distance between AHU-106 and AHU-201 is 4.76715 km
# Distance between AHU-107 and AHU-201 is 2.154836 km
# Distance between AHU-201 and AHU-201 is 0.0 km
# Distance between AHU-202 and AHU-201 is 1.863163 km
# Distance between ANJ-101 and AHU-201 is 15.058932 km
# Distance between ANJ-309 and AHU-201 is 13.82686 km
# Distance between ANJ-310 and AHU-201 is 13.155263999999999 km
# Distance between ANJ-311 and AHU-201 is 10.796083000000001 km
# Distance between ANJ-312 and AHU-201 is 9.457113 km
# Distance between CDN-111 and AHU-201 is 14.432305 km
# Distance between CDN-112 and AHU-201 is 12.518637 km
# Distance between CDN-113 and AHU-201 is 12.904003000000001 km
# Distance between CDN-114 and AHU-201 is 11.113411 km
# Distance between CDN-115 and AHU-201 is 11.96163 km
# Distance between CDN-116 and AHU-201 is 11.666488 km
# Distance between CDN-301 and AHU-201 is 13.498508 km
# Distance between IBI-301 and AHU-201 is 35.536578 km
# Distance between LAC-102 and AHU-201 is 16.838848000000002 km
# Distance between LAC-104 and AHU-201 is 14.381782999999999 km
# Distance between LAC-305 and AHU-201 is 15.058696 km
# Distance between LAC-306 and AHU-201 is 17.489043000000002 km
# Distance between LAS-321 and AHU-201 is 20.57 km
# Distance between LAS-323 and AHU-201 is 25.540135 km
# Distance between LAS-325 and AHU-201 is 23.207434000000003 km
# Distance between LAS-326 and AHU-201 is 22.857136999999998 km
# Distance between LAS-327 and AHU-201 is 22.676803 km
# Distance between LAS-328 and AHU-201 is 23.154883 km
# Distance between LAS-329 and AHU-201 is 20.874061 km
# Distance between LAS-330 and AHU-201 is 22.919963 km
# Distance between LAS-333 and AHU-201 is 23.704064 km
# Distance between MHM-105 and AHU-201 is 15.150221 km
# Distance between MHM-106 and AHU-201 is 14.791507 km
# Distance between MHM-107 and AHU-201 is 12.888122 km
# Distance between MHM-108 and AHU-201 is 11.105113 km
# Distance between MHM-109 and AHU-201 is 10.988189 km
# Distance between MHM-209 and AHU-201 is 11.370691 km
# Distance between MHM-210 and AHU-201 is 11.116325000000002 km
# Distance between MHM-211 and AHU-201 is 13.714986000000001 km
# Distance between MTN-102 and AHU-201 is 9.430028 km
# Distance between MTN-103 and AHU-201 is 9.421799 km
# Distance between MTN-104 and AHU-201 is 6.877057 km
# Distance between MTN-305 and AHU-201 is 5.4392640000000005 km
# Distance between MTN-307 and AHU-201 is 9.796408 km
# Distance between OUT-101 and AHU-201 is 9.852896000000001 km
# Distance between PMR-101 and AHU-201 is 7.6512 km
# Distance between PMR-102 and AHU-201 is 9.584232 km
# Distance between PMR-203 and AHU-201 is 8.270491 km
# Distance between PMR-204 and AHU-201 is 9.411403 km
# Distance between PRF-304B and AHU-201 is 27.80432 km
# Distance between PRF-304C and AHU-201 is 27.756676 km
# Distance between PRF-304D and AHU-201 is 25.802785 km
# Distance between PRF-304E and AHU-201 is 29.381471 km
# Distance between PRF-304F and AHU-201 is 10.631137 km
# Distance between RDP-101 and AHU-201 is 21.213641 km
# Distance between RDP-102 and AHU-201 is 21.21607 km
# Distance between RDP-103 and AHU-201 is 21.213641 km
# Distance between RDP-105 and AHU-201 is 23.201335999999998 km
# Distance between RDP-106 and AHU-201 is 22.915072 km
# Distance between RDP-107 and AHU-201 is 20.140528999999997 km
# Distance between RDP-201 and AHU-201 is 22.270264 km
# Distance between RDP-202 and AHU-201 is 18.782369 km
# Distance between RDP-203 and AHU-201 is 20.140528999999997 km
# Distance between RPP-101 and AHU-201 is 6.8694489999999995 km
# Distance between RPP-102 and AHU-201 is 8.387148 km
# Distance between RPP-103 and AHU-201 is 8.989794 km
# Distance between RPP-104 and AHU-201 is 10.183722 km
# Distance between RPP-201 and AHU-201 is 5.229972 km
# Distance between RPP-204 and AHU-201 is 6.365929 km
# Distance between RPP-205 and AHU-201 is 8.423441 km
# Distance between SLA-363 and AHU-201 is 6.412989 km
# Distance between SLA-364 and AHU-201 is 7.191006000000001 km
# Distance between SLA-365 and AHU-201 is 8.188992 km
# Distance between SLA-366 and AHU-201 is 4.735503 km
# Distance between SLA-367 and AHU-201 is 8.937381 km
# Distance between SLA-368 and AHU-201 is 8.653583000000001 km
# Distance between SLA-369 and AHU-201 is 7.331817 km
# Distance between SLA-370 and AHU-201 is 9.988331 km
# Distance between SLA-371 and AHU-201 is 5.996149 km
# Distance between SLE-109 and AHU-201 is 9.442967000000001 km
# Distance between SLE-110 and AHU-201 is 8.266313 km
# Distance between SLE-111 and AHU-201 is 9.044602999999999 km
# Distance between SLE-303 and AHU-201 is 11.229621999999999 km
# Distance between SLE-304 and AHU-201 is 11.229621999999999 km
# Distance between S-O-103 and AHU-201 is 22.101020000000002 km
# Distance between S-O-104 and AHU-201 is 20.035396000000002 km
# Distance between S-O-201A and AHU-201 is 18.772565999999998 km
# Distance between S-O-201B and AHU-201 is 17.588690999999997 km
# Distance between VER-310A and AHU-201 is 20.505592 km
# Distance between VER-310B and AHU-201 is 22.653367 km
# Distance between VMA-109 and AHU-201 is 24.414232 km
# Distance between VMA-110 and AHU-201 is 19.588504 km
# Distance between VMA-111 and AHU-201 is 10.559915 km
# Distance between VMA-306 and AHU-201 is 10.321564 km
# Distance between VMA-307 and AHU-201 is 10.509339 km
# Distance between VSP-103 and AHU-201 is 4.111167 km
# Distance between VSP-104 and AHU-201 is 2.910971 km
# Distance between VSP-107 and AHU-201 is 4.910192 km
# Distance between VSP-108 and AHU-201 is 5.349792000000001 km
# Distance between VSP-109 and AHU-201 is 4.255217 km
# Distance between VSP-205 and AHU-201 is 4.982047 km
# Distance between VSP-206 and AHU-201 is 5.673102 km
# Distance between AHU-101 and AHU-202 is 2.6941439999999997 km
# Distance between AHU-102 and AHU-202 is 2.397736 km
# Distance between AHU-103 and AHU-202 is 2.6941439999999997 km
# Distance between AHU-104 and AHU-202 is 2.20304 km
# Distance between AHU-105 and AHU-202 is 2.269476 km
# Distance between AHU-106 and AHU-202 is 6.092566 km
# Distance between AHU-107 and AHU-202 is 2.5726080000000002 km
# Distance between AHU-201 and AHU-202 is 2.065708 km
# Distance between AHU-202 and AHU-202 is 0.0 km
# Distance between ANJ-101 and AHU-202 is 16.268276 km
# Distance between ANJ-309 and AHU-202 is 15.036204 km
# Distance between ANJ-310 and AHU-202 is 14.364607 km
# Distance between ANJ-311 and AHU-202 is 12.005428 km
# Distance between ANJ-312 and AHU-202 is 10.842825999999999 km
# Distance between CDN-111 and AHU-202 is 13.373998 km
# Distance between CDN-112 and AHU-202 is 11.460329 km
# Distance between CDN-113 and AHU-202 is 11.845696 km
# Distance between CDN-114 and AHU-202 is 10.055104 km
# Distance between CDN-115 and AHU-202 is 10.903323 km
# Distance between CDN-116 and AHU-202 is 10.608182000000001 km
# Distance between CDN-301 and AHU-202 is 12.4402 km
# Distance between IBI-301 and AHU-202 is 34.478273 km
# Distance between LAC-102 and AHU-202 is 15.78054 km
# Distance between LAC-104 and AHU-202 is 13.323478999999999 km
# Distance between LAC-305 and AHU-202 is 14.00039 km
# Distance between LAC-306 and AHU-202 is 16.430734 km
# Distance between LAS-321 and AHU-202 is 19.511695 km
# ...
# Distance between MHM-107 and VSP-109 is 12.190938000000001 km
# Distance between MHM-108 and VSP-109 is 10.40793 km
# Distance between MHM-109 and VSP-109 is 10.291006 km
# Distance between MHM-209 and VSP-109 is 11.045959 km
# Distance between MHM-210 and VSP-109 is 10.791593 km
# Distance between MHM-211 and VSP-109 is 13.017804 km
# Distance between MTN-102 and VSP-109 is 13.962755 km
# Distance between MTN-103 and VSP-109 is 15.859862999999999 km
# Distance between MTN-104 and VSP-109 is 12.243825999999999 km
# Distance between MTN-305 and VSP-109 is 9.356307000000001 km
# Distance between MTN-307 and VSP-109 is 14.345945 km
# Distance between OUT-101 and VSP-109 is 4.902169 km
# Distance between PMR-101 and VSP-109 is 4.713982 km
# Distance between PMR-102 and VSP-109 is 5.765416 km
# Distance between PMR-203 and VSP-109 is 5.354961 km
# Distance between PMR-204 and VSP-109 is 8.71422 km
# Distance between PRF-304B and VSP-109 is 23.61001 km
# Distance between PRF-304C and VSP-109 is 23.562365000000003 km
# Distance between PRF-304D and VSP-109 is 21.608473 km
# Distance between PRF-304E and VSP-109 is 19.793817999999998 km
# Distance between PRF-304F and VSP-109 is 15.362763999999999 km
# Distance between RDP-101 and VSP-109 is 17.770229999999998 km
# Distance between RDP-102 and VSP-109 is 15.808922 km
# Distance between RDP-103 and VSP-109 is 17.770229999999998 km
# Distance between RDP-105 and VSP-109 is 22.504154 km
# Distance between RDP-106 and VSP-109 is 22.217889 km
# Distance between RDP-107 and VSP-109 is 19.443346000000002 km
# Distance between RDP-201 and VSP-109 is 17.760357 km
# Distance between RDP-202 and VSP-109 is 18.085186 km
# Distance between RDP-203 and VSP-109 is 19.443346000000002 km
# Distance between RPP-101 and VSP-109 is 3.046839 km
# Distance between RPP-102 and VSP-109 is 7.689965 km
# Distance between RPP-103 and VSP-109 is 8.29261 km
# Distance between RPP-104 and VSP-109 is 9.858989 km
# Distance between RPP-201 and VSP-109 is 3.02782 km
# Distance between RPP-204 and VSP-109 is 5.668209 km
# Distance between RPP-205 and VSP-109 is 7.726258 km
# Distance between SLA-363 and VSP-109 is 7.0046040000000005 km
# Distance between SLA-364 and VSP-109 is 6.957055 km
# Distance between SLA-365 and VSP-109 is 8.780606 km
# Distance between SLA-366 and VSP-109 is 5.3271180000000005 km
# Distance between SLA-367 and VSP-109 is 9.528995 km
# Distance between SLA-368 and VSP-109 is 9.245197000000001 km
# Distance between SLA-369 and VSP-109 is 7.1783 km
# Distance between SLA-370 and VSP-109 is 8.664294 km
# Distance between SLA-371 and VSP-109 is 4.814254 km
# Distance between SLE-109 and VSP-109 is 8.745781999999998 km
# Distance between SLE-110 and VSP-109 is 10.386927 km
# Distance between SLE-111 and VSP-109 is 11.165216000000001 km
# Distance between SLE-303 and VSP-109 is 10.532438 km
# Distance between SLE-304 and VSP-109 is 10.532438 km
# Distance between S-O-103 and VSP-109 is 17.906706999999997 km
# Distance between S-O-104 and VSP-109 is 15.841085 km
# Distance between S-O-201A and VSP-109 is 14.578256 km
# Distance between S-O-201B and VSP-109 is 13.394382 km
# Distance between VER-310A and VSP-109 is 16.730438 km
# Distance between VER-310B and VSP-109 is 19.63477 km
# Distance between VMA-109 and VSP-109 is 18.827758000000003 km
# Distance between VMA-110 and VSP-109 is 15.448156 km
# Distance between VMA-111 and VSP-109 is 6.754404999999999 km
# Distance between VMA-306 and VSP-109 is 7.3276710000000005 km
# Distance between VMA-307 and VSP-109 is 7.743875 km
# Distance between VSP-103 and VSP-109 is 2.4938939999999996 km
# Distance between VSP-104 and VSP-109 is 6.202249 km
# Distance between VSP-107 and VSP-109 is 4.212473 km
# Distance between VSP-108 and VSP-109 is 3.732519 km
# Distance between VSP-109 and VSP-109 is 0.0 km
# Distance between VSP-205 and VSP-109 is 7.9707 km
# Distance between VSP-206 and VSP-109 is 4.975918 km
# Distance between AHU-101 and VSP-205 is 9.773837 km
# Distance between AHU-102 and VSP-205 is 9.565045 km
# Distance between AHU-103 and VSP-205 is 9.773837 km
# Distance between AHU-104 and VSP-205 is 8.154297 km
# Distance between AHU-105 and VSP-205 is 4.41463 km
# Distance between AHU-106 and VSP-205 is 5.520933 km
# Distance between AHU-107 and VSP-205 is 3.50273 km
# Distance between AHU-201 and VSP-205 is 4.992826 km
# Distance between AHU-202 and VSP-205 is 6.293497 km
# Distance between ANJ-101 and VSP-205 is 11.838736999999998 km
# Distance between ANJ-309 and VSP-205 is 10.606667 km
# Distance between ANJ-310 and VSP-205 is 9.93507 km
# Distance between ANJ-311 and VSP-205 is 7.57589 km
# Distance between ANJ-312 and VSP-205 is 5.840207 km
# Distance between CDN-111 and VSP-205 is 16.859434 km
# Distance between CDN-112 and VSP-205 is 14.945765999999999 km
# Distance between CDN-113 and VSP-205 is 15.331133 km
# Distance between CDN-114 and VSP-205 is 13.540541 km
# Distance between CDN-115 and VSP-205 is 14.388761 km
# Distance between CDN-116 and VSP-205 is 14.093617 km
# Distance between CDN-301 and VSP-205 is 15.925638000000001 km
# Distance between IBI-301 and VSP-205 is 36.063027000000005 km
# Distance between LAC-102 and VSP-205 is 19.265978999999998 km
# Distance between LAC-104 and VSP-205 is 16.808914 km
# Distance between LAC-305 and VSP-205 is 19.429789 km
# Distance between LAC-306 and VSP-205 is 19.916172 km
# Distance between LAS-321 and VSP-205 is 23.416287 km
# Distance between LAS-323 and VSP-205 is 27.967264 km
# Distance between LAS-325 and VSP-205 is 25.634562000000003 km
# Distance between LAS-326 and VSP-205 is 25.284266 km
# Distance between LAS-327 and VSP-205 is 25.103936 km
# Distance between LAS-328 and VSP-205 is 25.582014 km
# Distance between LAS-329 and VSP-205 is 23.301188999999997 km
# Distance between LAS-330 and VSP-205 is 25.347092 km
# Distance between LAS-333 and VSP-205 is 26.131193 km
# Distance between MHM-105 and VSP-205 is 11.930027 km
# Distance between MHM-106 and VSP-205 is 11.571312 km
# Distance between MHM-107 and VSP-205 is 9.667928 km
# Distance between MHM-108 and VSP-205 is 7.884918 km
# Distance between MHM-109 and VSP-205 is 7.763944 km
# Distance between MHM-209 and VSP-205 is 8.146446 km
# Distance between MHM-210 and VSP-205 is 7.89208 km
# Distance between MHM-211 and VSP-205 is 10.494793 km
# Distance between MTN-102 and VSP-205 is 5.867292 km
# Distance between MTN-103 and VSP-205 is 7.137157 km
# Distance between MTN-104 and VSP-205 is 4.1292219999999995 km
# Distance between MTN-305 and VSP-205 is 1.352277 km
# Distance between MTN-307 and VSP-205 is 6.889373 km
# Distance between OUT-101 and VSP-205 is 11.520647 km
# Distance between PMR-101 and VSP-205 is 7.692126 km
# Distance between PMR-102 and VSP-205 is 10.487491 km
# Distance between PMR-203 and VSP-205 is 7.941215000000001 km
# Distance between PMR-204 and VSP-205 is 7.3295770000000005 km
# Distance between PRF-304B and VSP-205 is 30.231453000000002 km
# Distance between PRF-304C and VSP-205 is 30.183803 km
# Distance between PRF-304D and VSP-205 is 28.229916 km
# Distance between PRF-304E and VSP-205 is 26.415258 km
# Distance between PRF-304F and VSP-205 is 14.670453 km
# Distance between RDP-101 and VSP-205 is 10.244978999999999 km
# Distance between RDP-102 and VSP-205 is 8.985336 km
# Distance between RDP-103 and VSP-205 is 10.244978999999999 km
# Distance between RDP-105 and VSP-205 is 19.981145 km
# Distance between RDP-106 and VSP-205 is 19.694877 km
# Distance between RDP-107 and VSP-205 is 16.920336 km
# Distance between RDP-201 and VSP-205 is 10.039530000000001 km
# Distance between RDP-202 and VSP-205 is 15.562176 km
# Distance between RDP-203 and VSP-205 is 16.920336 km
# Distance between RPP-101 and VSP-205 is 7.441542 km
# Distance between RPP-102 and VSP-205 is 5.162903 km
# Distance between RPP-103 and VSP-205 is 5.766971 km
# Distance between RPP-104 and VSP-205 is 6.959477 km
# Distance between RPP-201 and VSP-205 is 5.934311 km
# Distance between RPP-204 and VSP-205 is 4.976883 km
# Distance between RPP-205 and VSP-205 is 4.864912 km
# Distance between SLA-363 and VSP-205 is 10.452306 km
# Distance between SLA-364 and VSP-205 is 11.230321 km
# Distance between SLA-365 and VSP-205 is 12.228308 km
# Distance between SLA-366 and VSP-205 is 8.774818999999999 km
# Distance between SLA-367 and VSP-205 is 12.976697 km
# Distance between SLA-368 and VSP-205 is 12.692897 km
# Distance between SLA-369 and VSP-205 is 11.371133 km
# Distance between SLA-370 and VSP-205 is 15.285735 km
# Distance between SLA-371 and VSP-205 is 10.035465 km
# Distance between SLE-109 and VSP-205 is 6.222772 km
# Distance between SLE-110 and VSP-205 is 4.042926 km
# Distance between SLE-111 and VSP-205 is 4.821216000000001 km
# Distance between SLE-303 and VSP-205 is 7.074807 km
# Distance between SLE-304 and VSP-205 is 7.074807 km
# Distance between S-O-103 and VSP-205 is 24.528148 km
# Distance between S-O-104 and VSP-205 is 22.462525000000003 km
# Distance between S-O-201A and VSP-205 is 21.199697 km
# Distance between S-O-201B and VSP-205 is 20.015824000000002 km
# Distance between VER-310A and VSP-205 is 23.351879 km
# Distance between VER-310B and VSP-205 is 19.068055 km
# Distance between VMA-109 and VSP-205 is 13.585728999999999 km
# Distance between VMA-110 and VSP-205 is 22.069598000000003 km
# Distance between VMA-111 and VSP-205 is 11.061759 km
# Distance between VMA-306 and VSP-205 is 10.323706 km
# Distance between VMA-307 and VSP-205 is 10.952380999999999 km
# Distance between VSP-103 and VSP-205 is 5.921448000000001 km
# Distance between VSP-104 and VSP-205 is 1.8241939999999999 km
# Distance between VSP-107 and VSP-205 is 4.002611 km
# Distance between VSP-108 and VSP-205 is 7.160073000000001 km
# Distance between VSP-109 and VSP-205 is 8.123871 km
# Distance between VSP-205 and VSP-205 is 0.0 km
# Distance between VSP-206 and VSP-205 is 3.2328580000000002 km
# Distance between AHU-101 and VSP-206 is 11.031125 km
# Distance between AHU-102 and VSP-206 is 10.822334000000001 km
# Distance between AHU-103 and VSP-206 is 11.031125 km
# Distance between AHU-104 and VSP-206 is 11.305335999999999 km
# Distance between AHU-105 and VSP-206 is 6.193708 km
# Distance between AHU-106 and VSP-206 is 7.575051 km
# Distance between AHU-107 and VSP-206 is 4.575129 km
# Distance between AHU-201 and VSP-206 is 5.544162 km
# Distance between AHU-202 and VSP-206 is 6.844834 km
# Distance between ANJ-101 and VSP-206 is 9.490999 km
# Distance between ANJ-309 and VSP-206 is 8.258929 km
# Distance between ANJ-310 and VSP-206 is 7.587331 km
# Distance between ANJ-311 and VSP-206 is 5.2281509999999995 km
# Distance between ANJ-312 and VSP-206 is 9.119092 km
# Distance between CDN-111 and VSP-206 is 13.724107 km
# Distance between CDN-112 and VSP-206 is 11.810439 km
# Distance between CDN-113 and VSP-206 is 12.195807 km
# Distance between CDN-114 and VSP-206 is 10.405213 km
# Distance between CDN-115 and VSP-206 is 11.253433999999999 km
# Distance between CDN-116 and VSP-206 is 10.958291 km
# Distance between CDN-301 and VSP-206 is 12.79031 km
# Distance between IBI-301 and VSP-206 is 32.927699000000004 km
# Distance between LAC-102 and VSP-206 is 16.130651 km
# Distance between LAC-104 and VSP-206 is 13.673587 km
# Distance between LAC-305 and VSP-206 is 16.29446 km
# Distance between LAC-306 and VSP-206 is 16.780846 km
# Distance between LAS-321 and VSP-206 is 20.280960999999998 km
# Distance between LAS-323 and VSP-206 is 24.831937999999997 km
# Distance between LAS-325 and VSP-206 is 22.499236 km
# Distance between LAS-326 and VSP-206 is 22.148939 km
# Distance between LAS-327 and VSP-206 is 21.968607 km
# Distance between LAS-328 and VSP-206 is 22.446686000000003 km
# Distance between LAS-329 and VSP-206 is 20.165863 km
# Distance between LAS-330 and VSP-206 is 22.211764 km
# Distance between LAS-333 and VSP-206 is 22.995869 km
# Distance between MHM-105 and VSP-206 is 9.582289000000001 km
# Distance between MHM-106 and VSP-206 is 9.223573 km
# Distance between MHM-107 and VSP-206 is 7.320189 km
# Distance between MHM-108 and VSP-206 is 5.5371809999999995 km
# Distance between MHM-109 and VSP-206 is 5.416205 km
# Distance between MHM-209 and VSP-206 is 5.798707 km
# Distance between MHM-210 and VSP-206 is 5.544341 km
# Distance between MHM-211 and VSP-206 is 8.147054 km
# Distance between MTN-102 and VSP-206 is 9.092006 km
# Distance between MTN-103 and VSP-206 is 10.989115 km
# Distance between MTN-104 and VSP-206 is 7.373077 km
# Distance between MTN-305 and VSP-206 is 4.485558 km
# Distance between MTN-307 and VSP-206 is 9.475195 km
# Distance between OUT-101 and VSP-206 is 8.38532 km
# Distance between PMR-101 and VSP-206 is 4.728314 km
# Distance between PMR-102 and VSP-206 is 7.356185 km
# Distance between PMR-203 and VSP-206 is 4.97819 km
# Distance between PMR-204 and VSP-206 is 4.422607 km
# Distance between PRF-304B and VSP-206 is 27.096127 km
# Distance between PRF-304C and VSP-206 is 27.048477 km
# Distance between PRF-304D and VSP-206 is 25.094587999999998 km
# Distance between PRF-304E and VSP-206 is 23.279932000000002 km
# Distance between PRF-304F and VSP-206 is 18.848877 km
# Distance between RDP-101 and VSP-206 is 13.467630999999999 km
# Distance between RDP-102 and VSP-206 is 10.938174 km
# Distance between RDP-103 and VSP-206 is 13.467630999999999 km
# Distance between RDP-105 and VSP-206 is 17.633404 km
# Distance between RDP-106 and VSP-206 is 17.347137 km
# Distance between RDP-107 and VSP-206 is 14.572599 km
# Distance between RDP-201 and VSP-206 is 12.889608 km
# Distance between RDP-202 and VSP-206 is 13.214437 km
# Distance between RDP-203 and VSP-206 is 14.572599 km
# Distance between RPP-101 and VSP-206 is 4.534575 km
# Distance between RPP-102 and VSP-206 is 2.815164 km
# Distance between RPP-103 and VSP-206 is 3.419232 km
# Distance between RPP-104 and VSP-206 is 4.611738 km
# Distance between RPP-201 and VSP-206 is 3.0273429999999997 km
# Distance between RPP-204 and VSP-206 is 2.0699140000000003 km
# Distance between RPP-205 and VSP-206 is 2.5171729999999997 km
# Distance between SLA-363 and VSP-206 is 10.483189 km
# Distance between SLA-364 and VSP-206 is 10.443168 km
# Distance between SLA-365 and VSP-206 is 12.259191999999999 km
# Distance between SLA-366 and VSP-206 is 8.805703 km
# Distance between SLA-367 and VSP-206 is 13.007582000000001 km
# Distance between SLA-368 and VSP-206 is 12.723783 km
# Distance between SLA-369 and VSP-206 is 10.664414 km
# Distance between SLA-370 and VSP-206 is 12.150409 km
# Distance between SLA-371 and VSP-206 is 9.730986999999999 km
# Distance between SLE-109 and VSP-206 is 3.8750329999999997 km
# Distance between SLE-110 and VSP-206 is 5.513547 km
# Distance between SLE-111 and VSP-206 is 6.291837 km
# Distance between SLE-303 and VSP-206 is 5.661689 km
# Distance between SLE-304 and VSP-206 is 5.661689 km
# Distance between S-O-103 and VSP-206 is 21.392822 km
# Distance between S-O-104 and VSP-206 is 19.327199 km
# Distance between S-O-201A and VSP-206 is 18.064369 km
# Distance between S-O-201B and VSP-206 is 16.880494 km
# Distance between VER-310A and VSP-206 is 20.216553 km
# Distance between VER-310B and VSP-206 is 15.838445 km
# Distance between VMA-109 and VSP-206 is 10.356121 km
# Distance between VMA-110 and VSP-206 is 18.934271 km
# Distance between VMA-111 and VSP-206 is 7.800114 km
# Distance between VMA-306 and VSP-206 is 7.062061 km
# Distance between VMA-307 and VSP-206 is 7.690737 km
# Distance between VSP-103 and VSP-206 is 2.786121 km
# Distance between VSP-104 and VSP-206 is 3.909244 km
# Distance between VSP-107 and VSP-206 is 1.1724359999999998 km
# Distance between VSP-108 and VSP-206 is 4.024745 km
# Distance between VSP-109 and VSP-206 is 4.988543 km
# Distance between VSP-205 and VSP-206 is 3.0958989999999997 km
# Distance between VSP-206 and VSP-206 is 0.0 km
#       Removal Site 1 Removal Site 2  Distance
# 0            AHU-101        AHU-101  0.000000
# 1            AHU-102        AHU-101  0.354811
# 2            AHU-103        AHU-101  0.000000
# 3            AHU-104        AHU-101  1.268511
# 4            AHU-105        AHU-101  4.929787
# ...              ...            ...       ...
# 11231        VSP-107        VSP-206  1.172436
# 11232        VSP-108        VSP-206  4.024745
# 11233        VSP-109        VSP-206  4.988543
# 11234        VSP-205        VSP-206  3.095899
# 11235        VSP-206        VSP-206  0.000000
#
# [11236 rows x 3 columns]
