# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd

# %%
# Load your datasets with an alternate encoding
try:
    removal_sites = pd.read_csv('Removal_Sites.csv', encoding='utf-8')
except UnicodeDecodeError:
    removal_sites = pd.read_csv('Removal_Sites.csv', encoding='ISO-8859-1')  # or 'latin1'

try:
    disposal_sites = pd.read_csv('Disposal_Sites.csv', encoding='utf-8')
except UnicodeDecodeError:
    disposal_sites = pd.read_csv('Disposal_Sites.csv', encoding='ISO-8859-1')

try:
    dist_proper = pd.read_csv('Removal_to_Dispoal_Distance.csv', encoding='utf-8')
except UnicodeDecodeError:
    dist_proper = pd.read_csv('Removal_to_Dispoal_Distance.csv', encoding='ISO-8859-1')
    
try:
    dist_sites = pd.read_csv('Removal_to_Removal_Distance.csv', encoding='utf-8')
except UnicodeDecodeError:
    dist_sites = pd.read_csv('Removal_to_Removal_Distance.csv',encoding='ISO-8859-1')

# %% [markdown]
# ## First Priority as Hub

# %%
import gurobipy as gp
from gurobipy import GRB

# Create a Gurobi model
model = gp.Model('SnowRemoval')
model.Params.OutputFlag = 0
# Set the NonConvex parameter
model.setParam('NonConvex', 2)

# Define the hub (assuming the hub is one of the removal sites)
hub_id = 'VMA-109'  # Replace with the actual ID of the hub

# Decision variables
removal_ids = removal_sites['NomSecteur'].tolist()
disposal_ids = disposal_sites['NomDepot'].tolist()
X = model.addVars(removal_ids, disposal_ids, vtype=GRB.BINARY, name="X")
Y = model.addVars(removal_ids, vtype=GRB.CONTINUOUS, name="Y")
Z = model.addVars(removal_ids, removal_ids, vtype=GRB.BINARY, name="Z")  # Auxiliary variables

# Pre-calculate cost and round-trip distances
cost_distance_dict = {}

for i in removal_ids:
    for j in disposal_ids:
        # Get disposal cost and convert to float
        disposal_cost = float(disposal_sites[disposal_sites['NomDepot'] == j]['Cost ($/m3)'].iloc[0]) if disposal_sites[disposal_sites['NomDepot'] == j]['Cost ($/m3)'].iloc[0] else 0.0

        # Get distance to disposal site and convert to float
        distance_to_disposal = float(dist_proper[(dist_proper['PickupSector'] == i) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].iloc[0]) if not dist_proper[(dist_proper['PickupSector'] == i) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].empty else 0.0
        
        # Get distance from disposal site to hub and convert to float
        distance_to_hub = float(dist_proper[(dist_proper['PickupSector'] == hub_id) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].iloc[0]) if not dist_proper[(dist_proper['PickupSector'] == hub_id) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].empty else 0.0

        # Get distance from hub to removal site i (assuming symmetric distances)
        distance_from_hub_to_i = float(dist_sites[(dist_sites['Removal Site 1'] == hub_id) & (dist_sites['Removal Site 2'] == i)]['Distance'].iloc[0]) if not dist_sites[(dist_sites['Removal Site 1'] == hub_id) & (dist_sites['Removal Site 2'] == i)].empty else 0.0

        # Total round-trip distance
        total_distance = distance_from_hub_to_i + distance_to_disposal + distance_to_hub

        # Store in dictionary
        cost_distance_dict[(i, j)] = (disposal_cost, total_distance)

# Objective function with penalty for priority
penalty_factor = 100000
objective = gp.quicksum(
    (Y[i] * cost_distance_dict[(i, j)][0] + Y[i]*(cost_distance_dict[(i, j)][1] * 0.1395 + 0.513)) * X[i, j]
    for i in removal_ids for j in disposal_ids)

# Adding penalty logic for priorities
for i in removal_ids:
    for k in removal_ids:
        if i != k:
            priority_diff = float(removal_sites[removal_sites['NomSecteur'] == k]['Priority'].iloc[0]) - \
                            float(removal_sites[removal_sites['NomSecteur'] == i]['Priority'].iloc[0])
            objective += penalty_factor * Z[i, k] * max(0, priority_diff)

model.setObjective(objective, GRB.MINIMIZE)

# Constraints
# 1. Capacity of disposal sites
for j in disposal_ids:
    model.addConstr(gp.quicksum(Y[i] * X[i, j] for i in removal_ids) <= float(disposal_sites[disposal_sites['NomDepot'] == j]['Capacite m3'].iloc[0]))

# 2. Completeness of snow removal
for i in removal_ids:
    model.addConstr(gp.quicksum(X[i, j] for j in disposal_ids) == 1)

# 3. Total snow transported from each removal site equals its snow volume
for i in removal_ids:
    total_snow_volume = float(removal_sites[removal_sites['NomSecteur'] == i]['Volume m3'].iloc[0])
    model.addConstr(gp.quicksum(Y[i] * X[i, j] for j in disposal_ids) == total_snow_volume)

# Additional constraints for priority ordering
for i in removal_ids:
    for k in removal_ids:
        if i != k:
            model.addConstr(gp.quicksum(X[i, j] for j in disposal_ids) - gp.quicksum(X[k, j] for j in disposal_ids) <= Z[i, k])

# Optimize the model
model.optimize()

# Check if an optimal solution was found
if model.status == GRB.OPTIMAL:
    # Print the total cost
    total_cost = model.ObjVal
    print(f"Total Cost of Snow Removal: ${total_cost:.2f}")

    # Print the amount of snow transported for each route
    print("\nSnow Transported for Each Route:")
    for i in removal_ids:
        for j in disposal_ids:
            if X[i, j].X > 0.5:  # If this route is used
                snow_transported = Y[i].X
                print(f"Removal site {i} -> Disposal site {j}: {snow_transported} m³")
else:
    print("No optimal solution found.")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-30
# Total Cost of Snow Removal: $57035642.81
#
# Snow Transported for Each Route:
# Removal site VMA-109 -> Disposal site Fullum (VMA): 93274.51 m³
# Removal site VMA-307 -> Disposal site Fullum (VMA): 82691.13 m³
# Removal site VMA-306 -> Disposal site Fullum (VMA): 96229.11 m³
# Removal site VMA-111 -> Disposal site Fullum (VMA): 85847.51 m³
# Removal site VMA-110 -> Disposal site Riverside (VMA): 127483.61 m³
# Removal site PMR-101 -> Disposal site Fullum (VMA): 158592.4 m³
# Removal site PMR-102 -> Disposal site Fullum (VMA): 144354.73 m³
# Removal site S-O-104 -> Disposal site Riverside (VMA): 136883.4 m³
# Removal site PMR-204 -> Disposal site Iberville (PMR): 80600.83 m³
# Removal site MHM-109 -> Disposal site Iberville (PMR): 126720.19 m³
# Removal site PMR-203 -> Disposal site Fullum (VMA): 97228.93 m³
# Removal site RPP-201 -> Disposal site Fullum (VMA): 116858.26 m³
# Removal site MHM-209 -> Disposal site Iberville (PMR): 124186.67 m³
# Removal site MHM-210 -> Disposal site Iberville (PMR): 156288.64 m³
# Removal site RPP-204 -> Disposal site Fullum (VMA): 123910.35 m³
# Removal site RPP-101 -> Disposal site Fullum (VMA): 100797.42 m³
# Removal site RPP-102 -> Disposal site Iberville (PMR): 95611.77 m³
# Removal site OUT-101 -> Disposal site Riverside (VMA): 170139.37 m³
# Removal site RPP-104 -> Disposal site Iberville (PMR): 152513.24 m³
# Removal site VER-310B -> Disposal site Riverside (VMA): 91295.89 m³
# Removal site VSP-107 -> Disposal site Fullum (VMA): 125642.5 m³
# Removal site CDN-111 -> Disposal site Butler (S-O): 70225.35 m³
# Removal site VSP-206 -> Disposal site Iberville (PMR): 107770.34 m³
# Removal site S-O-201B -> Disposal site Riverside (VMA): 107975.69 m³
# Removal site RPP-205 -> Disposal site Iberville (PMR): 133863.99 m³
# Removal site AHU-107 -> Disposal site Iberville (PMR): 165025.8 m³
# Removal site RPP-103 -> Disposal site Iberville (PMR): 113049.76 m³
# Removal site S-O-201A -> Disposal site Riverside (VMA): 94217.6 m³
# Removal site AHU-105 -> Disposal site Fullum (VMA): 144586.67 m³
# Removal site MHM-211 -> Disposal site Iberville (PMR): 120956.77 m³
# Removal site VSP-104 -> Disposal site Fullum (VMA): 126061.39 m³
# Removal site MHM-105 -> Disposal site Iberville (PMR): 135651.25 m³
# Removal site CDN-112 -> Disposal site Riverside (VMA): 85719.86 m³
# Removal site S-O-103 -> Disposal site Saint-Pierre (LAC): 197580.1 m³
# Removal site SLE-109 -> Disposal site Iberville (PMR): 108860.15 m³
# Removal site CDN-301 -> Disposal site Riverside (VMA): 226169.69 m³
# Removal site MHM-106 -> Disposal site Iberville (PMR): 150424.21 m³
# Removal site MHM-107 -> Disposal site Iberville (PMR): 156504.79 m³
# Removal site CDN-113 -> Disposal site Riverside (VMA): 110109.53 m³
# Removal site LAS-328 -> Disposal site Fullum (VMA): 90925.53 m³
# Removal site LAS-329 -> Disposal site Saint-Pierre (LAC): 66308.04 m³
# Removal site LAS-321 -> Disposal site Butler (S-O): 61684.34 m³
# Removal site ANJ-310 -> Disposal site Iberville (PMR): 65548.68 m³
# Removal site VSP-205 -> Disposal site Iberville (PMR): 105697.54 m³
# Removal site AHU-106 -> Disposal site Fullum (VMA): 160528.94 m³
# Removal site LAS-327 -> Disposal site Fullum (VMA): 68856.07 m³
# Removal site VER-310A -> Disposal site Butler (S-O): 193127.45 m³
# Removal site MHM-108 -> Disposal site Iberville (PMR): 177831.34 m³
# Removal site SLE-111 -> Disposal site Iberville (PMR): 112853.32 m³
# Removal site LAS-323 -> Disposal site Butler (S-O): 81718.74 m³
# Removal site ANJ-309 -> Disposal site Iberville (PMR): 68076.99 m³
# Removal site CDN-114 -> Disposal site Riverside (VMA): 90497.64 m³
# Removal site LAS-326 -> Disposal site Fullum (VMA): 66068.18 m³
# Removal site LAS-330 -> Disposal site Saint-Pierre (LAC): 69701.58 m³
# Removal site MTN-305 -> Disposal site Iberville (PMR): 173318.12 m³
# Removal site LAS-325 -> Disposal site Saint-Pierre (LAC): 77214.89 m³
# Removal site SLE-110 -> Disposal site Iberville (PMR): 143274.78 m³
# Removal site CDN-116 -> Disposal site Riverside (VMA): 100403.2 m³
# Removal site SLA-364 -> Disposal site Riverside (VMA): 96099.1 m³
# Removal site CDN-115 -> Disposal site Riverside (VMA): 86829.59 m³
# Removal site SLA-369 -> Disposal site Riverside (VMA): 74626.73 m³
# Removal site LAS-333 -> Disposal site Saint-Pierre (LAC): 67148.59 m³
# Removal site SLE-304 -> Disposal site Iberville (PMR): 202107.95 m³
# Removal site SLE-303 -> Disposal site Iberville (PMR): 219784.46 m³
# Removal site VSP-108 -> Disposal site Iberville (PMR): 120159.51 m³
# Removal site LAC-102 -> Disposal site St-Michel-17ième(Sous-Sol): 84276.29 m³
# Removal site SLA-363 -> Disposal site St-Michel-17ième(Sous-Sol): 84510.81 m³
# Removal site VSP-109 -> Disposal site Iberville (PMR): 137970.19 m³
# Removal site SLA-370 -> Disposal site Riverside (VMA): 81596.87 m³
# Removal site MTN-102 -> Disposal site Iberville (PMR): 115918.37 m³
# Removal site ANJ-312 -> Disposal site Iberville (PMR): 190725.51 m³
# Removal site SLA-365 -> Disposal site St-Michel-17ième(Sous-Sol): 100648.23 m³
# Removal site VSP-103 -> Disposal site Iberville (PMR): 145643.47 m³
# Removal site ANJ-311 -> Disposal site Iberville (PMR): 74463.74 m³
# Removal site SLA-366 -> Disposal site Iberville (PMR): 81563.47 m³
# Removal site LAC-305 -> Disposal site St-Michel-17ième(Sous-Sol): 61232.24 m³
# Removal site ANJ-101 -> Disposal site Iberville (PMR): 135587.31 m³
# Removal site SLA-371 -> Disposal site Iberville (PMR): 80953.24 m³
# Removal site LAC-306 -> Disposal site St-Michel-17ième(Sous-Sol): 149069.24 m³
# Removal site LAC-104 -> Disposal site St-Michel-17ième(Sous-Sol): 52879.08 m³
# Removal site MTN-307 -> Disposal site Iberville (PMR): 179912.37 m³
# Removal site SLA-368 -> Disposal site St-Michel-17ième(Sous-Sol): 92066.03 m³
# Removal site MTN-103 -> Disposal site St-Michel-17ième(Sous-Sol): 106176.99 m³
# Removal site MTN-104 -> Disposal site Iberville (PMR): 105891.84 m³
# Removal site SLA-367 -> Disposal site St-Michel-17ième(Sous-Sol): 96600.02 m³
# Removal site RDP-202 -> Disposal site St-Michel-17ième(Sous-Sol): 115670.96 m³
# Removal site RDP-102 -> Disposal site St-Michel - Robert (VSP): 163220.74000000002 m³
# Removal site RDP-201 -> Disposal site St-Michel-17ième(Sous-Sol): 166379.71 m³
# Removal site RDP-101 -> Disposal site St-Michel-17ième(Sous-Sol): 198928.84 m³
# Removal site RDP-103 -> Disposal site St-Michel-17ième(Sous-Sol): 201736.38 m³
# Removal site AHU-101 -> Disposal site Millen (AHU): 146517.1 m³
# Removal site AHU-103 -> Disposal site Millen (AHU): 174266.08 m³
# Removal site RDP-203 -> Disposal site Iberville (PMR): 182385.61 m³
# Removal site RDP-107 -> Disposal site Iberville (PMR): 173405.52 m³
# Removal site AHU-202 -> Disposal site Millen (AHU): 135547.87 m³
# Removal site AHU-104 -> Disposal site Millen (AHU): 128579.68 m³
# Removal site AHU-102 -> Disposal site Millen (AHU): 166156.4 m³
# Removal site AHU-201 -> Disposal site Millen (AHU): 132188.9 m³
# Removal site PRF-304F -> Disposal site St-Michel-17ième(Sous-Sol): 22601.93 m³
# Removal site RDP-105 -> Disposal site St-Michel-17ième(Sous-Sol): 157347.72 m³
# Removal site RDP-106 -> Disposal site St-Michel-17ième(Sous-Sol): 182306.97 m³
# Removal site PRF-304E -> Disposal site St-Michel-17ième(Sous-Sol): 38547.16 m³
# Removal site PRF-304D -> Disposal site St-Michel-17ième(Sous-Sol): 19647.35 m³
# Removal site PRF-304C -> Disposal site St-Michel-17ième(Sous-Sol): 22260.38 m³
# Removal site PRF-304B -> Disposal site St-Michel-17ième(Sous-Sol): 24034.84 m³
# Removal site IBI-301 -> Disposal site St-Michel-17ième(Sous-Sol): 23055.45 m³

# %% [markdown]
# ## Least Prioirty as hub

# %%
import gurobipy as gp
from gurobipy import GRB

# Create a Gurobi model
model = gp.Model('SnowRemoval')
model.Params.OutputFlag = 0
# Set the NonConvex parameter
model.setParam('NonConvex', 2)

# Define the hub (assuming the hub is one of the removal sites)
hub_id = 'IBI-301'  # Replace with the actual ID of the hub

# Decision variables
removal_ids = removal_sites['NomSecteur'].tolist()
disposal_ids = disposal_sites['NomDepot'].tolist()
X = model.addVars(removal_ids, disposal_ids, vtype=GRB.BINARY, name="X")
Y = model.addVars(removal_ids, vtype=GRB.CONTINUOUS, name="Y")
Z = model.addVars(removal_ids, removal_ids, vtype=GRB.BINARY, name="Z")  # Auxiliary variables

# Pre-calculate cost and round-trip distances
cost_distance_dict = {}

for i in removal_ids:
    for j in disposal_ids:
        # Get disposal cost and convert to float
        disposal_cost = float(disposal_sites[disposal_sites['NomDepot'] == j]['Cost ($/m3)'].iloc[0]) if disposal_sites[disposal_sites['NomDepot'] == j]['Cost ($/m3)'].iloc[0] else 0.0

        # Get distance to disposal site and convert to float
        distance_to_disposal = float(dist_proper[(dist_proper['PickupSector'] == i) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].iloc[0]) if not dist_proper[(dist_proper['PickupSector'] == i) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].empty else 0.0
        
        # Get distance from disposal site to hub and convert to float
        distance_to_hub = float(dist_proper[(dist_proper['PickupSector'] == hub_id) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].iloc[0]) if not dist_proper[(dist_proper['PickupSector'] == hub_id) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].empty else 0.0

        # Get distance from hub to removal site i (assuming symmetric distances)
        distance_from_hub_to_i = float(dist_sites[(dist_sites['Removal Site 1'] == hub_id) & (dist_sites['Removal Site 2'] == i)]['Distance'].iloc[0]) if not dist_sites[(dist_sites['Removal Site 1'] == hub_id) & (dist_sites['Removal Site 2'] == i)].empty else 0.0

        # Total round-trip distance
        total_distance = distance_from_hub_to_i + distance_to_disposal + distance_to_hub

        # Store in dictionary
        cost_distance_dict[(i, j)] = (disposal_cost, total_distance)

# Objective function with penalty for priority
penalty_factor = 100000
objective = gp.quicksum(
    (Y[i] * cost_distance_dict[(i, j)][0] + Y[i]*(cost_distance_dict[(i, j)][1] * 0.1395 + 0.513)) * X[i, j]
    for i in removal_ids for j in disposal_ids)

# Adding penalty logic for priorities
for i in removal_ids:
    for k in removal_ids:
        if i != k:
            priority_diff = float(removal_sites[removal_sites['NomSecteur'] == k]['Priority'].iloc[0]) - \
                            float(removal_sites[removal_sites['NomSecteur'] == i]['Priority'].iloc[0])
            objective += penalty_factor * Z[i, k] * max(0, priority_diff)

model.setObjective(objective, GRB.MINIMIZE)

# Constraints
# 1. Capacity of disposal sites
for j in disposal_ids:
    model.addConstr(gp.quicksum(Y[i] * X[i, j] for i in removal_ids) <= float(disposal_sites[disposal_sites['NomDepot'] == j]['Capacite m3'].iloc[0]))

# 2. Completeness of snow removal
for i in removal_ids:
    model.addConstr(gp.quicksum(X[i, j] for j in disposal_ids) == 1)

# 3. Total snow transported from each removal site equals its snow volume
for i in removal_ids:
    total_snow_volume = float(removal_sites[removal_sites['NomSecteur'] == i]['Volume m3'].iloc[0])
    model.addConstr(gp.quicksum(Y[i] * X[i, j] for j in disposal_ids) == total_snow_volume)

# Additional constraints for priority ordering
for i in removal_ids:
    for k in removal_ids:
        if i != k:
            model.addConstr(gp.quicksum(X[i, j] for j in disposal_ids) - gp.quicksum(X[k, j] for j in disposal_ids) <= Z[i, k])

# Optimize the model
model.optimize()

# Check if an optimal solution was found
if model.status == GRB.OPTIMAL:
    # Print the total cost
    total_cost = model.ObjVal
    print(f"Total Cost of Snow Removal: ${total_cost:.2f}")

    # Print the amount of snow transported for each route
    print("\nSnow Transported for Each Route:")
    for i in removal_ids:
        for j in disposal_ids:
            if X[i, j].X > 0.5:  # If this route is used
                snow_transported = Y[i].X
                print(f"Removal site {i} -> Disposal site {j}: {snow_transported} m³")
else:
    print("No optimal solution found.")
# Out:
# Total Cost of Snow Removal: $121770460.70
#
# Snow Transported for Each Route:
# Removal site VMA-109 -> Disposal site Saint-Pierre (LAC): 93274.51 m³
# Removal site VMA-307 -> Disposal site SauvÃ© (AHU): 82691.13 m³
# Removal site VMA-306 -> Disposal site SauvÃ© (AHU): 96229.11 m³
# Removal site VMA-111 -> Disposal site SauvÃ© (AHU): 85847.51 m³
# Removal site VMA-110 -> Disposal site Saint-Pierre (LAC): 127483.61 m³
# Removal site PMR-101 -> Disposal site SauvÃ© (AHU): 158592.4 m³
# Removal site PMR-102 -> Disposal site SauvÃ© (AHU): 144354.73 m³
# Removal site S-O-104 -> Disposal site Saint-Pierre (LAC): 136883.4 m³
# Removal site PMR-204 -> Disposal site Millen (AHU): 80600.83 m³
# Removal site MHM-109 -> Disposal site Millen (AHU): 126720.19 m³
# Removal site PMR-203 -> Disposal site SauvÃ© (AHU): 97228.93 m³
# Removal site RPP-201 -> Disposal site Millen (AHU): 116858.26 m³
# Removal site MHM-209 -> Disposal site Millen (AHU): 124186.67 m³
# Removal site MHM-210 -> Disposal site Millen (AHU): 156288.64 m³
# Removal site RPP-204 -> Disposal site SauvÃ© (AHU): 123910.35 m³
# Removal site RPP-101 -> Disposal site SauvÃ© (AHU): 100797.42 m³
# Removal site RPP-102 -> Disposal site SauvÃ© (AHU): 95611.77 m³
# Removal site OUT-101 -> Disposal site SauvÃ© (AHU): 170139.37 m³
# Removal site RPP-104 -> Disposal site SauvÃ© (AHU): 152513.24 m³
# Removal site VER-310B -> Disposal site Verdun (VER): 91295.89 m³
# Removal site VSP-107 -> Disposal site SauvÃ© (AHU): 125642.5 m³
# Removal site CDN-111 -> Disposal site Saint-Pierre (LAC): 70225.35 m³
# Removal site VSP-206 -> Disposal site SauvÃ© (AHU): 107770.34 m³
# Removal site S-O-201B -> Disposal site Saint-Pierre (LAC): 107975.69 m³
# Removal site RPP-205 -> Disposal site SauvÃ© (AHU): 133863.99 m³
# Removal site AHU-107 -> Disposal site SauvÃ© (AHU): 165025.8 m³
# Removal site RPP-103 -> Disposal site SauvÃ© (AHU): 113049.76 m³
# Removal site S-O-201A -> Disposal site Saint-Pierre (LAC): 94217.6 m³
# Removal site AHU-105 -> Disposal site SauvÃ© (AHU): 144586.67 m³
# Removal site MHM-211 -> Disposal site Millen (AHU): 120956.77 m³
# Removal site VSP-104 -> Disposal site Millen (AHU): 126061.39 m³
# Removal site MHM-105 -> Disposal site St-Michel-17ième(Sous-Sol): 135651.25 m³
# Removal site CDN-112 -> Disposal site Thimens (SLA): 85719.86 m³
# Removal site S-O-103 -> Disposal site Angrignon (LAS): 197580.1 m³
# Removal site SLE-109 -> Disposal site SauvÃ© (AHU): 108860.15 m³
# Removal site CDN-301 -> Disposal site Jules-Poitras 1 (AHU): 226169.69 m³
# Removal site MHM-106 -> Disposal site St-Michel-17ième(Sous-Sol): 150424.21 m³
# Removal site MHM-107 -> Disposal site St-Michel-17ième(Sous-Sol): 156504.79 m³
# Removal site CDN-113 -> Disposal site Jules-Poitras 1 (AHU): 110109.53 m³
# Removal site LAS-328 -> Disposal site Jules-Poitras 1 (AHU): 90925.53 m³
# Removal site LAS-329 -> Disposal site Angrignon (LAS): 66308.04 m³
# Removal site LAS-321 -> Disposal site Saint-Pierre (LAC): 61684.34 m³
# Removal site ANJ-310 -> Disposal site Millen (AHU): 65548.68 m³
# Removal site VSP-205 -> Disposal site Millen (AHU): 105697.54 m³
# Removal site AHU-106 -> Disposal site Millen (AHU): 160528.94 m³
# Removal site LAS-327 -> Disposal site Jules-Poitras 1 (AHU): 68856.07 m³
# Removal site VER-310A -> Disposal site Saint-Pierre (LAC): 193127.45 m³
# Removal site MHM-108 -> Disposal site Millen (AHU): 177831.34 m³
# Removal site SLE-111 -> Disposal site Millen (AHU): 112853.32 m³
# Removal site LAS-323 -> Disposal site Saint-Pierre (LAC): 81718.74 m³
# Removal site ANJ-309 -> Disposal site SauvÃ© (AHU): 68076.99 m³
# Removal site CDN-114 -> Disposal site Thimens (SLA): 90497.64 m³
# Removal site LAS-326 -> Disposal site Jules-Poitras 1 (AHU): 66068.18 m³
# Removal site LAS-330 -> Disposal site Angrignon (LAS): 69701.58 m³
# Removal site MTN-305 -> Disposal site Millen (AHU): 173318.12 m³
# Removal site LAS-325 -> Disposal site Angrignon (LAS): 77214.89 m³
# Removal site SLE-110 -> Disposal site Millen (AHU): 143274.78 m³
# Removal site CDN-116 -> Disposal site Jules-Poitras 1 (AHU): 100403.2 m³
# Removal site SLA-364 -> Disposal site Jules-Poitras 1 (AHU): 96099.1 m³
# Removal site CDN-115 -> Disposal site Jules-Poitras 1 (AHU): 86829.59 m³
# Removal site SLA-369 -> Disposal site Thimens (SLA): 74626.73 m³
# Removal site LAS-333 -> Disposal site Angrignon (LAS): 67148.59 m³
# Removal site SLE-304 -> Disposal site SauvÃ© (AHU): 202107.95 m³
# Removal site SLE-303 -> Disposal site SauvÃ© (AHU): 219784.46 m³
# Removal site VSP-108 -> Disposal site Millen (AHU): 120159.51 m³
# Removal site LAC-102 -> Disposal site 46 ieme (LAC): 84276.29 m³
# Removal site SLA-363 -> Disposal site Jules-Poitras 1 (AHU): 84510.81 m³
# Removal site VSP-109 -> Disposal site SauvÃ© (AHU): 137970.19 m³
# Removal site SLA-370 -> Disposal site Thimens (SLA): 81596.87 m³
# Removal site MTN-102 -> Disposal site Millen (AHU): 115918.37 m³
# Removal site ANJ-312 -> Disposal site Millen (AHU): 190725.51 m³
# Removal site SLA-365 -> Disposal site Sartelon (SLA): 100648.23 m³
# Removal site VSP-103 -> Disposal site Millen (AHU): 145643.47 m³
# Removal site ANJ-311 -> Disposal site Millen (AHU): 74463.74 m³
# Removal site SLA-366 -> Disposal site Jules-Poitras 1 (AHU): 81563.47 m³
# Removal site LAC-305 -> Disposal site Thimens (SLA): 61232.24 m³
# Removal site ANJ-101 -> Disposal site St-Michel-17ième(Sous-Sol): 135587.31 m³
# Removal site SLA-371 -> Disposal site Jules-Poitras 1 (AHU): 80953.24 m³
# Removal site LAC-306 -> Disposal site 46 ieme (LAC): 149069.24 m³
# Removal site LAC-104 -> Disposal site Thimens (SLA): 52879.08 m³
# Removal site MTN-307 -> Disposal site Millen (AHU): 179912.37 m³
# Removal site SLA-368 -> Disposal site Sartelon (SLA): 92066.03 m³
# Removal site MTN-103 -> Disposal site Millen (AHU): 106176.99 m³
# Removal site MTN-104 -> Disposal site Millen (AHU): 105891.84 m³
# Removal site SLA-367 -> Disposal site Sartelon (SLA): 96600.02 m³
# Removal site RDP-202 -> Disposal site St-Michel-17ième(Sous-Sol): 115670.96 m³
# Removal site RDP-102 -> Disposal site St-Michel - Robert (VSP): 163220.74 m³
# Removal site RDP-201 -> Disposal site St-Michel-17ième(Sous-Sol): 166379.71 m³
# Removal site RDP-101 -> Disposal site St-Michel-17ième(Sous-Sol): 198928.84 m³
# Removal site RDP-103 -> Disposal site St-Michel-17ième(Sous-Sol): 201736.38 m³
# Removal site AHU-101 -> Disposal site ChÃ¢teau Pierrefonds (PRF): 146517.1 m³
# Removal site AHU-103 -> Disposal site Jules-Poitras 1 (AHU): 174266.08 m³
# Removal site RDP-203 -> Disposal site St-Michel-17ième(Sous-Sol): 182385.61 m³
# Removal site RDP-107 -> Disposal site St-Michel-17ième(Sous-Sol): 173405.52 m³
# Removal site AHU-202 -> Disposal site Jules-Poitras 1 (AHU): 135547.87 m³
# Removal site AHU-104 -> Disposal site Jules-Poitras 1 (AHU): 128579.68 m³
# Removal site AHU-102 -> Disposal site Jules-Poitras 1 (AHU): 166156.4 m³
# Removal site AHU-201 -> Disposal site Millen (AHU): 132188.9 m³
# Removal site PRF-304F -> Disposal site Thimens (SLA): 22601.93 m³
# Removal site RDP-105 -> Disposal site St-Michel-17ième(Sous-Sol): 157347.72 m³
# Removal site RDP-106 -> Disposal site St-Michel-17ième(Sous-Sol): 182306.97 m³
# Removal site PRF-304E -> Disposal site Sartelon (SLA): 38547.16 m³
# Removal site PRF-304D -> Disposal site St-Michel-17ième(Sous-Sol): 19647.35 m³
# Removal site PRF-304C -> Disposal site ChÃ¢teau Pierrefonds (PRF): 22260.38 m³
# Removal site PRF-304B -> Disposal site ChÃ¢teau Pierrefonds (PRF): 24034.84 m³
# Removal site IBI-301 -> Disposal site St-Michel-17ième(Sous-Sol): 23055.45 m³

# %% [markdown]
# ## Middle priority as hub

# %%
import gurobipy as gp
from gurobipy import GRB

# Create a Gurobi model
model = gp.Model('SnowRemoval')
model.Params.OutputFlag = 0
# Set the NonConvex parameter
model.setParam('NonConvex', 2)

# Define the hub (assuming the hub is one of the removal sites)
hub_id = 'LAS-326'  # Replace with the actual ID of the hub 

# Decision variables
removal_ids = removal_sites['NomSecteur'].tolist()
disposal_ids = disposal_sites['NomDepot'].tolist()
X = model.addVars(removal_ids, disposal_ids, vtype=GRB.BINARY, name="X")
Y = model.addVars(removal_ids, vtype=GRB.CONTINUOUS, name="Y")
Z = model.addVars(removal_ids, removal_ids, vtype=GRB.BINARY, name="Z")  # Auxiliary variables

# Pre-calculate cost and round-trip distances
cost_distance_dict = {}

for i in removal_ids:
    for j in disposal_ids:
        # Get disposal cost and convert to float
        disposal_cost = float(disposal_sites[disposal_sites['NomDepot'] == j]['Cost ($/m3)'].iloc[0]) if disposal_sites[disposal_sites['NomDepot'] == j]['Cost ($/m3)'].iloc[0] else 0.0

        # Get distance to disposal site and convert to float
        distance_to_disposal = float(dist_proper[(dist_proper['PickupSector'] == i) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].iloc[0]) if not dist_proper[(dist_proper['PickupSector'] == i) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].empty else 0.0
        
        # Get distance from disposal site to hub and convert to float
        distance_to_hub = float(dist_proper[(dist_proper['PickupSector'] == hub_id) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].iloc[0]) if not dist_proper[(dist_proper['PickupSector'] == hub_id) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].empty else 0.0

        # Get distance from hub to removal site i (assuming symmetric distances)
        distance_from_hub_to_i = float(dist_sites[(dist_sites['Removal Site 1'] == hub_id) & (dist_sites['Removal Site 2'] == i)]['Distance'].iloc[0]) if not dist_sites[(dist_sites['Removal Site 1'] == hub_id) & (dist_sites['Removal Site 2'] == i)].empty else 0.0

        # Total round-trip distance
        total_distance = distance_from_hub_to_i + distance_to_disposal + distance_to_hub

        # Store in dictionary
        cost_distance_dict[(i, j)] = (disposal_cost, total_distance)

# Objective function with penalty for priority
penalty_factor = 100000
objective = gp.quicksum(
    (Y[i] * cost_distance_dict[(i, j)][0] + Y[i]*(cost_distance_dict[(i, j)][1] * 0.1395 + 0.513)) * X[i, j]
    for i in removal_ids for j in disposal_ids)

# Adding penalty logic for priorities
for i in removal_ids:
    for k in removal_ids:
        if i != k:
            priority_diff = float(removal_sites[removal_sites['NomSecteur'] == k]['Priority'].iloc[0]) - \
                            float(removal_sites[removal_sites['NomSecteur'] == i]['Priority'].iloc[0])
            objective += penalty_factor * Z[i, k] * max(0, priority_diff)

model.setObjective(objective, GRB.MINIMIZE)

# Constraints
# 1. Capacity of disposal sites
for j in disposal_ids:
    model.addConstr(gp.quicksum(Y[i] * X[i, j] for i in removal_ids) <= float(disposal_sites[disposal_sites['NomDepot'] == j]['Capacite m3'].iloc[0]))

# 2. Completeness of snow removal
for i in removal_ids:
    model.addConstr(gp.quicksum(X[i, j] for j in disposal_ids) == 1)

# 3. Total snow transported from each removal site equals its snow volume
for i in removal_ids:
    total_snow_volume = float(removal_sites[removal_sites['NomSecteur'] == i]['Volume m3'].iloc[0])
    model.addConstr(gp.quicksum(Y[i] * X[i, j] for j in disposal_ids) == total_snow_volume)

# Additional constraints for priority ordering
for i in removal_ids:
    for k in removal_ids:
        if i != k:
            model.addConstr(gp.quicksum(X[i, j] for j in disposal_ids) - gp.quicksum(X[k, j] for j in disposal_ids) <= Z[i, k])

# Optimize the model
model.optimize()

# Check if an optimal solution was found
if model.status == GRB.OPTIMAL:
    # Print the total cost
    total_cost = model.ObjVal
    print(f"Total Cost of Snow Removal: ${total_cost:.2f}")

    # Print the amount of snow transported for each route
    print("\nSnow Transported for Each Route:")
    for i in removal_ids:
        for j in disposal_ids:
            if X[i, j].X > 0.5:  # If this route is used
                snow_transported = Y[i].X
                print(f"Removal site {i} -> Disposal site {j}: {snow_transported} m³")
else:
    print("No optimal solution found.")
# Out:
# Total Cost of Snow Removal: $53226555.05
#
# Snow Transported for Each Route:
# Removal site VMA-109 -> Disposal site Fullum (VMA): 93274.51 m³
# Removal site VMA-307 -> Disposal site Fullum (VMA): 82691.13 m³
# Removal site VMA-306 -> Disposal site Iberville (PMR): 96229.11 m³
# Removal site VMA-111 -> Disposal site Iberville (PMR): 85847.51 m³
# Removal site VMA-110 -> Disposal site Riverside (VMA): 127483.61 m³
# Removal site PMR-101 -> Disposal site Iberville (PMR): 158592.4 m³
# Removal site PMR-102 -> Disposal site Riverside (VMA): 144354.73 m³
# Removal site S-O-104 -> Disposal site Butler (S-O): 136883.4 m³
# Removal site PMR-204 -> Disposal site Iberville (PMR): 80600.83 m³
# Removal site MHM-109 -> Disposal site Iberville (PMR): 126720.19 m³
# Removal site PMR-203 -> Disposal site Iberville (PMR): 97228.93 m³
# Removal site RPP-201 -> Disposal site Millen (AHU): 116858.26 m³
# Removal site MHM-209 -> Disposal site De la Salle (MHM): 124186.67 m³
# Removal site MHM-210 -> Disposal site De la Salle (MHM): 156288.64 m³
# Removal site RPP-204 -> Disposal site St-Michel - Robert (VSP): 123910.35 m³
# Removal site RPP-101 -> Disposal site SauvÃ© (AHU): 100797.42 m³
# Removal site RPP-102 -> Disposal site Iberville (PMR): 95611.77 m³
# Removal site OUT-101 -> Disposal site SauvÃ© (AHU): 170139.37 m³
# Removal site RPP-104 -> Disposal site De la Salle (MHM): 152513.24 m³
# Removal site VER-310B -> Disposal site Verdun (VER): 91295.89 m³
# Removal site VSP-107 -> Disposal site St-Michel - Robert (VSP): 125642.5 m³
# Removal site CDN-111 -> Disposal site Saint-Pierre (LAC): 70225.35 m³
# Removal site VSP-206 -> Disposal site St-Michel - Robert (VSP): 107770.34 m³
# Removal site S-O-201B -> Disposal site Butler (S-O): 107975.69 m³
# Removal site RPP-205 -> Disposal site St-Michel - Robert (VSP): 133863.99 m³
# Removal site AHU-107 -> Disposal site Millen (AHU): 165025.8 m³
# Removal site RPP-103 -> Disposal site St-Michel - Robert (VSP): 113049.76 m³
# Removal site S-O-201A -> Disposal site Saint-Pierre (LAC): 94217.6 m³
# Removal site AHU-105 -> Disposal site SauvÃ© (AHU): 144586.67 m³
# Removal site MHM-211 -> Disposal site De la Salle (MHM): 120956.77 m³
# Removal site VSP-104 -> Disposal site St-Michel - Charland (VSP): 126061.39 m³
# Removal site MHM-105 -> Disposal site De la Salle (MHM): 135651.25 m³
# Removal site CDN-112 -> Disposal site Saint-Pierre (LAC): 85719.86 m³
# Removal site S-O-103 -> Disposal site Saint-Pierre (LAC): 197580.1 m³
# Removal site SLE-109 -> Disposal site St-Michel - Robert (VSP): 108860.15 m³
# Removal site CDN-301 -> Disposal site Saint-Pierre (LAC): 226169.69 m³
# Removal site MHM-106 -> Disposal site De la Salle (MHM): 150424.21 m³
# Removal site MHM-107 -> Disposal site De la Salle (MHM): 156504.79 m³
# Removal site CDN-113 -> Disposal site Saint-Pierre (LAC): 110109.53 m³
# Removal site LAS-328 -> Disposal site Fullum (VMA): 90925.53 m³
# Removal site LAS-329 -> Disposal site Saint-Pierre (LAC): 66308.04 m³
# Removal site LAS-321 -> Disposal site Saint-Pierre (LAC): 61684.34 m³
# Removal site ANJ-310 -> Disposal site St-Michel - Robert (VSP): 65548.68 m³
# Removal site VSP-205 -> Disposal site St-Michel - Charland (VSP): 105697.54 m³
# Removal site AHU-106 -> Disposal site Millen (AHU): 160528.94 m³
# Removal site LAS-327 -> Disposal site SauvÃ© (AHU): 68856.07 m³
# Removal site VER-310A -> Disposal site Saint-Pierre (LAC): 193127.45 m³
# Removal site MHM-108 -> Disposal site St-Michel - Robert (VSP): 177831.34 m³
# Removal site SLE-111 -> Disposal site St-Michel - Charland (VSP): 112853.32 m³
# Removal site LAS-323 -> Disposal site Saint-Pierre (LAC): 81718.74 m³
# Removal site ANJ-309 -> Disposal site St-Michel-17ième(Sous-Sol): 68076.99 m³
# Removal site CDN-114 -> Disposal site Saint-Pierre (LAC): 90497.64 m³
# Removal site LAS-326 -> Disposal site Iberville (PMR): 66068.18 m³
# Removal site LAS-330 -> Disposal site Saint-Pierre (LAC): 69701.58 m³
# Removal site MTN-305 -> Disposal site St-Michel - Charland (VSP): 173318.12 m³
# Removal site LAS-325 -> Disposal site St-Michel-17ième(Sous-Sol): 77214.89 m³
# Removal site SLE-110 -> Disposal site St-Michel - Charland (VSP): 143274.78 m³
# Removal site CDN-116 -> Disposal site Jules-Poitras 2 (SLA): 100403.2 m³
# Removal site SLA-364 -> Disposal site Jules-Poitras 1 (AHU): 96099.1 m³
# Removal site CDN-115 -> Disposal site Jules-Poitras 2 (SLA): 86829.59 m³
# Removal site SLA-369 -> Disposal site Jules-Poitras 2 (SLA): 74626.73 m³
# Removal site LAS-333 -> Disposal site St-Michel-17ième(Sous-Sol): 67148.59 m³
# Removal site SLE-304 -> Disposal site St-Michel - Robert (VSP): 202107.95 m³
# Removal site SLE-303 -> Disposal site St-Michel - Robert (VSP): 219784.46 m³
# Removal site VSP-108 -> Disposal site Millen (AHU): 120159.51 m³
# Removal site LAC-102 -> Disposal site 46 ieme (LAC): 84276.29 m³
# Removal site SLA-363 -> Disposal site Jules-Poitras 1 (AHU): 84510.81 m³
# Removal site VSP-109 -> Disposal site SauvÃ© (AHU): 137970.19 m³
# Removal site SLA-370 -> Disposal site Jules-Poitras 2 (SLA): 81596.87 m³
# Removal site MTN-102 -> Disposal site Lausanne (MTN): 115918.37 m³
# Removal site ANJ-312 -> Disposal site Lausanne (MTN): 190725.51 m³
# Removal site SLA-365 -> Disposal site Jules-Poitras 1 (AHU): 100648.23 m³
# Removal site VSP-103 -> Disposal site Millen (AHU): 145643.47 m³
# Removal site ANJ-311 -> Disposal site St-Michel - Robert (VSP): 74463.74 m³
# Removal site SLA-366 -> Disposal site Jules-Poitras 2 (SLA): 81563.47 m³
# Removal site LAC-305 -> Disposal site St-Michel-17ième(Sous-Sol): 61232.24 m³
# Removal site ANJ-101 -> Disposal site St-Michel-17ième(Sous-Sol): 135587.31 m³
# Removal site SLA-371 -> Disposal site Jules-Poitras 2 (SLA): 80953.24 m³
# Removal site LAC-306 -> Disposal site 46 ieme (LAC): 149069.24 m³
# Removal site LAC-104 -> Disposal site St-Michel-17ième(Sous-Sol): 52879.08 m³
# Removal site MTN-307 -> Disposal site Lausanne (MTN): 179912.37 m³
# Removal site SLA-368 -> Disposal site Jules-Poitras 1 (AHU): 92066.03 m³
# Removal site MTN-103 -> Disposal site Lausanne (MTN): 106176.99 m³
# Removal site MTN-104 -> Disposal site Lausanne (MTN): 105891.84 m³
# Removal site SLA-367 -> Disposal site Jules-Poitras 1 (AHU): 96600.02 m³
# Removal site RDP-202 -> Disposal site St-Michel-17ième(Sous-Sol): 115670.96 m³
# Removal site RDP-102 -> Disposal site St-Michel - Robert (VSP): 163220.74 m³
# Removal site RDP-201 -> Disposal site St-Michel-17ième(Sous-Sol): 166379.71 m³
# Removal site RDP-101 -> Disposal site St-Michel-17ième(Sous-Sol): 198928.84 m³
# Removal site RDP-103 -> Disposal site St-Michel-17ième(Sous-Sol): 201736.38 m³
# Removal site AHU-101 -> Disposal site SauvÃ© (AHU): 146517.1 m³
# Removal site AHU-103 -> Disposal site Jules-Poitras 1 (AHU): 174266.08 m³
# Removal site RDP-203 -> Disposal site St-Michel-17ième(Sous-Sol): 182385.61 m³
# Removal site RDP-107 -> Disposal site St-Michel-17ième(Sous-Sol): 173405.52 m³
# Removal site AHU-202 -> Disposal site Millen (AHU): 135547.87 m³
# Removal site AHU-104 -> Disposal site Jules-Poitras 1 (AHU): 128579.68 m³
# Removal site AHU-102 -> Disposal site Jules-Poitras 1 (AHU): 166156.4 m³
# Removal site AHU-201 -> Disposal site Millen (AHU): 132188.9 m³
# Removal site PRF-304F -> Disposal site St-Michel-17ième(Sous-Sol): 22601.93 m³
# Removal site RDP-105 -> Disposal site St-Michel-17ième(Sous-Sol): 157347.72 m³
# Removal site RDP-106 -> Disposal site St-Michel-17ième(Sous-Sol): 182306.96999999872 m³
# Removal site PRF-304E -> Disposal site St-Michel-17ième(Sous-Sol): 38547.16 m³
# Removal site PRF-304D -> Disposal site St-Michel-17ième(Sous-Sol): 19647.35 m³
# Removal site PRF-304C -> Disposal site St-Michel-17ième(Sous-Sol): 22260.38 m³
# Removal site PRF-304B -> Disposal site St-Michel-17ième(Sous-Sol): 24034.84 m³
# Removal site IBI-301 -> Disposal site St-Michel-17ième(Sous-Sol): 23055.45 m³

# %% [markdown]
# ## Finding the optimal hub

# %% [markdown]
# Code takes 1.5 hours to run - the optimal hub is VSP-206​. We are running the code for 'VSP-206' as hub at the end.

# %%
# # Initialize an empty DataFrame to store results
# results_df = pd.DataFrame(columns=['Hub', 'TotalCost'])
# route_details_df = pd.DataFrame(columns=['Hub', 'RemovalSite', 'DisposalSite', 'SnowTransported'])

# # Create a Gurobi model
# model = gp.Model('SnowRemoval')

# # Set the NonConvex parameter
# model.setParam('NonConvex', 2)

# # Iterate over each potential hub
# for potential_hub in removal_sites['NomSecteur'].tolist():
#     # Set the hub_id to the current potential hub
#     hub_id = potential_hub

#     # Decision variables
#     removal_ids = removal_sites['NomSecteur'].tolist()
#     disposal_ids = disposal_sites['NomDepot'].tolist()
#     X = model.addVars(removal_ids, disposal_ids, vtype=GRB.BINARY, name="X")
#     Y = model.addVars(removal_ids, vtype=GRB.CONTINUOUS, name="Y")
#     Z = model.addVars(removal_ids, removal_ids, vtype=GRB.BINARY, name="Z")  # Auxiliary variables

#     # Pre-calculate cost and round-trip distances
#     cost_distance_dict = {}

#     for i in removal_ids:
#         for j in disposal_ids:
#             # Get disposal cost and convert to float
#             disposal_cost = float(disposal_sites[disposal_sites['NomDepot'] == j]['Cost ($/m3)'].iloc[0]) if disposal_sites[disposal_sites['NomDepot'] == j]['Cost ($/m3)'].iloc[0] else 0.0

#             # Get distance to disposal site and convert to float
#             distance_to_disposal = float(dist_proper[(dist_proper['PickupSector'] == i) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].iloc[0]) if not dist_proper[(dist_proper['PickupSector'] == i) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].empty else 0.0

#             # Get distance from disposal site to hub and convert to float
#             distance_to_hub = float(dist_proper[(dist_proper['PickupSector'] == hub_id) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].iloc[0]) if not dist_proper[(dist_proper['PickupSector'] == hub_id) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].empty else 0.0

#             # Get distance from hub to removal site i (assuming symmetric distances)
#             distance_from_hub_to_i = float(dist_sites[(dist_sites['Removal Site 1'] == hub_id) & (dist_sites['Removal Site 2'] == i)]['Distance'].iloc[0]) if not dist_sites[(dist_sites['Removal Site 1'] == hub_id) & (dist_sites['Removal Site 2'] == i)].empty else 0.0

#             # Total round-trip distance
#             total_distance = distance_from_hub_to_i + distance_to_disposal + distance_to_hub

#             # Store in dictionary
#             cost_distance_dict[(i, j)] = (disposal_cost, total_distance)

#     # Objective function with penalty for priority
#     penalty_factor = 100000
#     objective = gp.quicksum(
#         (Y[i] * cost_distance_dict[(i, j)][0] + Y[i]*(cost_distance_dict[(i, j)][1] * 0.1395 + 0.513)) * X[i, j]
#         for i in removal_ids for j in disposal_ids)

#     # Adding penalty logic for priorities
#     for i in removal_ids:
#         for k in removal_ids:
#             if i != k:
#                 priority_diff = float(removal_sites[removal_sites['NomSecteur'] == k]['Priority'].iloc[0]) - \
#                                 float(removal_sites[removal_sites['NomSecteur'] == i]['Priority'].iloc[0])
#                 objective += penalty_factor * Z[i, k] * max(0, priority_diff)

#     model.setObjective(objective, GRB.MINIMIZE)

#     # Constraints
#     # 1. Capacity of disposal sites
#     for j in disposal_ids:
#         model.addConstr(gp.quicksum(Y[i] * X[i, j] for i in removal_ids) <= float(disposal_sites[disposal_sites['NomDepot'] == j]['Capacite m3'].iloc[0]))

#     # 2. Completeness of snow removal
#     for i in removal_ids:
#         model.addConstr(gp.quicksum(X[i, j] for j in disposal_ids) == 1)

#     # 3. Total snow transported from each removal site equals its snow volume
#     for i in removal_ids:
#         total_snow_volume = float(removal_sites[removal_sites['NomSecteur'] == i]['Volume m3'].iloc[0])
#         model.addConstr(gp.quicksum(Y[i] * X[i, j] for j in disposal_ids) == total_snow_volume)

#     # Additional constraints for priority ordering
#     for i in removal_ids:
#         for k in removal_ids:
#             if i != k:
#                 model.addConstr(gp.quicksum(X[i, j] for j in disposal_ids) - gp.quicksum(X[k, j] for j in disposal_ids) <= Z[i, k])

#     # Optimize the model
#     model.optimize()

    
#     # Check if an optimal solution was found
#     if model.status == GRB.OPTIMAL:
#         # Store total cost for the hub
#         temp_results_df = pd.DataFrame({'Hub': [potential_hub], 'TotalCost': [model.ObjVal]})
#         results_df = pd.concat([results_df, temp_results_df], ignore_index=True)

#         # Store route details
#         for i in removal_ids:
#             for j in disposal_ids:
#                 if X[i, j].X > 0.5:  # If this route is used
#                     snow_transported = Y[i].X
#                     temp_route_details = pd.DataFrame({
#                         'Hub': [potential_hub],
#                         'RemovalSite': [i],
#                         'DisposalSite': [j],
#                         'SnowTransported': [snow_transported]
#                     })
#                     route_details_df = pd.concat([route_details_df, temp_route_details], ignore_index=True)
#     else:
#         print(f"No optimal solution found for hub {potential_hub}.")

# %% [markdown]
# ## Exporting the optimal solution for each hub to a csv file

# %%
# # Export the results and route details to CSV files
# results_df.to_csv('Optimal_Hub_Results.csv', index=False)
# route_details_df.to_csv('Route_Details.csv', index=False)

# %% [markdown]
# ## Running model for 'VSP-206'

# %%
import gurobipy as gp
from gurobipy import GRB

# Create a Gurobi model
model = gp.Model('SnowRemoval')
model.Params.OutputFlag = 0

# Set the NonConvex parameter
model.setParam('NonConvex', 2)

# Define the hub (assuming the hub is one of the removal sites)
hub_id = 'VSP-206'  # Replace with the actual ID of the hub 

# Decision variables
removal_ids = removal_sites['NomSecteur'].tolist()
disposal_ids = disposal_sites['NomDepot'].tolist()
X = model.addVars(removal_ids, disposal_ids, vtype=GRB.BINARY, name="X")
Y = model.addVars(removal_ids, vtype=GRB.CONTINUOUS, name="Y")
Z = model.addVars(removal_ids, removal_ids, vtype=GRB.BINARY, name="Z")  # Auxiliary variables

# Pre-calculate cost and round-trip distances
cost_distance_dict = {}

for i in removal_ids:
    for j in disposal_ids:
        # Get disposal cost and convert to float
        disposal_cost = float(disposal_sites[disposal_sites['NomDepot'] == j]['Cost ($/m3)'].iloc[0]) if disposal_sites[disposal_sites['NomDepot'] == j]['Cost ($/m3)'].iloc[0] else 0.0

        # Get distance to disposal site and convert to float
        distance_to_disposal = float(dist_proper[(dist_proper['PickupSector'] == i) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].iloc[0]) if not dist_proper[(dist_proper['PickupSector'] == i) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].empty else 0.0
        
        # Get distance from disposal site to hub and convert to float
        distance_to_hub = float(dist_proper[(dist_proper['PickupSector'] == hub_id) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].iloc[0]) if not dist_proper[(dist_proper['PickupSector'] == hub_id) & (dist_proper['DisposalSite'] == j)][' Distance (km)'].empty else 0.0

        # Get distance from hub to removal site i (assuming symmetric distances)
        distance_from_hub_to_i = float(dist_sites[(dist_sites['Removal Site 1'] == hub_id) & (dist_sites['Removal Site 2'] == i)]['Distance'].iloc[0]) if not dist_sites[(dist_sites['Removal Site 1'] == hub_id) & (dist_sites['Removal Site 2'] == i)].empty else 0.0

        # Total round-trip distance
        total_distance = distance_from_hub_to_i + distance_to_disposal + distance_to_hub

        # Store in dictionary
        cost_distance_dict[(i, j)] = (disposal_cost, total_distance)

# Objective function with penalty for priority
penalty_factor = 100000
objective = gp.quicksum(
    (Y[i] * cost_distance_dict[(i, j)][0] + Y[i]*(cost_distance_dict[(i, j)][1] * 0.1395 + 0.513)) * X[i, j]
    for i in removal_ids for j in disposal_ids)

# Adding penalty logic for priorities
for i in removal_ids:
    for k in removal_ids:
        if i != k:
            priority_diff = float(removal_sites[removal_sites['NomSecteur'] == k]['Priority'].iloc[0]) - \
                            float(removal_sites[removal_sites['NomSecteur'] == i]['Priority'].iloc[0])
            objective += penalty_factor * Z[i, k] * max(0, priority_diff)

model.setObjective(objective, GRB.MINIMIZE)

# Constraints
# 1. Capacity of disposal sites
for j in disposal_ids:
    model.addConstr(gp.quicksum(Y[i] * X[i, j] for i in removal_ids) <= float(disposal_sites[disposal_sites['NomDepot'] == j]['Capacite m3'].iloc[0]))

# 2. Completeness of snow removal
for i in removal_ids:
    model.addConstr(gp.quicksum(X[i, j] for j in disposal_ids) == 1)

# 3. Total snow transported from each removal site equals its snow volume
for i in removal_ids:
    total_snow_volume = float(removal_sites[removal_sites['NomSecteur'] == i]['Volume m3'].iloc[0])
    model.addConstr(gp.quicksum(Y[i] * X[i, j] for j in disposal_ids) == total_snow_volume)

# Additional constraints for priority ordering
for i in removal_ids:
    for k in removal_ids:
        if i != k:
            model.addConstr(gp.quicksum(X[i, j] for j in disposal_ids) - gp.quicksum(X[k, j] for j in disposal_ids) <= Z[i, k])

# Optimize the model
model.optimize()

# Check if an optimal solution was found
if model.status == GRB.OPTIMAL:
    # Print the total cost
    total_cost = model.ObjVal
    print(f"Total Cost of Snow Removal: ${total_cost:.2f}")

    # Print the amount of snow transported for each route
    print("\nSnow Transported for Each Route:")
    for i in removal_ids:
        for j in disposal_ids:
            if X[i, j].X > 0.5:  # If this route is used
                snow_transported = Y[i].X
                print(f"Removal site {i} -> Disposal site {j}: {snow_transported} m³")
else:
    print("No optimal solution found.")
# Out:
# Total Cost of Snow Removal: $42049854.45
#
# Snow Transported for Each Route:
# Removal site VMA-109 -> Disposal site Iberville (PMR): 93274.51 m³
# Removal site VMA-307 -> Disposal site Iberville (PMR): 82691.13 m³
# Removal site VMA-306 -> Disposal site Iberville (PMR): 96229.11 m³
# Removal site VMA-111 -> Disposal site Iberville (PMR): 85847.51 m³
# Removal site VMA-110 -> Disposal site Iberville (PMR): 127483.61 m³
# Removal site PMR-101 -> Disposal site Iberville (PMR): 158592.4 m³
# Removal site PMR-102 -> Disposal site Iberville (PMR): 144354.73 m³
# Removal site S-O-104 -> Disposal site Iberville (PMR): 136883.4 m³
# Removal site PMR-204 -> Disposal site Iberville (PMR): 80600.83 m³
# Removal site MHM-109 -> Disposal site Iberville (PMR): 126720.19 m³
# Removal site PMR-203 -> Disposal site Iberville (PMR): 97228.93 m³
# Removal site RPP-201 -> Disposal site St-Michel - Robert (VSP): 116858.26 m³
# Removal site MHM-209 -> Disposal site Iberville (PMR): 124186.67 m³
# Removal site MHM-210 -> Disposal site Iberville (PMR): 156288.64 m³
# Removal site RPP-204 -> Disposal site St-Michel - Robert (VSP): 123910.35 m³
# Removal site RPP-101 -> Disposal site St-Michel - Robert (VSP): 100797.42 m³
# Removal site RPP-102 -> Disposal site St-Michel - Robert (VSP): 95611.77 m³
# Removal site OUT-101 -> Disposal site SauvÃ© (AHU): 170139.37 m³
# Removal site RPP-104 -> Disposal site St-Michel - Robert (VSP): 152513.24 m³
# Removal site VER-310B -> Disposal site Iberville (PMR): 91295.89 m³
# Removal site VSP-107 -> Disposal site St-Michel - Robert (VSP): 125642.5 m³
# Removal site CDN-111 -> Disposal site Iberville (PMR): 70225.35 m³
# Removal site VSP-206 -> Disposal site St-Michel - Robert (VSP): 107770.34 m³
# Removal site S-O-201B -> Disposal site Riverside (VMA): 107975.69 m³
# Removal site RPP-205 -> Disposal site St-Michel - Robert (VSP): 133863.99 m³
# Removal site AHU-107 -> Disposal site Millen (AHU): 165025.8 m³
# Removal site RPP-103 -> Disposal site St-Michel - Robert (VSP): 113049.76 m³
# Removal site S-O-201A -> Disposal site Saint-Pierre (LAC): 94217.6 m³
# Removal site AHU-105 -> Disposal site SauvÃ© (AHU): 144586.67 m³
# Removal site MHM-211 -> Disposal site St-Michel - Robert (VSP): 120956.77 m³
# Removal site VSP-104 -> Disposal site St-Michel - Charland (VSP): 126061.39 m³
# Removal site MHM-105 -> Disposal site Iberville (PMR): 135651.25 m³
# Removal site CDN-112 -> Disposal site St-Michel-17ième(Sous-Sol): 85719.86 m³
# Removal site S-O-103 -> Disposal site St-Michel-17ième(Sous-Sol): 197580.1 m³
# Removal site SLE-109 -> Disposal site St-Michel - Robert (VSP): 108860.15 m³
# Removal site CDN-301 -> Disposal site St-Michel-17ième(Sous-Sol): 226169.69 m³
# Removal site MHM-106 -> Disposal site Iberville (PMR): 150424.21 m³
# Removal site MHM-107 -> Disposal site St-Michel - Robert (VSP): 156504.79 m³
# Removal site CDN-113 -> Disposal site St-Michel-17ième(Sous-Sol): 110109.53 m³
# Removal site LAS-328 -> Disposal site St-Michel - Robert (VSP): 90925.53 m³
# Removal site LAS-329 -> Disposal site St-Michel-17ième(Sous-Sol): 66308.04 m³
# Removal site LAS-321 -> Disposal site St-Michel-17ième(Sous-Sol): 61684.34 m³
# Removal site ANJ-310 -> Disposal site St-Michel - Robert (VSP): 65548.68 m³
# Removal site VSP-205 -> Disposal site St-Michel - Charland (VSP): 105697.54 m³
# Removal site AHU-106 -> Disposal site St-Michel - Charland (VSP): 160528.94 m³
# Removal site LAS-327 -> Disposal site St-Michel - Robert (VSP): 68856.07 m³
# Removal site VER-310A -> Disposal site St-Michel-17ième(Sous-Sol): 193127.45 m³
# Removal site MHM-108 -> Disposal site St-Michel - Robert (VSP): 177831.34 m³
# Removal site SLE-111 -> Disposal site St-Michel - Robert (VSP): 112853.32 m³
# Removal site LAS-323 -> Disposal site St-Michel-17ième(Sous-Sol): 81718.74 m³
# Removal site ANJ-309 -> Disposal site St-Michel - Robert (VSP): 68076.99 m³
# Removal site CDN-114 -> Disposal site SauvÃ© (AHU): 90497.64 m³
# Removal site LAS-326 -> Disposal site St-Michel - Robert (VSP): 66068.18 m³
# Removal site LAS-330 -> Disposal site St-Michel-17ième(Sous-Sol): 69701.58 m³
# Removal site MTN-305 -> Disposal site St-Michel - Charland (VSP): 173318.12 m³
# Removal site LAS-325 -> Disposal site St-Michel-17ième(Sous-Sol): 77214.89 m³
# Removal site SLE-110 -> Disposal site St-Michel - Robert (VSP): 143274.78 m³
# Removal site CDN-116 -> Disposal site SauvÃ© (AHU): 100403.2 m³
# Removal site SLA-364 -> Disposal site SauvÃ© (AHU): 96099.1 m³
# Removal site CDN-115 -> Disposal site SauvÃ© (AHU): 86829.59 m³
# Removal site SLA-369 -> Disposal site SauvÃ© (AHU): 74626.73 m³
# Removal site LAS-333 -> Disposal site St-Michel-17ième(Sous-Sol): 67148.59 m³
# Removal site SLE-304 -> Disposal site St-Michel - Robert (VSP): 202107.95 m³
# Removal site SLE-303 -> Disposal site St-Michel - Robert (VSP): 219784.46 m³
# Removal site VSP-108 -> Disposal site St-Michel - Robert (VSP): 120159.51 m³
# Removal site LAC-102 -> Disposal site St-Michel-17ième(Sous-Sol): 84276.29 m³
# Removal site SLA-363 -> Disposal site SauvÃ© (AHU): 84510.81 m³
# Removal site VSP-109 -> Disposal site SauvÃ© (AHU): 137970.19 m³
# Removal site SLA-370 -> Disposal site Jules-Poitras 2 (SLA): 81596.87 m³
# Removal site MTN-102 -> Disposal site St-Michel - Charland (VSP): 115918.37 m³
# Removal site ANJ-312 -> Disposal site St-Michel - Charland (VSP): 190725.51 m³
# Removal site SLA-365 -> Disposal site SauvÃ© (AHU): 100648.23 m³
# Removal site VSP-103 -> Disposal site St-Michel - Robert (VSP): 145643.47 m³
# Removal site ANJ-311 -> Disposal site St-Michel - Robert (VSP): 74463.74 m³
# Removal site SLA-366 -> Disposal site SauvÃ© (AHU): 81563.47 m³
# Removal site LAC-305 -> Disposal site St-Michel-17ième(Sous-Sol): 61232.24 m³
# Removal site ANJ-101 -> Disposal site St-Michel - Robert (VSP): 135587.31 m³
# Removal site SLA-371 -> Disposal site SauvÃ© (AHU): 80953.24 m³
# Removal site LAC-306 -> Disposal site St-Michel-17ième(Sous-Sol): 149069.24 m³
# Removal site LAC-104 -> Disposal site SauvÃ© (AHU): 52879.08 m³
# Removal site MTN-307 -> Disposal site St-Michel - Robert (VSP): 179912.37 m³
# Removal site SLA-368 -> Disposal site SauvÃ© (AHU): 92066.03 m³
# Removal site MTN-103 -> Disposal site Lausanne (MTN): 106176.99 m³
# Removal site MTN-104 -> Disposal site St-Michel - Charland (VSP): 105891.84 m³
# Removal site SLA-367 -> Disposal site SauvÃ© (AHU): 96600.02 m³
# Removal site RDP-202 -> Disposal site St-Michel - Robert (VSP): 115670.96 m³
# Removal site RDP-102 -> Disposal site St-Michel - Robert (VSP): 163220.74 m³
# Removal site RDP-201 -> Disposal site St-Michel - Charland (VSP): 166379.71 m³
# Removal site RDP-101 -> Disposal site Lausanne (MTN): 198928.84 m³
# Removal site RDP-103 -> Disposal site Lausanne (MTN): 201736.38 m³
# Removal site AHU-101 -> Disposal site SauvÃ© (AHU): 146517.1 m³
# Removal site AHU-103 -> Disposal site SauvÃ© (AHU): 174266.08 m³
# Removal site RDP-203 -> Disposal site Lafarge (sud) (MHM): 182385.61 m³
# Removal site RDP-107 -> Disposal site St-Michel - Robert (VSP): 173405.52 m³
# Removal site AHU-202 -> Disposal site Millen (AHU): 135547.87 m³
# Removal site AHU-104 -> Disposal site Millen (AHU): 128579.68 m³
# Removal site AHU-102 -> Disposal site SauvÃ© (AHU): 166156.4 m³
# Removal site AHU-201 -> Disposal site Millen (AHU): 132188.9 m³
# Removal site PRF-304F -> Disposal site SauvÃ© (AHU): 22601.93 m³
# Removal site RDP-105 -> Disposal site St-Michel-17ième(Sous-Sol): 157347.72 m³
# Removal site RDP-106 -> Disposal site St-Michel-17ième(Sous-Sol): 182306.97 m³
# Removal site PRF-304E -> Disposal site St-Michel-17ième(Sous-Sol): 38547.16 m³
# Removal site PRF-304D -> Disposal site St-Michel-17ième(Sous-Sol): 19647.35 m³
# Removal site PRF-304C -> Disposal site St-Michel-17ième(Sous-Sol): 22260.38 m³
# Removal site PRF-304B -> Disposal site St-Michel-17ième(Sous-Sol): 24034.84 m³
# Removal site IBI-301 -> Disposal site St-Michel-17ième(Sous-Sol): 23055.45 m³
